# %%
# dark theme extension https://stackoverflow.com/questions/46510192/change-the-theme-in-jupyter-notebook
import fingertips_py as ftp
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
import os
pd.set_option('display.max_colwidth', -1)    # stop the column text truncating... 
pd.set_option("display.max_rows", None, "display.max_columns", None)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
indicator_df = ftp.get_metadata_for_all_indicators_from_csv()

# %%
##################################################################################################
# buyzzwords
# asthma - done 
# lower respiratory tract infections - done 
# pneumonia - done 
# respiratory - done 
# chronic obstructive pulmonary disease - done 

### tables broken down by ailment, next --> arrange into indicdence, mortality rate, hospital admissions.


# 1205  Lung cancer registrations
# 1203	Mortality rate from lung cancer


# 90612 COPD002: Diagnosis conf. by spirometry (den. incl. exc.) - need to check 
# 92302	Emergency hospital admissions for COPD
# 93577	Emergency hospital admissions for COPD, all ages
# 253		COPD: QOF prevalence (all ages)  --> check out...    
# 93643	Mortality rate from COPD as a contributory cause
# 1204	Mortality rate from chronic obstructive pulmonary disease


# 40701	Under 75 mortality rate from respiratory disease
# 93575	Emergency hospital admissions for respiratory disease

# 92253	Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years
# 192972	Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years
# 92971	Admissions for lower respiratory tract infections in infants aged 1 year
# 92252	Admissions for lower respiratory tract infections in infants aged 1 year
# 92251	Admissions for lower respiratory tract infections in infants aged under 1 year
# 92970	Admissions for lower respiratory tract infections in infants aged under 1 year
# 93576	Emergency hospital admissions for bronchiolitis in children aged under 2 years

# 93573	Emergency hospital admissions for asthma in adults (aged 19 years and over)
# 90810	Hospital admissions for asthma (under 19 years)
# 92780	Hospital admissions for asthma (under 19 years) -- need to see which one is relevant
# 93644	Mortality rate from asthma


# 93574	Emergency hospital admissions for pneumonia
# 93641	Mortality rate from pneumonia (all mentions)
# 93640	Mortality rate from pneumonia (underlying cause)


##################################################################################################

# rearranged:

### Prevalance...  -- maybe lung cancer can surplus Quality framework dataset... 
# 1205  Lung cancer registrations
# 253		COPD: QOF prevalence (all ages)  --> check out...   

### mortality
# 1203	Mortality rate from lung cancer
# 93643	Mortality rate from COPD as a contributory cause
# 1204	Mortality rate from chronic obstructive pulmonary disease
# 40701	Under 75 mortality rate from respiratory disease
# 93644	Mortality rate from asthma
# 93641	Mortality rate from pneumonia (all mentions)
# 93640	Mortality rate from pneumonia (underlying cause)


### admissions 
# 92302	Emergency hospital admissions for COPD
# 93577	Emergency hospital admissions for COPD, all ages
# 93575	Emergency hospital admissions for respiratory disease
# 92253	Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years
# 192972	Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years
# 92971	Admissions for lower respiratory tract infections in infants aged 1 year
# 92252	Admissions for lower respiratory tract infections in infants aged 1 year
# 92251	Admissions for lower respiratory tract infections in infants aged under 1 year
# 92970	Admissions for lower respiratory tract infections in infants aged under 1 year
# 93573	Emergency hospital admissions for asthma in adults (aged 19 years and over)
# 90810	Hospital admissions for asthma (under 19 years)
# 92780	Hospital admissions for asthma (under 19 years) -- need to see which one is relevant
# 93574	Emergency hospital admissions for pneumonia


### need to check 
# 90612 COPD002: Diagnosis conf. by spirometry (den. incl. exc.) - need to check

# %%
# define the indicator df here
indicator_df = ftp.get_metadata_for_all_indicators_from_csv()
interested_indicators = indicator_df[['Indicator ID', 'Indicator']].sort_values(by='Indicator')

# %%
# We search the indicator_df here and return indicators want to use in our analysis
interested_indicators[interested_indicators['Indicator'].str.lower().str.contains('asthma'.lower())].head(100)
# Out:
#       Indicator ID  \
# 191   90615
# 853   92481
# 1196  93136
# 866   92624
# 1199  93137
# 30    285
# 1285  93573
# 31    286
# 287   90810
# 664   92780
# 1300  93595
# 1299  93594
# 1292  93644
#
#                                                                                                            Indicator
# 191   AST004: smoking recorded in last 12 mths (14-19y w asthma), den. incl. exc.
# 853   Admissions for asthma for children aged 0 to 9
# 1196  Admissions for asthma for children aged 0 to 9
# 866   Admissions for asthma for young people aged 10 to 18
# 1199  Admissions for asthma for young people aged 10 to 18
# 30    Asthma: QOF prevalence (all ages)
# 1285  Emergency hospital admissions for asthma in adults (aged 19 years and over)
# 31    Exception rate for asthma indicators
# 287   Hospital admissions for asthma (under 19 years)
# 664   Hospital admissions for asthma (under 19 years)
# 1300  Median length of stay (days) of emergency admissions to hospital for asthma (under 19 years)
# 1299  Median length of stay (days) of emergency admissions to hospital for asthma in adults (aged 19 years and over)
# 1292  Mortality rate from asthma

# %%
def _concat_output_data(indicator_ids, name):
    directory = './data_output/{0}'.format(name)

    if not os.path.exists(directory):
        os.makedirs(directory)
        
    lst_df = []
    for id in indicator_ids:
        tmp_d = ftp.get_data_for_indicator_at_all_available_geographies(id)
        lst_df.append(tmp_d)
        
    tmp_concat = pd.concat(lst_df, axis=0, ignore_index=True)
    
    tmp_concat.to_csv(directory + '/' +  name + '.csv')
    
    # free memory
    tmp_concat= None 
    lst_df = None

# %%
# concat the prevalence dataset
# _concat_output_data([1205,253, 285], 'prevalance_supplement')

# %%
# concat mortality_rate dataset
# _concat_output_data([1203,93643, 1204, 40701, 93644, 93641, 93640], 'mortality_rate')

# %%
# concat hospital admissions dataset
# _concat_output_data([92302,93577, 93575, 92253, 192972, 92971, 92252, 92251, 92970, 93573, 90810, 92780, 93574], 'hospital_admissions')

# %%
# one time run (as we removed subset, already hardcoded into function if we reload.)
# hospital_admissions_df.to_csv('./data_output/hospital_admissions/hospital_admissions.csv')

# %%
mlc = ftp.get_data_for_indicator_at_all_available_geographies(285)
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(mlc.shape)

mlc[(mlc['Area Type']=='GP')].head(100)
# Out:
# (73710, 26)
#      Indicator ID                     Indicator Name Parent Code Parent Name  \
# 2    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 3    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 4    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 5    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 6    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 7    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 8    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 9    285           Asthma: QOF prevalence (all ages)  E92000001   England
# 10   285           Asthma: QOF prevalence (all ages)  E92000001   England
#
# 23   4.781184             5.561656            NaN
# 24   4.163848             5.176138            NaN
# 25   5.635403             6.527458            NaN
# 26   5.798402             6.635016            NaN
# 27   5.509462             6.415548            NaN
# 28   6.808543             7.521248            NaN
# 29   6.001300             6.905834            NaN
# 30   7.506292             8.321450            NaN
# 31   4.165078             5.079126            NaN
# 32   4.604922             6.080265            NaN
# 33   6.202113             7.282910            NaN
# 34   5.782939             6.828438            NaN
# 35   4.508821             5.363020            NaN
# 36   4.870373             5.999368            NaN
# 37   6.727216             7.865083            NaN
# 38   4.999621             5.707540            NaN
# 39   5.203565             6.265036            NaN
# 40   5.633386             6.461027            NaN
# 41   4.736804             5.951010            NaN
# 42   4.860160             6.076163            NaN
# 43   4.776382             5.798091            NaN
# 44   5.429102             6.482778            NaN
# 45   3.963164             4.926200            NaN
# 46   6.073472             7.135809            NaN
# 47   4.257953             5.934498            NaN
# 48   4.471287             5.442049            NaN
# 49   5.471822             6.541124            NaN
# 50   4.222446             5.364432            NaN
# 51   3.755035             4.769327            NaN
# 52   4.509509             5.589879            NaN
# 53   6.547851             8.399242            NaN
# 54   5.692058             7.196714            NaN
# 55   5.955140             6.941214            NaN
# 56   3.798489             5.805256            NaN
# 57   5.280005             7.119581            NaN
# 58   5.474840             7.890966            NaN
# 59   5.910812             6.995578            NaN
# 60   4.533861             5.776737            NaN
# 61   4.103118             5.713434            NaN
# 62   6.328115             7.535051            NaN
# 63   8.426074             10.887852           NaN
# 64   5.651936             6.944802            NaN
# 65   4.906942             6.443475            NaN
# 66   8.671833             12.179418           NaN
# 67   5.059400             6.210039            NaN
# 68   0.350034             1.901190            NaN
# 69   1.515082             3.271500            NaN
# 70   6.509079             7.713359            NaN
# 71   5.654121             7.662067            NaN
# 72   5.240454             6.430866            NaN
# 73   4.632132             5.860107            NaN
# 74   6.946910             7.985594            NaN
# 75   5.408486             6.265818            NaN
# 76   5.813416             6.844081            NaN
# 77   6.771203             7.990272            NaN
# 78   5.748741             6.516748            NaN
# 79   5.492149             6.625231            NaN
# 80   5.338253             6.734936            NaN
# 81   5.422150             6.638858            NaN
# 82   6.252446             7.060769            NaN
# 83   6.746670             7.710590            NaN
# 84   5.223127             6.216029            NaN
# 85   5.900338             6.696677            NaN
# 86   6.857553             8.037368            NaN
# 87   5.499695             6.788614            NaN
# 88   7.232160             8.983393            NaN
# 89   6.283299             7.603190            NaN
# 90   6.683552             7.764527            NaN
# 91   5.477728             6.212427            NaN
# 92   6.342122             7.247482            NaN
# 93   5.241208             6.416863            NaN
# 94   7.116998             8.960618            NaN
# 95   6.306417             7.573951            NaN
# 96   4.894754             6.623421            NaN
# 97   5.881056             6.700452            NaN
# 98   7.207107             8.341427            NaN
# 99   5.839121             7.005856            NaN
# 100  5.782205             6.525388            NaN
# 101  5.378797             6.330259            NaN
#
#      Upper CI 99.8 limit  Count  Denominator Value note Recent Trend  \
# 2   NaN                   301    4164         NaN        NaN
# 3   NaN                   1548   20588        NaN        NaN
# 4   NaN                   463    8271         NaN        NaN
# 5   NaN                   380    7972         NaN        NaN
# 75  NaN                   668    11473        NaN        NaN
# 76  NaN                   540    8559         NaN        NaN
# 77  NaN                   519    7054         NaN        NaN
# 78  NaN                   917    14980        NaN        NaN
# 79  NaN                   410    6795         NaN        NaN
# 80  NaN                   267    4451         NaN        NaN
# 81  NaN                   352    5865         NaN        NaN
# 82  NaN                   970    14597        NaN        NaN
# 83  NaN                   799    11076        NaN        NaN
# 84  NaN                   478    8387         NaN        NaN
# 85  NaN                   898    14284        NaN        NaN
# 86  NaN                   564    7595         NaN        NaN
# 87  NaN                   325    5317         NaN        NaN
# 88  NaN                   300    3720         NaN        NaN
# 89  NaN                   393    5684         NaN        NaN
# 90  NaN                   634    8799         NaN        NaN
# 91  NaN                   913    15649        NaN        NaN
# 92  NaN                   804    11857        NaN        NaN
# 93  NaN                   353    6085         NaN        NaN
# 94  NaN                   266    3329         NaN        NaN
# 95  NaN                   426    6162         NaN        NaN
# 96  NaN                   158    2773         NaN        NaN
# 97  NaN                   846    13475        NaN        NaN
# 98  NaN                   663    8549         NaN        NaN
# 99  NaN                   433    6768         NaN        NaN
# 100 NaN                   986    16050        NaN        NaN
# 101 NaN                   545    9338         NaN        NaN
#
#     Compared to England value or percentiles Compared to percentiles  \
# 2    Higher                                   Not compared
# 3    Higher                                   Not compared
# 4    Similar                                  Not compared
# 5    Lower                                    Not compared
# 6    Similar                                  Not compared
# 7    Higher                                   Not compared
# 8    Similar                                  Not compared
# 9    Similar                                  Not compared
# 10   Similar                                  Not compared
# 11   Lower                                    Not compared
# 12   Higher                                   Not compared
# 13   Similar                                  Not compared
# 14   Lower                                    Not compared
# 15   Similar                                  Not compared
# 16   Similar                                  Not compared
# 17   Similar                                  Not compared
# 18   Similar                                  Not compared
# 19   Similar                                  Not compared
# 20   Similar                                  Not compared
# 21   Higher                                   Not compared
# 22   Similar                                  Not compared
# 23   Lower                                    Not compared
# 24   Lower                                    Not compared
# 25   Similar                                  Not compared
# 26   Similar                                  Not compared
# 27   Similar                                  Not compared
# 28   Higher                                   Not compared
# 29   Similar                                  Not compared
# 30   Higher                                   Not compared
# 31   Lower                                    Not compared
# 32   Similar                                  Not compared
# 33   Similar                                  Not compared
# 34   Similar                                  Not compared
# 35   Lower                                    Not compared
# 36   Similar                                  Not compared
# 37   Higher                                   Not compared
# 38   Lower                                    Not compared
# 39   Similar                                  Not compared
# 40   Similar                                  Not compared
# 41   Similar                                  Not compared
# 42   Similar                                  Not compared
# 43   Similar                                  Not compared
# 44   Similar                                  Not compared
# 45   Lower                                    Not compared
# 46   Similar                                  Not compared
# 47   Similar                                  Not compared
# 48   Lower                                    Not compared
# 49   Similar                                  Not compared
# 50   Lower                                    Not compared
# 51   Lower                                    Not compared
# 52   Lower                                    Not compared
# 53   Higher                                   Not compared
# 54   Similar                                  Not compared
# 55   Similar                                  Not compared
# 56   Similar                                  Not compared
# 57   Similar                                  Not compared
# 58   Similar                                  Not compared
# 59   Similar                                  Not compared
# 60   Similar                                  Not compared
# 61   Similar                                  Not compared
# 62   Higher                                   Not compared
# 63   Higher                                   Not compared
# 64   Similar                                  Not compared
# 65   Similar                                  Not compared
# 66   Higher                                   Not compared
# 67   Similar                                  Not compared
# 68   Lower                                    Not compared
# 69   Lower                                    Not compared
# 70   Higher                                   Not compared
# 71   Similar                                  Not compared
# 72   Similar                                  Not compared
# 73   Similar                                  Not compared
# 74   Higher                                   Not compared
# 75   Similar                                  Not compared
# 76   Similar                                  Not compared
# 77   Higher                                   Not compared
# 78   Similar                                  Not compared
# 79   Similar                                  Not compared
# 80   Similar                                  Not compared
# 81   Similar                                  Not compared
# 82   Higher                                   Not compared
# 83   Higher                                   Not compared
# 84   Similar                                  Not compared
# 85   Similar                                  Not compared
# 86   Higher                                   Not compared
# 87   Similar                                  Not compared
# 88   Higher                                   Not compared
# 89   Similar                                  Not compared
# 90   Higher                                   Not compared
# 91   Similar                                  Not compared
# 92   Higher                                   Not compared
# 93   Similar                                  Not compared
# 94   Higher                                   Not compared
# 95   Similar                                  Not compared
# 96   Similar                                  Not compared
# 97   Similar                                  Not compared
# 98   Higher                                   Not compared
# 99   Similar                                  Not compared
# 100  Similar                                  Not compared
# 101  Similar                                  Not compared
#
#      Time period Sortable  New data  Compared to goal
# 2    20090000             NaN       NaN
# 3    20090000             NaN       NaN
# 4    20090000             NaN       NaN
# 5    20090000             NaN       NaN
# 6    20090000             NaN       NaN
# 7    20090000             NaN       NaN
# 8    20090000             NaN       NaN
# 9    20090000             NaN       NaN
# 10   20090000             NaN       NaN
# 11   20090000             NaN       NaN
# 12   20090000             NaN       NaN
# 13   20090000             NaN       NaN
# 14   20090000             NaN       NaN
# 15   20090000             NaN       NaN
# 16   20090000             NaN       NaN
# 17   20090000             NaN       NaN
# 18   20090000             NaN       NaN
# 19   20090000             NaN       NaN
# 20   20090000             NaN       NaN
# 21   20090000             NaN       NaN
# 22   20090000             NaN       NaN
# 23   20090000             NaN       NaN
# 24   20090000             NaN       NaN
# 25   20090000             NaN       NaN
# 26   20090000             NaN       NaN
# 27   20090000             NaN       NaN
# 28   20090000             NaN       NaN
# 29   20090000             NaN       NaN
# 30   20090000             NaN       NaN
# 31   20090000             NaN       NaN
# 32   20090000             NaN       NaN
# 33   20090000             NaN       NaN
# 34   20090000             NaN       NaN
# 35   20090000             NaN       NaN
# 36   20090000             NaN       NaN
# 37   20090000             NaN       NaN
# 38   20090000             NaN       NaN
# 39   20090000             NaN       NaN
# 40   20090000             NaN       NaN
# 41   20090000             NaN       NaN
# 42   20090000             NaN       NaN
# 43   20090000             NaN       NaN
# 44   20090000             NaN       NaN
# 45   20090000             NaN       NaN
# 46   20090000             NaN       NaN
# 47   20090000             NaN       NaN
# 48   20090000             NaN       NaN
# 49   20090000             NaN       NaN
# 50   20090000             NaN       NaN
# 51   20090000             NaN       NaN
# 52   20090000             NaN       NaN
# 53   20090000             NaN       NaN
# 54   20090000             NaN       NaN
# 55   20090000             NaN       NaN
# 56   20090000             NaN       NaN
# 57   20090000             NaN       NaN
# 58   20090000             NaN       NaN
# 59   20090000             NaN       NaN
# 60   20090000             NaN       NaN
# 61   20090000             NaN       NaN
# 62   20090000             NaN       NaN
# 63   20090000             NaN       NaN
# 64   20090000             NaN       NaN
# 65   20090000             NaN       NaN
# 66   20090000             NaN       NaN
# 67   20090000             NaN       NaN
# 68   20090000             NaN       NaN
# 69   20090000             NaN       NaN
# 70   20090000             NaN       NaN
# 71   20090000             NaN       NaN
# 72   20090000             NaN       NaN
# 73   20090000             NaN       NaN
# 74   20090000             NaN       NaN
# 75   20090000             NaN       NaN
# 76   20090000             NaN       NaN
# 77   20090000             NaN       NaN
# 78   20090000             NaN       NaN
# 79   20090000             NaN       NaN
# 80   20090000             NaN       NaN
# 81   20090000             NaN       NaN
# 82   20090000             NaN       NaN
# 83   20090000             NaN       NaN
# 84   20090000             NaN       NaN
# 85   20090000             NaN       NaN
# 86   20090000             NaN       NaN
# 87   20090000             NaN       NaN
# 88   20090000             NaN       NaN
# 89   20090000             NaN       NaN
# 90   20090000             NaN       NaN
# 91   20090000             NaN       NaN
# 92   20090000             NaN       NaN
# 93   20090000             NaN       NaN
# 94   20090000             NaN       NaN
# 95   20090000             NaN       NaN
# 96   20090000             NaN       NaN
# 97   20090000             NaN       NaN
# 98   20090000             NaN       NaN
# 99   20090000             NaN       NaN
# 100  20090000             NaN       NaN
# 101  20090000             NaN       NaN

# %%
# checks 

def preliminary_data_checks(df, name):
    
    print('Running analysis checks on the {0} DataFrame...'.format(name))
    print('\n\n')
    
    print('the shape of the df is as follows: ', df.shape)
    print('\n\n')


    print('Check 1. Columns for the {0} DataFrame as as follows: {1} \n'.format(name, list(df.columns)))
    print('\n\n')
    


    
    print('Check 2. The {0} DataFrame column datatypes are as follows: {1}'.format(name, df.dtypes))
    print('\n\n')
    
    
    
    print('Check 1a. NULL values in Columns for the {0} DataFrame as as follows: \n'.format(name))
    print(df.isna().sum())
    print('\n\n')
    
    
    indicators = df['Indicator Name'].unique()
    print('there are {0} diifferent indicators in this set, they are as follows:'.format(len(indicators)))
    for indicator in indicators:
        print(indicator)
        
    print('\n\n')
    
    print('data is prevalent for the following years (individual indicator analysis is required...) \n')
    print(sorted(df['Time period Sortable'].unique()))
#     print(sorted(tmp_df['Area Type'].unique()))

# %% [markdown]
# # Run analysis on Data now it has been concatenated

# %%
mortality_df = pd.read_csv('./data_output/mortality_rate/mortality_rate.csv')
prevalance_supplement_df = pd.read_csv('./data_output/prevalance_supplement/prevalance_supplement.csv')
hospital_admissions_df = pd.read_csv('./data_output/hospital_admissions/hospital_admissions.csv')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (10,11,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
preliminary_data_checks(mortality_df, 'mortality')
# Out:
# Running analysis checks on the mortality DataFrame...
#
#
#
# the shape of the df is as follows:  (228912, 27)
#
#
#
# Check 1. Columns for the mortality DataFrame as as follows: ['Unnamed: 0', 'Indicator ID', 'Indicator Name', 'Parent Code', 'Parent Name', 'Area Code', 'Area Name', 'Area Type', 'Sex', 'Age', 'Category Type', 'Category', 'Time period', 'Value', 'Lower CI 95.0 limit', 'Upper CI 95.0 limit', 'Lower CI 99.8 limit', 'Upper CI 99.8 limit', 'Count', 'Denominator', 'Value note', 'Recent Trend', 'Compared to England value or percentiles', 'Compared to percentiles', 'Time period Sortable', 'New data', 'Compared to goal']
#
#
#
#
# Check 2. The mortality DataFrame column datatypes are as follows: Unnamed: 0                                  int64
# Indicator ID                                int64
# Indicator Name                              object
# Parent Code                                 object
# Parent Name                                 object
# Area Code                                   object
# Area Name                                   object
# Area Type                                   object
# Sex                                         object
# Age                                         object
# Category Type                               object
# Category                                    object
# Time period                                 object
# Value                                       float64
# Lower CI 95.0 limit                         float64
# Upper CI 95.0 limit                         float64
# Lower CI 99.8 limit                         float64
# Upper CI 99.8 limit                         float64
# Count                                       float64
# Denominator                                 float64
# Value note                                  object
# Recent Trend                                object
# Compared to England value or percentiles    object
# Compared to percentiles                     object
# Time period Sortable                        int64
# New data                                    float64
# Compared to goal                            float64
# dtype: object
#
#
#
# Check 1a. NULL values in Columns for the mortality DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 5337
# Parent Name                                 5337
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               218652
# Category                                    218652
# Time period                                 0
# Value                                       2692
# Lower CI 95.0 limit                         2692
# Upper CI 95.0 limit                         2692
# Lower CI 99.8 limit                         183528
# Upper CI 99.8 limit                         183528
# Count                                       5183
# Denominator                                 860
# Value note                                  221151
# Recent Trend                                215069
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    228912
# Compared to goal                            228912
# dtype: int64
#
#
#
# there are 7 diifferent indicators in this set, they are as follows:
# Mortality rate from lung cancer
# Mortality rate from COPD as a contributory cause
# Mortality rate from chronic obstructive pulmonary disease
# Under 75 mortality rate from respiratory disease
# Mortality rate from asthma
# Mortality rate from pneumonia (all mentions)
# Mortality rate from pneumonia (underlying cause)
#
#
#
# data is prevalent for the following years (individual indicator analysis is required...)
#
# [20010000, 20020000, 20030000, 20040000, 20050000, 20060000, 20070000, 20080000, 20090000, 20100000, 20110000, 20120000, 20130000, 20140000, 20150000, 20160000, 20170000]

# %%
# get some plots? so we can see visualise the different indicators and time 
# mortality_df.plot('Indicator Name', 'Time period Sortable')
# plt.show()


# piv = mortality_df.pivot(index='Time period Sortable', columns='Indicator name', values='Count')

# %%
# grouped = mortality_df.groupby(['Time period Sortable', 'Indicator Name']).size().reset_index().rename(columns={0:'nr_records'})


# we should use count instead, as we do not want to include the null values with 'size()'
# we pick any column (Area codem, whatever, they will all contain the same vlaue the same)
grouped = mortality_df.groupby(['Time period Sortable', 'Indicator Name']).count()['Area Code'].reset_index().rename(columns={'Area Code':'nr_records'})

# get rid of extra 0 and cast to int for now...
grouped['Time period Sortable'] = (grouped['Time period Sortable']/10000).astype(int)
grouped.head()
# Out:
#    Time period Sortable  \
# 0  2001
# 1  2001
# 2  2001
# 3  2002
# 4  2002
#
#                                               Indicator Name  nr_records
# 0  Mortality rate from chronic obstructive pulmonary disease  4533
# 1  Mortality rate from lung cancer                            3015
# 2  Under 75 mortality rate from respiratory disease           4266
# 3  Mortality rate from chronic obstructive pulmonary disease  4533
# 4  Mortality rate from lung cancer                            3015

# %%
piv = grouped.pivot(
index = 'Time period Sortable',
columns='Indicator Name',
values='nr_records'
)
piv.head(100)

# %%
# we cant see because the datapoints are exactly the same for indicators (so the lines overlap, maybe)
# piv.plot()
# plt.legend((bbox_to_anchor)=(1.03,1), loc=2, borderaxespad=1)


# instead try a facet grid
# pivot doesnt seem to be working (maybe set is too large, next we will try facetgrid with seaborn)
m = sns.FacetGrid(grouped, col='Indicator Name', col_wrap=3, height=5)
m.map(sns.lineplot, 'Time period Sortable', 'nr_records')
m.set(xticks=np.arange(2000, 2022, 2))

# %%
# the above =shows that we have good data for the mortality rate
grouped.head()

for indicator in grouped['Indicator Name'].unique():
    t_df = grouped[grouped['Indicator Name'] == indicator]
    max_year = t_df['Time period Sortable'].max()
    min_year = t_df['Time period Sortable'].min()

    print('Indicator statistics for {0}:'.format(indicator))
    
    print('First Data Points: {0} the last data points {1} \n'.format(
        min_year, max_year)
    )
# Out:
# Indicator statistics for Mortality rate from chronic obstructive pulmonary disease:
# First Data Points: 2001 the last data points 2017
#
# Indicator statistics for Mortality rate from lung cancer:
# First Data Points: 2001 the last data points 2017
#
# Indicator statistics for Under 75 mortality rate from respiratory disease:
# First Data Points: 2001 the last data points 2017
#
# Indicator statistics for Mortality rate from COPD as a contributory cause:
# First Data Points: 2006 the last data points 2017
#
# Indicator statistics for Mortality rate from asthma:
# First Data Points: 2006 the last data points 2017
#
# Indicator statistics for Mortality rate from pneumonia (all mentions):
# First Data Points: 2006 the last data points 2017
#
# Indicator statistics for Mortality rate from pneumonia (underlying cause):
# First Data Points: 2006 the last data points 2017

# %%
# remove england statistics, we want CCGs
special = mortality_df[(mortality_df['Area Name'] != 'England')]

# filter out male and female results, for now
special = special[special['Sex'] == 'Persons']

# limit to CCGS (using LOC with isin())
special = special.loc[special['Area Type'].isin(['CCGs (since 4/20)','CCGs (2019/20)'])]


# Important graph is to plot the different indicators values by year (so use a sum instead of count)
grouped_sum = special.groupby(['Time period Sortable', 'Indicator Name']).sum()['Count'].reset_index()



# get rid of extra 0 and cast to int for now, for the sortable time period...
grouped_sum['Time period Sortable'] = (grouped_sum['Time period Sortable']/10000).astype(int)
grouped_sum.head()

# we will use seaborn here (for pandas will need another pivot table, where we break out indicator name)

# set the figure size with rc argument for seaborn (stack overflow)
sns.set(rc={'figure.figsize':(11,8)})

sns.lineplot(data=grouped_sum, x='Time period Sortable', y='Count', hue='Indicator Name', legend='full')

# Put the legend out of the figure using matlibplot (stackoverflow...)
plt.legend((bbox_to_anchor)=(1.03,1), loc=2, borderaxespad=1)

plt.show()

# %%
def plot_indicator_df(df):
    # Important graph is to plot the different indicators values by year (so use a sum instead of count)
    grouped_sum = df.groupby(['Time period Sortable', 'Indicator Name', 'Indicator ID']).sum()['Count'].reset_index()

    # get rid of extra 0 and cast to int for now...
    grouped_sum['Time period Sortable'] = (grouped_sum['Time period Sortable']/10000).astype(int)
#     grouped_sum['Count'] = grouped_sum['Count'].astype(int)

    # we will use seaborn here (for pandas will need another pivot table, where we break out indicator name)
    # set the figure size with rc argument for seaborn (stack overflow)
    sns.set(rc={'figure.figsize':(11,8)})

    sns.lineplot(data=grouped_sum, x='Time period Sortable', y='Count', hue='Indicator Name', legend='full')

    # Put the legend out of the figure using matlibplot (stackoverflow...)
    plt.legend((bbox_to_anchor)=(1.03,1), loc=2, borderaxespad=1)

    plt.show()

# %% [markdown]
# we will now answer the dataset detailing questions:
#
#
# 1. How many data sources are you using? Where are you getting the data from? Is it publicly available?
# Who provides the data? What challenges might be present based on your answers?
#
# **Answer**
# For Fingertips, we are using the publicly available 'fingertips_py' python package: https://fingertips-py.readthedocs.io/en/latest/ to download a SERIES (PUT FINAL NUMBER) of indicators. Preliminary findings indicate that data is on tghe yearly level, for the mortalities dataset we have a window between 2006 - 2017 for all indicators.

# %% [markdown]
# ### 2. How large are your data sets? Do you foresee any hardware restrictions in analyzing your data? Will you need to use creative methods to handle your data (working in smaller batches, outsourcing computing etc.)

# %%
print('answer: we have concatenated the fingertips indicators into three datasets: mortality_df, prevalance_supplement_df, hospital_admissions_df')

print('the size is as follows: ')
print('mortality: ', mortality_df.shape)
print('prevalance_supplement_df: ', prevalance_supplement_df.shape)
print('hospital_admissions_df: ', hospital_admissions_df.shape)

print('At the time of writing, we do not see a problem with analysing the sets, as our model will take a subset of rows based on CGP area location. In addition, our important field (count) is aggregated to the year level.')

mortality_df.head()
# Out:
# answer: we have concatenated the fingertips indicators into three datasets: mortality_df, prevalance_supplement_df, hospital_admissions_df
# the size is as follows:
# mortality:  (228912, 27)
# prevalance_supplement_df:  (157586, 27)
# hospital_admissions_df:  (55900, 28)
# At the time of writing, we do not see a problem with analysing the sets, as our model will take a subset of rows based on CGP area location. In addition, our important field (count) is aggregated to the year level.
#    Unnamed: 0  Indicator ID                   Indicator Name Parent Code  \
# 0  0           1203          Mortality rate from lung cancer  NaN
# 1  1           1203          Mortality rate from lung cancer  NaN
# 2  2           1203          Mortality rate from lung cancer  NaN
# 3  3           1203          Mortality rate from lung cancer  NaN
# 4  4           1203          Mortality rate from lung cancer  NaN
#
#   Parent Name  Area Code Area Name Area Type   Sex       Age  \
# 0  NaN         E92000001  England   England   Male  All ages
# 1  NaN         E92000001  England   England   Male  All ages
# 2  NaN         E92000001  England   England   Male  All ages
# 3  NaN         E92000001  England   England   Male  All ages
# 4  NaN         E92000001  England   England   Male  All ages
#
#                                           Category Type  \
# 0  NaN
# 1  County & UA deprivation deciles in England (IMD2010)
# 2  County & UA deprivation deciles in England (IMD2010)
# 3  County & UA deprivation deciles in England (IMD2010)
# 4  County & UA deprivation deciles in England (IMD2010)
#
#                                 Category Time period       Value  \
# 0  NaN                                    2001 - 03   93.446004
# 1  Most deprived decile (IMD2010)         2001 - 03   129.952898
# 2  Second most deprived decile (IMD2010)  2001 - 03   113.045523
# 3  Third more deprived decile (IMD2010)   2001 - 03   122.301265
# 4  Fourth more deprived decile (IMD2010)  2001 - 03   109.243674
#
#    Lower CI 95.0 limit  Upper CI 95.0 limit  Lower CI 99.8 limit  \
# 0  92.596587            94.301109           NaN
# 1  126.203319           133.782087          NaN
# 2  109.214648           116.972968          NaN
# 3  118.496771           126.193157          NaN
# 4  106.086345           112.468933          NaN
#
#    Upper CI 99.8 limit    Count  Denominator Value note Recent Trend  \
# 0 NaN                   49011.0  72886051.0   NaN        NaN
# 1 NaN                   4952.0   6435808.0    NaN        NaN
# 2 NaN                   3528.0   5129660.0    NaN        NaN
# 3 NaN                   4238.0   4944789.0    NaN        NaN
# 4 NaN                   4824.0   6391084.0    NaN        NaN
#
#   Compared to England value or percentiles Compared to percentiles  \
# 0  Not compared                             Not compared
# 1  Worse                                    Not compared
# 2  Worse                                    Not compared
# 3  Worse                                    Not compared
# 4  Worse                                    Not compared
#
#    Time period Sortable  New data  Compared to goal
# 0  20010000             NaN       NaN
# 1  20010000             NaN       NaN
# 2  20010000             NaN       NaN
# 3  20010000             NaN       NaN
# 4  20010000             NaN       NaN

# %% [markdown]
# ### 3.  What variables do you have in your data? What data dypes do you have?

# %%
print('The variables for mortality_df, prevalance_supplement_df, hospital_admissions_df are consistent and follow the convention: \n')
print('mortality: ', mortality_df.dtypes)
print('\n')

# print('hospital_admissions_df: ', hospital_admissions_df.dtypes)
# print('\n\n')


print(hospital_admissions_df.columns == prevalance_supplement_df.columns )
print(prevalance_supplement_df.columns ==hospital_admissions_df.columns)
print('\n\n')


print('''Fields of interest are: Indicator Name, Area Name, Area Type, Time Period Sortable/Time Period Count, 
Denominator. Additional fields of interest for model breakdown: Age, Sex''')

print('potential problem with lung cancel registrations (no denominator.... I dont think we can use this set )')


print('largest issue is that we do not have GP/hospital breakdown with this set.')
# Out:
# The variables for mortality_df, prevalance_supplement_df, hospital_admissions_df are consistent and follow the convention:
#
# mortality:  Unnamed: 0                                  int64
# Indicator ID                                int64
# Indicator Name                              object
# Parent Code                                 object
# Parent Name                                 object
# Area Code                                   object
# Area Name                                   object
# Area Type                                   object
# Sex                                         object
# Age                                         object
# Category Type                               object
# Category                                    object
# Time period                                 object
# Value                                       float64
# Lower CI 95.0 limit                         float64
# Upper CI 95.0 limit                         float64
# Lower CI 99.8 limit                         float64
# Upper CI 99.8 limit                         float64
# Count                                       float64
# Denominator                                 float64
# Value note                                  object
# Recent Trend                                object
# Compared to England value or percentiles    object
# Compared to percentiles                     object
# Time period Sortable                        int64
# New data                                    float64
# Compared to goal                            float64
# dtype: object
#
#
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
#
#
#
# Fields of interest are: Indicator Name, Area Name, Area Type, Time Period Sortable/Time Period Count,
# Denominator. Additional fields of interest for model breakdown: Age, Sex
# potential problem with lung cancel registrations (no denominator.... I dont think we can use this set )
# largest issue is that we do not have GP/hospital breakdown with this set.

# %% [markdown]
# ### 4.  How complete is your data? How will you be addressing NAs?

# %%
for df, name in [[mortality_df, 'mortality'],[ prevalance_supplement_df, 'prevalence'], [ hospital_admissions_df, 'hospital']]:
    
    print('Check 1a. NULL values in Columns for the {0} DataFrame as as follows: \n'.format(name))
    print(df.isna().sum())
    print('\n\n')
    print('Reasons for Nan values are specified here: ', df[df['Count'].isna()]['Value note'].unique())
    print('\n\n')

    
    
    
# There are NaNs in some CCG fields across all years. 
# The documentation (https://www.ons.gov.uk/file?uri=/methodology/methodologytopicsandstatisticalconcepts/disclosurecontrol/healthstatistics/confidentialityguidanctcm77181864.pdf) 
# explains that cell suppression has taken place, in CCGs recording low numbers of indicators (to avoid identification of paitents)
# Secondary supression also occurs in the same field for CCGs (to avoid disclosure by differencing) 


print('For supressed CCGs, we should potentially drom them from our analysis (as no data available across range'),

print('if missing data due to malfunction e.g. 1 year, - we could interpolate based on the values before after, or the CGP values around this area..')

print('potential problem with lung cancel registrations (no denominator.... I dont think we can use this set ) - it might not have the range anyway...')
# Out:
# Check 1a. NULL values in Columns for the mortality DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 5337
# Parent Name                                 5337
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               218652
# Category                                    218652
# Time period                                 0
# Value                                       2692
# Lower CI 95.0 limit                         2692
# Upper CI 95.0 limit                         2692
# Lower CI 99.8 limit                         183528
# Upper CI 99.8 limit                         183528
# Count                                       5183
# Denominator                                 860
# Value note                                  221151
# Recent Trend                                215069
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    228912
# Compared to goal                            228912
# dtype: int64
#
#
#
# Reasons for Nan values are specified here:  ['Value for Cornwall and Isles of Scilly combined'
#  'Value cannot be calculated as number of cases is too small'
#  'Value for Hackney and City of London combined'
#  'Value suppressed to avoid disclosure by differencing'
#  'Value suppressed for disclosure control due to small count']
#
#
#
# Check 1a. NULL values in Columns for the prevalence DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 241
# Parent Name                                 241
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               157164
# Category                                    157164
# Time period                                 0
# Value                                       38
# Lower CI 95.0 limit                         144
# Upper CI 95.0 limit                         144
# Lower CI 99.8 limit                         127543
# Upper CI 99.8 limit                         127543
# Count                                       80
# Denominator                                 10040
# Value note                                  156785
# Recent Trend                                141744
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    157586
# Compared to goal                            157586
# dtype: int64
#
#
#
# Reasons for Nan values are specified here:  [nan 'Value for Cornwall and Isles of Scilly combined'
#  'Value for Hackney and City of London combined']
#
#
#
# Check 1a. NULL values in Columns for the hospital DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 1636
# Parent Name                                 1636
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               53570
# Category                                    53570
# Time period                                 0
# Value                                       1650
# Lower CI 95.0 limit                         2232
# Upper CI 95.0 limit                         2232
# Lower CI 99.8 limit                         12677
# Upper CI 99.8 limit                         12677
# Count                                       1642
# Denominator                                 522
# Value note                                  52834
# Recent Trend                                45742
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    56538
# Compared to goal                            56538
# dtype: int64
#
#
#
# Reasons for Nan values are specified here:  ['Value for Cornwall and Isles of Scilly combined'
#  'Value for Hackney and City of London combined'
#  'Value is not presented due to an issue with HES coding in Nottingham University Hospitals Trust in 2016/17, for which over 30% of records did not have a valid geography of residence assigned. In 2015/16, over 20% of patients that attended hospital from this area were treated at Nottingham University Hospitals Trust.'
#  'Value is not presented due to an issue with HES coding in East Sussex Healthcare NHS Trust in 2018/19, for which approximately 85,000 records erroneously had all diagnosis codes removed. In 2018/19, over 10% of patients that attended hospital from this area had records that were missing diagnosis codes'
#  'Value suppressed for disclosure control reasons'
#  'Value suppressed for disclosure control due to small count'
#  'Value suppressed to avoid disclosure by differencing'
#  'Due to an issue with HES coding in Nottingham University Hospitals Trust in 2016/17, for which over 30% of records did not have a valid geography of residence assigned, this value should be treated with caution. In 2015/16, between 10% and 20% of patients that attended hospital from this area were treated at Nottingham University Hospitals Trust.']
#
#
#
# For supressed CCGs, we should potentially drom them from our analysis (as no data available across range
# if missing data due to malfunction e.g. 1 year, - we could interpolate based on the values before after, or the CGP values around this area..
# potential problem with lung cancel registrations (no denominator.... I dont think we can use this set ) - it might not have the range anyway...

# %%
# plot a graph for the datasets to see data window:
for df, name in [[mortality_df, 'mortality'],[ prevalance_supplement_df, 'prevalence'], [ hospital_admissions_df, 'hospital']]:
    print('Plotting incident graph for {0} dataset.'.format(name))
    print('\n\n')
    plot_indicator_df(df)
    print('\n\n')
# Out:
# Plotting incident graph for mortality dataset.
# Plotting incident graph for prevalence dataset.
# Plotting incident graph for hospital dataset.
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# **drop "Emergency hospital admissions for bronchiolitis in children aged under 2 years"** indicator.. only 1 year
# 5. Do you need more data at this point?
#    * **Answer** three notable issues with this dataset are
#    * Datasets are not broken down by hospital/GP... this means they cannot work with the radius/distance approach
#    * Hospital admissions/prevalence supplement sets are yearly, mortality is bi-yearly
#    * Hospital admissions do not go back further than 2013  aside from Asthma U19 (2011) & COPD (2010) and all end in 2018, these give us 7 and 8 points for our model respectively.
#    * Asthma hospital admissions (under 19) has two variants; 90810 is based on older definition of CCP, 92780 (2013 onwards) is the up-to-date CCP one
#    * SAME for COPD admission  - 92302 (2010 onwards) is the older definition, 93577 is the up-to-date CCG definition
#    * Mortality dataset rows are aggregated for two years (2001 - 2003, 2002 - 2004... 2017-2019).. we may need to aggrgate the pollution for 2 years for mortality indicators.
#
#    * Our three prevelance supplement datasets,
#        * COPD: QOF prevalence (all ages), broken down by GP, 2009 - 2019 data, this should be identical to NHS set.
#        * Asthma QOF prevalence (all ages), broken down by GP, 2009 - 2019 data, this should be identical to NHS set.
#        * Both prevalence sets show increase in 2015 (more collection?)
#        * Lung Cancer registrations is broken down by "County & UA" (not CCP) and is in two - year intervals. - N/A
#
#
#
#
# 6. What keys exist for record linkaging if you need to do so in the future?
#    * Time period Sortable
#    * Area Name (CCG - we can link this to pollutant station location, & e.g. map out which station lies in which CCG)
#
#
# 7. What are the most interesting data points?
#    * Prevalence supplement - spike in 2015, further investigation required
#
#
#
# 8. Are there any data points that you don't have yet that you would like or need for your analysis?
#    * Annual points for mortality dataset.

# %%
# need to drop the child bronchitis row, not useful (and only 1 yesr of data)

# 93576

print(hospital_admissions_df.shape)
print(hospital_admissions_df['Indicator ID'].unique())

hospital_admissions_df = hospital_admissions_df.drop(hospital_admissions_df[hospital_admissions_df['Indicator ID'] == 93576].index)


print(hospital_admissions_df.shape)
print(hospital_admissions_df['Indicator ID'].unique())

# tmp = hospital_admissions_df.copy()

# print(tmp['Indicator ID'].unique())
# print(tmp.shape)

# tmp = tmp.drop(tmp[tmp['Indicator ID'] == 93576].index)
# print(tmp['Indicator ID'].unique())
# print(tmp.shape)

# tmp
# Out:
# (56538, 27)
# [92302 93577 93575 92253 92971 92252 92251 92970 93576 93573 90810 92780
#  93574]
# (55900, 27)
# [92302 93577 93575 92253 92971 92252 92251 92970 93573 90810 92780 93574]

# %%
# tst = hospital_admissions_df[hospital_admissions_df['Indicator Name']=='Hospital admissions for asthma (under 19 years)']
tst = hospital_admissions_df.copy()
# grp = tst.groupby(['Indicator ID', 'Time period']).sum()['Count']
# print(grp.head(20))


# 92302	Emergency hospital admissions for COPD
# 93577	Emergency hospital admissions for COPD, all ages


print(tst[tst['Indicator ID'] == 92302 ]['Area Type'].unique())
print(tst[tst['Indicator ID'] == 93577 ]['Area Type'].unique())
# Out:
# ['England' 'County & UA (4/19-3/20)' 'District & UA (4/19-3/20)'
#  'Combined authorities' 'County & UA (pre 4/19)' 'District & UA (pre 4/19)'
#  'Region']
# ['England' 'CCGs (since 4/20)' 'CCGs (2019/20)']

# %%
tst[(tst['Indicator ID'] == 90810) & (tst['Area Type'] == 'County & UA (pre 4/19)') ].head(1000)
# Out:
#        Unnamed: 0  Indicator ID  \
# 45211  45211       90810
# 45212  45212       90810
# 45213  45213       90810
# 45214  45214       90810
# 45215  45215       90810
# 45216  45216       90810
# 45217  45217       90810
# 45218  45218       90810
# 45219  45219       90810
# 45220  45220       90810
# 45221  45221       90810
# 45222  45222       90810
# 45223  45223       90810
# 45224  45224       90810
# 45225  45225       90810
# 45226  45226       90810
# 45227  45227       90810
# 45228  45228       90810
# 45229  45229       90810
# 45230  45230       90810
# 45231  45231       90810
# 45232  45232       90810
# 45233  45233       90810
# 45234  45234       90810
# 45235  45235       90810
# 45236  45236       90810
# 45237  45237       90810
# 45238  45238       90810
# 45239  45239       90810
# 45240  45240       90810
# 45241  45241       90810
# 45242  45242       90810
# 45243  45243       90810
# 45244  45244       90810
# 45245  45245       90810
# 45246  45246       90810
# 45247  45247       90810
# 45248  45248       90810
# 45249  45249       90810
# 45250  45250       90810
# 45251  45251       90810
# 45252  45252       90810
# 45253  45253       90810
# 45254  45254       90810
# 45377  Hospital admissions for asthma (under 19 years)  E92000001
# 45378  Hospital admissions for asthma (under 19 years)  E92000001
# 45379  Hospital admissions for asthma (under 19 years)  E92000001
# 45380  Hospital admissions for asthma (under 19 years)  E92000001
# 45381  Hospital admissions for asthma (under 19 years)  E92000001
# 45382  Hospital admissions for asthma (under 19 years)  E92000001
# 45383  Hospital admissions for asthma (under 19 years)  E92000001
# 45384  Hospital admissions for asthma (under 19 years)  E92000001
# 45385  Hospital admissions for asthma (under 19 years)  E92000001
# 45386  Hospital admissions for asthma (under 19 years)  E92000001
# 45387  Hospital admissions for asthma (under 19 years)  E92000001
# 45388  Hospital admissions for asthma (under 19 years)  E92000001
# 45389  Hospital admissions for asthma (under 19 years)  E92000001
# 45390  Hospital admissions for asthma (under 19 years)  E92000001
# 45391  Hospital admissions for asthma (under 19 years)  E92000001
# 45392  Hospital admissions for asthma (under 19 years)  E92000001
# 45393  Hospital admissions for asthma (under 19 years)  E92000001
# 45394  Hospital admissions for asthma (under 19 years)  E92000001
# ...
# 45935  20130000             NaN       NaN
# 45936  20130000             NaN       NaN
# 45937  20130000             NaN       NaN
# 45938  20130000             NaN       NaN
# 45939  20130000             NaN       NaN
# 45940  20130000             NaN       NaN
# 45941  20130000             NaN       NaN
# 45942  20130000             NaN       NaN
# 45943  20130000             NaN       NaN
# 45944  20130000             NaN       NaN
# 45945  20130000             NaN       NaN
# 45946  20130000             NaN       NaN
# 45947  20130000             NaN       NaN
# 45948  20130000             NaN       NaN
# 45949  20130000             NaN       NaN
# 45950  20130000             NaN       NaN
# 45951  20130000             NaN       NaN
# 45952  20130000             NaN       NaN
# 45953  20130000             NaN       NaN
# 45954  20130000             NaN       NaN
# 45955  20130000             NaN       NaN
# 45956  20130000             NaN       NaN
# 45957  20130000             NaN       NaN
# 45958  20130000             NaN       NaN
# 45959  20130000             NaN       NaN
# 45960  20130000             NaN       NaN
# 45961  20130000             NaN       NaN
# 45962  20130000             NaN       NaN
# 45963  20130000             NaN       NaN
# 45964  20130000             NaN       NaN
# 45965  20130000             NaN       NaN
# 45966  20130000             NaN       NaN
# 45967  20130000             NaN       NaN
# 45968  20130000             NaN       NaN
# 45969  20130000             NaN       NaN
# 45970  20130000             NaN       NaN
# 45971  20130000             NaN       NaN
# 45972  20130000             NaN       NaN
# 45973  20130000             NaN       NaN
# 45974  20130000             NaN       NaN
# 45975  20130000             NaN       NaN
# 45976  20130000             NaN       NaN
# 45977  20130000             NaN       NaN
# 45978  20130000             NaN       NaN
# 45979  20130000             NaN       NaN
# 45980  20130000             NaN       NaN
# 45981  20130000             NaN       NaN
# 45982  20130000             NaN       NaN
# 45983  20130000             NaN       NaN
# 45984  20130000             NaN       NaN
# 45985  20130000             NaN       NaN
# 45986  20130000             NaN       NaN
# 45987  20130000             NaN       NaN
# 45988  20130000             NaN       NaN
# 45989  20130000             NaN       NaN
# 45990  20130000             NaN       NaN
# 45991  20130000             NaN       NaN
# 45992  20130000             NaN       NaN
# 45993  20130000             NaN       NaN
# 46174  20130000             NaN       NaN
# 46175  20130000             NaN       NaN
# 46176  20130000             NaN       NaN
# 46177  20130000             NaN       NaN
# 46178  20130000             NaN       NaN
# 46179  20130000             NaN       NaN
# 46180  20130000             NaN       NaN
# 46181  20130000             NaN       NaN
# 46182  20130000             NaN       NaN
# 46183  20130000             NaN       NaN
# 46184  20130000             NaN       NaN
# 46185  20130000             NaN       NaN
# 46186  20130000             NaN       NaN
# 46187  20130000             NaN       NaN
# 46188  20130000             NaN       NaN
# 46189  20130000             NaN       NaN
# 46190  20130000             NaN       NaN
# 46191  20130000             NaN       NaN
# 46192  20130000             NaN       NaN
# 46193  20130000             NaN       NaN
# 46194  20130000             NaN       NaN
# 46195  20130000             NaN       NaN
# 46196  20130000             NaN       NaN
# 46197  20130000             NaN       NaN
# 46198  20130000             NaN       NaN
# 46199  20130000             NaN       NaN
# 46200  20130000             NaN       NaN
# 46201  20130000             NaN       NaN
# 46202  20130000             NaN       NaN
# 46203  20130000             NaN       NaN
# 46204  20130000             NaN       NaN
# 46205  20130000             NaN       NaN
# 46206  20130000             NaN       NaN
# 46207  20130000             NaN       NaN
# 46208  20130000             NaN       NaN
# 46209  20130000             NaN       NaN
# 46210  20130000             NaN       NaN

# %%
def func(row):
    if row['Indicator ID'] == 92780:        
        return 'Hospital admissions for asthma (under 19 years) CCG'
    else:
        return row['Indicator Name']
# Out:
# (56538,)

# %%
# use apply to rename the extra asthma dataset. 
hospital_admissions_df['Indicator Name'] = hospital_admissions_df.apply(func, axis=1)
hospital_admissions_df.shape
# Out:
# (56538, 27)

# %%
hospital_admissions_df['Indicator Name'].unique()
# Out:
# array(['Emergency hospital admissions for COPD',
#        'Emergency hospital admissions for COPD, all ages',
#        'Emergency hospital admissions for respiratory disease',
#        'Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years',
#        'Admissions for lower respiratory tract infections in infants aged 1 year',
#        'Admissions for lower respiratory tract infections in infants aged under 1 year',
#        'Emergency hospital admissions for bronchiolitis in children aged under 2 years',
#        'Emergency hospital admissions for asthma in adults (aged 19 years and over)',
#        'Hospital admissions for asthma (under 19 years)',
#        'Hospital admissions for asthma (under 19 years) CCG',
#        'Emergency hospital admissions for pneumonia'], dtype=object)

# %%
# extra check, look at other method, proof there is no hospital trust breakdown (158 is trust level), 
# no results returned for hospital level (158)
ftp.retrieve_data.get_data_by_indicator_ids(['92302', '93577', '93575', '92253', '92971', '92252', '92251', '92970', '93573', '90810', '92780', '93574'], '158')

# results returned
# ftp.retrieve_data.get_data_by_indicator_ids(['92302', '93577', '93575', '92253', '92971', '92252', '92251', '92970', '93573', '90810', '92780', '93574'], '166')
# Out:
# Empty DataFrame
# Columns: [Indicator ID, Indicator Name, Parent Code, Parent Name, Area Code, Area Name, Area Type, Sex, Age, Category Type, Category, Time period, Value, Lower CI 95.0 limit, Upper CI 95.0 limit, Lower CI 99.8 limit, Upper CI 99.8 limit, Count, Denominator, Value note, Recent Trend, Compared to England value or percentiles, Compared to percentiles, Time period Sortable, New data, Compared to goal]
# Index: []

# %%
profile_dict = ftp.metadata.get_all_profiles()

# %%
profile_dict
# Out:
# [{'Id': 18,
#   'Name': 'Local Tobacco Control Profiles',
#   'Key': 'tobacco-control',
#   'GroupIds': [1938132885,
#    1938132886,
#    1938132900,
#    1938132887,
#    1938132888,
#    1938132889,
#    1938132890],
#   'GroupMetadata': [{'Id': 1938132885,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 18},
#    {'Id': 1938132886,
#     'Name': 'Smoking prevalence in adults',
#     'Sequence': 2,
#     'ProfileId': 18},
#    {'Id': 1938132900,
#     'Name': 'Smoking prevalence in priority populations',
#     'Sequence': 3,
#     'ProfileId': 18},
#    {'Id': 1938132887,
#     'Name': 'Smoking related mortality',
#     'Sequence': 4,
#     'ProfileId': 18},
#    {'Id': 1938132888,
#     'Name': 'Smoking related ill health',
#     'Sequence': 5,
#     'ProfileId': 18},
#    {'Id': 1938132889,
#     'Name': 'Impact of smoking',
#     'Sequence': 6,
#     'ProfileId': 18},
#    {'Id': 1938132890,
#     'Name': 'Smoking quitters',
#     'Sequence': 7,
#     'ProfileId': 18}]},
#  {'Id': 19,
#   'Name': 'Public Health Outcomes Framework',
#   'Key': 'public-health-outcomes-framework',
#   'GroupIds': [1000049, 1000041, 1000042, 1000043, 1000044, 1938132983],
#   'GroupMetadata': [{'Id': 1000049,
#     'Name': 'A. Overarching indicators',
#     'Sequence': 1,
#     'ProfileId': 19},
#    {'Id': 1000041,
#     'Name': 'B. Wider determinants of health',
#     'Sequence': 2,
#     'ProfileId': 19},
#    {'Id': 1000042,
#     'Name': 'C. Health improvement',
#     'Sequence': 3,
#     'ProfileId': 19},
#    {'Id': 1000043,
#     'Name': 'D. Health protection',
#     'Sequence': 4,
#     'ProfileId': 19},
#    {'Id': 1000044,
#     'Name': 'E. Healthcare and premature mortality',
#     'Sequence': 5,
#     'ProfileId': 19},
#    {'Id': 1938132983,
#     'Name': 'Supporting information',
#     'Sequence': 6,
#     'ProfileId': 19}]},
#  {'Id': 20,
#   'Name': 'National General Practice Profiles',
#   'Key': 'general-practice',
#   'GroupIds': [2000005,
#    1938132829,
#    1938133086,
#    3000008,
#    3000007,
#    3000009,
#    3000010,
#    2000002,
#    2000003,
#    2000009,
#    2000006,
#    1938132970,
#    2000004],
#   'GroupMetadata': [{'Id': 2000005,
#     'Name': 'Practice Summary',
#     'Sequence': 1,
#     'ProfileId': 20},
#    {'Id': 1938132829, 'Name': 'Cancer', 'Sequence': 2, 'ProfileId': 20},
#    {'Id': 1938133086,
#     'Name': 'Cancer  - TWW referrals',
#     'Sequence': 3,
#     'ProfileId': 20},
#    {'Id': 3000008,
#     'Name': 'CVD  - Coronary heart disease',
#     'Sequence': 4,
#     'ProfileId': 20},
#    {'Id': 3000007,
#     'Name': 'CVD  - Stroke and TIA',
#     'Sequence': 5,
#     'ProfileId': 20},
#    {'Id': 3000009,
#     'Name': 'CVD  - Heart failure and atrial fibrillation',
#     'Sequence': 6,
#     'ProfileId': 20},
#    {'Id': 3000010,
#     'Name': 'CVD  - Risk factors for CVD',
#     'Sequence': 7,
#     'ProfileId': 20},
#    {'Id': 2000002, 'Name': 'Diabetes', 'Sequence': 8, 'ProfileId': 20},
#    {'Id': 2000003, 'Name': 'Mental Health', 'Sequence': 9, 'ProfileId': 20},
#    {'Id': 2000009,
#     'Name': 'Musculoskeletal Conditions',
#     'Sequence': 10,
#     'ProfileId': 20},
#    {'Id': 2000006,
#     'Name': 'Respiratory Disease',
#     'Sequence': 11,
#     'ProfileId': 20},
#    {'Id': 1938132970,
#     'Name': 'AMR Local indicators',
#     'Sequence': 12,
#     'ProfileId': 20},
#    {'Id': 2000004,
#     'Name': 'Other Conditions',
#     'Sequence': 13,
#     'ProfileId': 20}]},
#  {'Id': 21,
#   'Name': 'National General Practice Profiles (supporting indicators)',
#   'Key': 'practice-profiles-supporting-indicators',
#   'GroupIds': [1200006],
#   'GroupMetadata': [{'Id': 1200006,
#     'Name': 'National GP Profiles - Supporting Indicators',
#     'Sequence': 1,
#     'ProfileId': 21}]},
#  {'Id': 26,
#   'Name': 'Local Authority Health Profiles',
#   'Key': 'health-profiles',
#   'GroupIds': [1938132696,
#    1938132695,
#    1938132694,
#    8000073,
#    1938133217,
#    3007000,
#    1938133216,
#    1938132701,
#    1938132974],
#   'GroupMetadata': [{'Id': 1938132696,
#     'Name': 'Life expectancy and causes of death',
#     'Sequence': 1,
#     'ProfileId': 26},
#    {'Id': 1938132695,
#     'Name': 'Injuries and ill health',
#     'Sequence': 2,
#     'ProfileId': 26},
#    {'Id': 1938132694,
#     'Name': 'Behavioural risk factors',
#     'Sequence': 3,
#     'ProfileId': 26},
#    {'Id': 8000073, 'Name': 'Child health', 'Sequence': 4, 'ProfileId': 26},
#    {'Id': 1938133217, 'Name': 'Inequalities', 'Sequence': 5, 'ProfileId': 26},
#    {'Id': 3007000,
#     'Name': 'Wider determinants of health',
#     'Sequence': 6,
#     'ProfileId': 26},
#    {'Id': 1938133216,
#     'Name': 'Health protection',
#     'Sequence': 7,
#     'ProfileId': 26},
#    {'Id': 1938132701,
#     'Name': 'All indicators',
#     'Sequence': 8,
#     'ProfileId': 26},
#    {'Id': 1938132974,
#     'Name': 'Supporting information',
#     'Sequence': 9,
#     'ProfileId': 26}]},
#  {'Id': 29,
#   'Name': 'Inhale - INteractive Health Atlas of Lung conditions in England',
#   'Key': 'inhale',
#   'GroupIds': [8000003, 8000005, 8000008, 8000009, 1938133345, 1938133300],
#   'GroupMetadata': [{'Id': 8000003,
#     'Name': 'Key indicators',
#     'Sequence': 1,
#     'ProfileId': 29},
#    {'Id': 8000005, 'Name': 'Risk Factors', 'Sequence': 2, 'ProfileId': 29},
#    {'Id': 8000008, 'Name': 'COPD', 'Sequence': 3, 'ProfileId': 29},
#    {'Id': 8000009, 'Name': 'Asthma', 'Sequence': 4, 'ProfileId': 29},
#    {'Id': 1938133345, 'Name': 'Pneumonia', 'Sequence': 5, 'ProfileId': 29},
#    {'Id': 1938133300, 'Name': 'Other', 'Sequence': 6, 'ProfileId': 29}]},
#  {'Id': 30,
#   'Name': 'Health Protection',
#   'Key': 'health-protection',
#   'GroupIds': [1000002,
#    1938133209,
#    1938132804,
#    1938133210,
#    1938133211,
#    1938133212,
#    1938133214,
#    1938132818],
#   'GroupMetadata': [{'Id': 1000002,
#     'Name': 'All Indicators',
#     'Sequence': 1,
#     'ProfileId': 30},
#    {'Id': 1938133209,
#     'Name': 'Gastrointestinal infection',
#     'Sequence': 2,
#     'ProfileId': 30},
#    {'Id': 1938132804,
#     'Name': 'Immunisation & childhood vaccine preventable diseases',
#     'Sequence': 3,
#     'ProfileId': 30},
#    {'Id': 1938133210,
#     'Name': 'Respiratory infection',
#     'Sequence': 4,
#     'ProfileId': 30},
#    {'Id': 1938133211, 'Name': 'Hepatitis', 'Sequence': 5, 'ProfileId': 30},
#    {'Id': 1938133212,
#     'Name': 'Sexually transmitted infections & HIV',
#     'Sequence': 6,
#     'ProfileId': 30},
#    {'Id': 1938133214,
#     'Name': 'Health care associated infection',
#     'Sequence': 7,
#     'ProfileId': 30},
#    {'Id': 1938132818,
#     'Name': 'Non-infectious environmental hazards',
#     'Sequence': 8,
#     'ProfileId': 30}]},
#  {'Id': 32,
#   'Name': 'NCMP and Child Obesity Profile',
#   'Key': 'national-child-measurement-programme',
#   'GroupIds': [8000011, 8000022, 1938133288, 1938133219],
#   'GroupMetadata': [{'Id': 8000011,
#     'Name': 'NCMP prevalence data',
#     'Sequence': 1,
#     'ProfileId': 32},
#    {'Id': 8000022,
#     'Name': 'NCMP data quality',
#     'Sequence': 2,
#     'ProfileId': 32},
#    {'Id': 1938133288,
#     'Name': 'NCMP small area data',
#     'Sequence': 3,
#     'ProfileId': 32},
#    {'Id': 1938133219,
#     'Name': 'Contextual indicators',
#     'Sequence': 4,
#     'ProfileId': 32}]},
#  {'Id': 36,
#   'Name': 'Mental Health, Dementia and Neurology',
#   'Key': 'mental-health',
#   'GroupIds': [8000017],
#   'GroupMetadata': [{'Id': 8000017,
#     'Name': 'Mental health Dementia and Neurology',
#     'Sequence': 1,
#     'ProfileId': 36}]},
#  {'Id': 37,
#   'Name': 'Modelled Prevalence Estimates',
#   'Key': 'prevalence',
#   'GroupIds': [1938133099, 8000020],
#   'GroupMetadata': [{'Id': 1938133099,
#     'Name': 'Modelled estimates',
#     'Sequence': 1,
#     'ProfileId': 37},
#    {'Id': 8000020,
#     'Name': 'Historic modelled estimates',
#     'Sequence': 2,
#     'ProfileId': 37}]},
#  {'Id': 40,
#   'Name': 'Common Mental Health Disorders',
#   'Key': 'common-mental-disorders',
#   'GroupIds': [1938132720,
#    8000041,
#    8000026,
#    8000042,
#    8000043,
#    1938132954,
#    1938132955,
#    1938133302],
#   'GroupMetadata': [{'Id': 1938132720,
#     'Name': 'CMHD pathway',
#     'Sequence': 1,
#     'ProfileId': 40},
#    {'Id': 8000041,
#     'Name': 'Risk and related factors',
#     'Sequence': 2,
#     'ProfileId': 40},
#    {'Id': 8000026, 'Name': 'Prevalence', 'Sequence': 3, 'ProfileId': 40},
#    {'Id': 8000042, 'Name': 'Services', 'Sequence': 4, 'ProfileId': 40},
#    {'Id': 8000043,
#     'Name': 'Quality and Outcomes',
#     'Sequence': 5,
#     'ProfileId': 40},
#    {'Id': 1938132954,
#     'Name': 'Outcomes by problem descriptor',
#     'Sequence': 6,
#     'ProfileId': 40},
#    {'Id': 1938132955,
#     'Name': 'Availability of therapy type',
#     'Sequence': 7,
#     'ProfileId': 40},
#    {'Id': 1938133302,
#     'Name': 'Exploring Inequality',
#     'Sequence': 8,
#     'ProfileId': 40}]},
#  {'Id': 41,
#   'Name': 'Severe Mental Illness',
#   'Key': 'severe-mental-illness',
#   'GroupIds': [1938132719, 8000027, 8000030, 8000031, 8000039],
#   'GroupMetadata': [{'Id': 1938132719,
#     'Name': 'Psychosis Pathway ',
#     'Sequence': 1,
#     'ProfileId': 41},
#    {'Id': 8000027,
#     'Name': 'Risk and related factors',
#     'Sequence': 2,
#     'ProfileId': 41},
#    {'Id': 8000030, 'Name': 'Prevalence ', 'Sequence': 3, 'ProfileId': 41},
#    {'Id': 8000031, 'Name': 'Services', 'Sequence': 4, 'ProfileId': 41},
#    {'Id': 8000039,
#     'Name': 'Quality and outcomes',
#     'Sequence': 5,
#     'ProfileId': 41}]},
#  {'Id': 45,
#   'Name': 'Sexual and Reproductive Health Profiles',
#   'Key': 'sexualhealth',
#   'GroupIds': [8000057,
#    8000035,
#    1938133286,
#    8000059,
#    8000036,
#    8000037,
#    8000058],
#   'GroupMetadata': [{'Id': 8000057,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 45},
#    {'Id': 8000035, 'Name': 'STI', 'Sequence': 2, 'ProfileId': 45},
#    {'Id': 1938133286, 'Name': 'HIV', 'Sequence': 3, 'ProfileId': 45},
#    {'Id': 8000059,
#     'Name': 'Reproductive Health',
#     'Sequence': 4,
#     'ProfileId': 45},
#    {'Id': 8000036,
#     'Name': 'Teenage Pregnancy',
#     'Sequence': 5,
#     'ProfileId': 45},
#    {'Id': 8000037,
#     'Name': 'Wider Determinants of Health',
#     'Sequence': 6,
#     'ProfileId': 45},
#    {'Id': 8000058, 'Name': 'All Indicators', 'Sequence': 7, 'ProfileId': 45}]},
#  {'Id': 46,
#   'Name': 'Atlas of Variation',
#   'Key': 'atlas-of-variation',
#   'GroupIds': [8000038],
#   'GroupMetadata': [{'Id': 8000038,
#     'Name': 'Atlas of variation',
#     'Sequence': 1,
#     'ProfileId': 46}]},
#  {'Id': 52,
#   'Name': 'Local Authority Health Profiles Supporting Indicators',
#   'Key': 'health-profiles-supporting',
#   'GroupIds': [8000060],
#   'GroupMetadata': [{'Id': 8000060,
#     'Name': 'Health Profiles Supporting Indicators',
#     'Sequence': 1,
#     'ProfileId': 52}]},
#  {'Id': 55,
#   'Name': 'Liver Disease Profiles',
#   'Key': 'liver-disease',
#   'GroupIds': [8000063],
#   'GroupMetadata': [{'Id': 8000063,
#     'Name': 'Liver Disease',
#     'Sequence': 1,
#     'ProfileId': 55}]},
#  {'Id': 58,
#   'Name': 'Learning Disability Profiles',
#   'Key': 'learning-disabilities',
#   'GroupIds': [1938132702, 1938132703, 1938132704, 1938132705],
#   'GroupMetadata': [{'Id': 1938132702,
#     'Name': 'Population',
#     'Sequence': 1,
#     'ProfileId': 58},
#    {'Id': 1938132703, 'Name': 'Health', 'Sequence': 2, 'ProfileId': 58},
#    {'Id': 1938132704,
#     'Name': 'Accommodation and social care',
#     'Sequence': 3,
#     'ProfileId': 58},
#    {'Id': 1938132705,
#     'Name': 'Coordination and local planning',
#     'Sequence': 4,
#     'ProfileId': 58}]},
#  {'Id': 65,
#   'Name': 'NHS Health Check',
#   'Key': 'nhs-health-check-detailed',
#   'GroupIds': [1938132726, 1938132768, 1938132770, 1938132767],
#   'GroupMetadata': [{'Id': 1938132726,
#     'Name': 'Health Check',
#     'Sequence': 1,
#     'ProfileId': 65},
#    {'Id': 1938132768, 'Name': 'Risk factors', 'Sequence': 2, 'ProfileId': 65},
#    {'Id': 1938132770,
#     'Name': 'Disease and death',
#     'Sequence': 3,
#     'ProfileId': 65},
#    {'Id': 1938132767,
#     'Name': 'Supporting Data',
#     'Sequence': 4,
#     'ProfileId': 65}]},
#  {'Id': 76,
#   'Name': 'Musculoskeletal Conditions',
#   'Key': 'msk',
#   'GroupIds': [1938133186,
#    1938133152,
#    1938133151,
#    1938133218,
#    1938132773,
#    1938133148,
#    1938133149,
#    1938133150],
#   'GroupMetadata': [{'Id': 1938133186,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 76},
#    {'Id': 1938133152, 'Name': 'Risk factors', 'Sequence': 2, 'ProfileId': 76},
#    {'Id': 1938133151,
#     'Name': 'Physical activity',
#     'Sequence': 3,
#     'ProfileId': 76},
#    {'Id': 1938133218,
#     'Name': 'MSK and comorbidity',
#     'Sequence': 4,
#     'ProfileId': 76},
#    {'Id': 1938132773, 'Name': 'Back pain', 'Sequence': 5, 'ProfileId': 76},
#    {'Id': 1938133148,
#     'Name': 'Osteoarthritis',
#     'Sequence': 6,
#     'ProfileId': 76},
#    {'Id': 1938133149,
#     'Name': 'Osteoporosis and fragility fracture',
#     'Sequence': 7,
#     'ProfileId': 76},
#    {'Id': 1938133150,
#     'Name': 'Rheumatoid arthritis',
#     'Sequence': 8,
#     'ProfileId': 76}]},
#  {'Id': 79,
#   'Name': 'Co-occurring substance misuse and mental health issues',
#   'Key': 'drugsandmentalhealth',
#   'GroupIds': [1938132935,
#    1938132790,
#    1938132791,
#    1938132792,
#    1938132936,
#    1938133084],
#   'GroupMetadata': [{'Id': 1938132935,
#     'Name': 'Risk and related factors',
#     'Sequence': 1,
#     'ProfileId': 79},
#    {'Id': 1938132790,
#     'Name': 'Alcohol, drugs and tobacco - prevalence',
#     'Sequence': 2,
#     'ProfileId': 79},
#    {'Id': 1938132791,
#     'Name': 'Alcohol, drugs and tobacco - treatment demand',
#     'Sequence': 3,
#     'ProfileId': 79},
#    {'Id': 1938132792,
#     'Name': 'Alcohol, drugs and tobacco - treatment response',
#     'Sequence': 4,
#     'ProfileId': 79},
#    {'Id': 1938132936,
#     'Name': 'Mental health prevalence and services',
#     'Sequence': 5,
#     'ProfileId': 79},
#    {'Id': 1938133084,
#     'Name': 'Mortality indicators',
#     'Sequence': 6,
#     'ProfileId': 79}]},
#  {'Id': 84,
#   'Name': 'Dementia Profile',
#   'Key': 'dementia',
#   'GroupIds': [1938133052,
#    1938132811,
#    1938132859,
#    1938132891,
#    1938132897,
#    1938132893,
#    1938132894],
#   'GroupMetadata': [{'Id': 1938133052,
#     'Name': 'Pathway on a Page',
#     'Sequence': 1,
#     'ProfileId': 84},
#    {'Id': 1938132811, 'Name': 'Prevalence', 'Sequence': 2, 'ProfileId': 84},
#    {'Id': 1938132859,
#     'Name': 'Preventing well',
#     'Sequence': 3,
#     'ProfileId': 84},
#    {'Id': 1938132891,
#     'Name': 'Diagnosing well',
#     'Sequence': 4,
#     'ProfileId': 84},
#    {'Id': 1938132897, 'Name': 'Living well', 'Sequence': 5, 'ProfileId': 84},
#    {'Id': 1938132893,
#     'Name': 'Supporting well',
#     'Sequence': 6,
#     'ProfileId': 84},
#    {'Id': 1938132894, 'Name': 'Dying well', 'Sequence': 7, 'ProfileId': 84}]},
#  {'Id': 86,
#   'Name': 'TB Strategy Monitoring Indicators',
#   'Key': 'tb-monitoring',
#   'GroupIds': [1938132814],
#   'GroupMetadata': [{'Id': 1938132814,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 86}]},
#  {'Id': 87,
#   'Name': 'Local Alcohol Profiles for England',
#   'Key': 'local-alcohol-profiles',
#   'GroupIds': [1938132984,
#    1938132832,
#    1938132833,
#    1938132982,
#    1938132848,
#    1938132835,
#    1938132895,
#    1938133118],
#   'GroupMetadata': [{'Id': 1938132984,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 87},
#    {'Id': 1938132832, 'Name': 'Mortality', 'Sequence': 2, 'ProfileId': 87},
#    {'Id': 1938132833,
#     'Name': 'Hospital Admissions',
#     'Sequence': 3,
#     'ProfileId': 87},
#    {'Id': 1938132982,
#     'Name': 'Hospital Admissions By Age-Group',
#     'Sequence': 4,
#     'ProfileId': 87},
#    {'Id': 1938132848,
#     'Name': 'Alcohol-Related Conditions',
#     'Sequence': 5,
#     'ProfileId': 87},
#    {'Id': 1938132835, 'Name': 'Other Impacts', 'Sequence': 6, 'ProfileId': 87},
#    {'Id': 1938132895, 'Name': 'Treatment', 'Sequence': 7, 'ProfileId': 87},
#    {'Id': 1938133118,
#     'Name': 'Consumption and Availability',
#     'Sequence': 8,
#     'ProfileId': 87}]},
#  {'Id': 91,
#   'Name': 'Suicide Prevention Profile',
#   'Key': 'suicide',
#   'GroupIds': [1938132828, 1938132831, 1938132834],
#   'GroupMetadata': [{'Id': 1938132828,
#     'Name': 'Suicide data',
#     'Sequence': 1,
#     'ProfileId': 91},
#    {'Id': 1938132831,
#     'Name': 'Related risk factors',
#     'Sequence': 2,
#     'ProfileId': 91},
#    {'Id': 1938132834,
#     'Name': 'Related service contacts',
#     'Sequence': 3,
#     'ProfileId': 91}]},
#  {'Id': 92,
#   'Name': 'Cancer Services',
#   'Key': 'cancerservices',
#   'GroupIds': [1938133365, 1938132830, 1938133085],
#   'GroupMetadata': [{'Id': 1938133365,
#     'Name': 'Summary of key indicators',
#     'Sequence': 1,
#     'ProfileId': 92},
#    {'Id': 1938132830,
#     'Name': 'Demographics, Screening and Diagnostics',
#     'Sequence': 2,
#     'ProfileId': 92},
#    {'Id': 1938133085,
#     'Name': 'Two-Week Wait Referrals',
#     'Sequence': 3,
#     'ProfileId': 92}]},
#  {'Id': 95,
#   'Name': 'Palliative and End of Life Care Profiles',
#   'Key': 'end-of-life',
#   'GroupIds': [1938132883,
#    1938132902,
#    1938132882,
#    1938132901,
#    1938133060,
#    1938133338,
#    1938132951,
#    1938132916],
#   'GroupMetadata': [{'Id': 1938132883,
#     'Name': 'Place of Death',
#     'Sequence': 1,
#     'ProfileId': 95},
#    {'Id': 1938132902,
#     'Name': 'Death in Usual Place of Residence (DiUPR)',
#     'Sequence': 2,
#     'ProfileId': 95},
#    {'Id': 1938132882,
#     'Name': 'Underlying Cause of Death',
#     'Sequence': 3,
#     'ProfileId': 95},
#    {'Id': 1938132901, 'Name': 'Mortality ', 'Sequence': 4, 'ProfileId': 95},
#    {'Id': 1938133060,
#     'Name': 'Care Homes and Community',
#     'Sequence': 5,
#     'ProfileId': 95},
#    {'Id': 1938133338, 'Name': 'Hospital Care', 'Sequence': 6, 'ProfileId': 95},
#    {'Id': 1938132951, 'Name': 'Dementia', 'Sequence': 7, 'ProfileId': 95},
#    {'Id': 1938132916,
#     'Name': 'Relevant Indicators from Other Profiles',
#     'Sequence': 8,
#     'ProfileId': 95}]},
#  {'Id': 98,
#   'Name': 'Mental Health and Wellbeing JSNA',
#   'Key': 'mh-jsna',
#   'GroupIds': [1938132922, 1938132920, 1938132921, 1938132923, 1938132924],
#   'GroupMetadata': [{'Id': 1938132922,
#     'Name': 'Prevalence & Incidence',
#     'Sequence': 1,
#     'ProfileId': 98},
#    {'Id': 1938132920, 'Name': 'Risk factors', 'Sequence': 2, 'ProfileId': 98},
#    {'Id': 1938132921,
#     'Name': 'Protective factors',
#     'Sequence': 3,
#     'ProfileId': 98},
#    {'Id': 1938132923, 'Name': 'Services', 'Sequence': 4, 'ProfileId': 98},
#    {'Id': 1938132924,
#     'Name': 'Quality & Outcomes',
#     'Sequence': 5,
#     'ProfileId': 98}]},
#  {'Id': 99,
#   'Name': 'Physical Activity',
#   'Key': 'physical-activity',
#   'GroupIds': [1938132899, 1938133001, 1938133004],
#   'GroupMetadata': [{'Id': 1938132899,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 99},
#    {'Id': 1938133001,
#     'Name': 'Related conditions',
#     'Sequence': 2,
#     'ProfileId': 99},
#    {'Id': 1938133004,
#     'Name': 'Supporting information',
#     'Sequence': 3,
#     'ProfileId': 99}]},
#  {'Id': 100,
#   'Name': 'Wider Impacts of COVID-19 on Health',
#   'Key': 'covid19',
#   'GroupIds': [1938133359, 1938133360, 1938133361, 1938133363, 1938133364],
#   'GroupMetadata': [{'Id': 1938133359,
#     'Name': 'Impact on mortality',
#     'Sequence': 1,
#     'ProfileId': 100},
#    {'Id': 1938133360,
#     'Name': 'Disruption to healthcare',
#     'Sequence': 2,
#     'ProfileId': 100},
#    {'Id': 1938133361,
#     'Name': 'Reduction in prevention, detection and management of conditions',
#     'Sequence': 3,
#     'ProfileId': 100},
#    {'Id': 1938133363,
#     'Name': 'Wider societal and economic impacts that affect health',
#     'Sequence': 4,
#     'ProfileId': 100},
#    {'Id': 1938133364,
#     'Name': 'Wellbeing and behavioural risk factors',
#     'Sequence': 5,
#     'ProfileId': 100}]},
#  {'Id': 101,
#   'Name': 'AMR local indicators',
#   'Key': 'amr-local-indicators',
#   'GroupIds': [1938133070,
#    1938132908,
#    1938132909,
#    1938132910,
#    1938132917,
#    1938132929,
#    1938132967,
#    1938132968],
#   'GroupMetadata': [{'Id': 1938133070,
#     'Name': 'Supporting NHS England Initiatives',
#     'Sequence': 1,
#     'ProfileId': 101},
#    {'Id': 1938132908,
#     'Name': 'Antimicrobial Resistance',
#     'Sequence': 2,
#     'ProfileId': 101},
#    {'Id': 1938132909,
#     'Name': 'Antibiotic Prescribing',
#     'Sequence': 3,
#     'ProfileId': 101},
#    {'Id': 1938132910,
#     'Name': 'Health Care Associated Infection',
#     'Sequence': 4,
#     'ProfileId': 101},
#    {'Id': 1938132917,
#     'Name': 'Infection Prevention and Control',
#     'Sequence': 5,
#     'ProfileId': 101},
#    {'Id': 1938132929,
#     'Name': 'Antimicrobial Stewardship',
#     'Sequence': 6,
#     'ProfileId': 101},
#    {'Id': 1938132967, 'Name': 'All Trust ', 'Sequence': 7, 'ProfileId': 101},
#    {'Id': 1938132968,
#     'Name': 'All Clinical Commissioning Group',
#     'Sequence': 8,
#     'ProfileId': 101}]},
#  {'Id': 102,
#   'Name': 'Perinatal Mental Health',
#   'Key': 'perinatal-mental-health',
#   'GroupIds': [1938132960, 1938132915, 1938132957, 1938132975],
#   'GroupMetadata': [{'Id': 1938132960,
#     'Name': 'Demographics',
#     'Sequence': 1,
#     'ProfileId': 102},
#    {'Id': 1938132915,
#     'Name': 'Risk & related factors',
#     'Sequence': 2,
#     'ProfileId': 102},
#    {'Id': 1938132957, 'Name': 'Prevalence', 'Sequence': 3, 'ProfileId': 102},
#    {'Id': 1938132975,
#     'Name': 'Identification & Access',
#     'Sequence': 4,
#     'ProfileId': 102}]},
#  {'Id': 103,
#   'Name': 'INLIQ test profile',
#   'Key': 'inliq',
#   'GroupIds': [1938133101],
#   'GroupMetadata': [{'Id': 1938133101,
#     'Name': 'INLIQ',
#     'Sequence': 1,
#     'ProfileId': 103}]},
#  {'Id': 105,
#   'Name': 'Child and Maternal Health',
#   'Key': 'child-health-profiles',
#   'GroupIds': [1938133228,
#    1938133222,
#    1938133223,
#    1938133257,
#    1938133224,
#    1938133258,
#    1938133259,
#    1938133260,
#    1938133225,
#    1938133261,
#    1938133226,
#    1938133229,
#    1938133230,
#    1938133231,
#    1938133232,
#    1938133263,
#    1938133236,
#    1938133237,
#    1938133238],
#   'GroupMetadata': [{'Id': 1938133228,
#     'Name': 'Child Health Profiles',
#     'Sequence': 1,
#     'ProfileId': 105},
#    {'Id': 1938133222,
#     'Name': 'Pregnancy and birth',
#     'Sequence': 2,
#     'ProfileId': 105},
#    {'Id': 1938133223, 'Name': 'Early years', 'Sequence': 3, 'ProfileId': 105},
#    {'Id': 1938133257,
#     'Name': 'Early years supplementary indicators',
#     'Sequence': 4,
#     'ProfileId': 105},
#    {'Id': 1938133224,
#     'Name': 'School-age children',
#     'Sequence': 5,
#     'ProfileId': 105},
#    {'Id': 1938133258,
#     'Name': 'School-age children: Primary',
#     'Sequence': 6,
#     'ProfileId': 105},
#    {'Id': 1938133259,
#     'Name': 'School-age children: Secondary',
#     'Sequence': 7,
#     'ProfileId': 105},
#    {'Id': 1938133260,
#     'Name': 'School-age children supplementary indicators',
#     'Sequence': 8,
#     'ProfileId': 105},
#    {'Id': 1938133225, 'Name': 'Young people', 'Sequence': 9, 'ProfileId': 105},
#    {'Id': 1938133261,
#     'Name': 'Young people supplementary indicators',
#     'Sequence': 10,
#     'ProfileId': 105},
#    {'Id': 1938133226,
#     'Name': 'Breastfeeding',
#     'Sequence': 11,
#     'ProfileId': 105},
#    {'Id': 1938133229,
#     'Name': 'Health behaviours in 15 year olds',
#     'Sequence': 12,
#     'ProfileId': 105},
#    {'Id': 1938133230,
#     'Name': 'Healthcare use',
#     'Sequence': 13,
#     'ProfileId': 105},
#    {'Id': 1938133231,
#     'Name': 'Long term conditions and complex health needs',
#     'Sequence': 14,
#     'ProfileId': 105},
#    {'Id': 1938133232, 'Name': 'Mortality', 'Sequence': 15, 'ProfileId': 105},
#    {'Id': 1938133263, 'Name': 'Oral health', 'Sequence': 16, 'ProfileId': 105},
#    {'Id': 1938133236,
#     'Name': 'Unintentional injuries',
#     'Sequence': 17,
#     'ProfileId': 105},
#    {'Id': 1938133237,
#     'Name': 'Vaccines and immunisations',
#     'Sequence': 18,
#     'ProfileId': 105},
#    {'Id': 1938133238,
#     'Name': 'Vulnerable children and young people',
#     'Sequence': 19,
#     'ProfileId': 105}]},
#  {'Id': 106,
#   'Name': 'Crisis Care Profile',
#   'Key': 'crisis-care',
#   'GroupIds': [1938132962,
#    1938133121,
#    1938132963,
#    1938132964,
#    1938132965,
#    1938132966],
#   'GroupMetadata': [{'Id': 1938132962,
#     'Name': 'Risk factors developing MH Crisis',
#     'Sequence': 1,
#     'ProfileId': 106},
#    {'Id': 1938133121,
#     'Name': 'Pre-existing MH Condition',
#     'Sequence': 2,
#     'ProfileId': 106},
#    {'Id': 1938132963,
#     'Name': 'Access to support',
#     'Sequence': 3,
#     'ProfileId': 106},
#    {'Id': 1938132964,
#     'Name': 'Urgent and emergency care',
#     'Sequence': 4,
#     'ProfileId': 106},
#    {'Id': 1938132965,
#     'Name': 'Quality of treatment',
#     'Sequence': 5,
#     'ProfileId': 106},
#    {'Id': 1938132966,
#     'Name': 'Recovery and staying well',
#     'Sequence': 6,
#     'ProfileId': 106}]},
#  {'Id': 109,
#   'Name': 'Marmot Indicators for Local Authorities',
#   'Key': 'marmot-indicators',
#   'GroupIds': [1938132973],
#   'GroupMetadata': [{'Id': 1938132973,
#     'Name': 'Marmot',
#     'Sequence': 1,
#     'ProfileId': 109}]},
#  {'Id': 110,
#   'Name': 'Healthy life expectancy and life expectancy around the 2011 Census: Marmot Indicators',
#   'Key': 'marmot-healthy-life-expectancy',
#   'GroupIds': [1938132980],
#   'GroupMetadata': [{'Id': 1938132980,
#     'Name': 'Marmot',
#     'Sequence': 1,
#     'ProfileId': 110}]},
#  {'Id': 111,
#   'Name': 'Marmot Indicators',
#   'Key': 'marmot',
#   'GroupIds': [1938132981],
#   'GroupMetadata': [{'Id': 1938132981,
#     'Name': 'Marmot Indicators',
#     'Sequence': 1,
#     'ProfileId': 111}]},
#  {'Id': 125,
#   'Name': 'Mortality Profile',
#   'Key': 'mortality-profile',
#   'GroupIds': [1938133009, 1938133056, 1938133058],
#   'GroupMetadata': [{'Id': 1938133009,
#     'Name': 'Premature Mortality',
#     'Sequence': 1,
#     'ProfileId': 125},
#    {'Id': 1938133056,
#     'Name': 'Preventable Mortality',
#     'Sequence': 2,
#     'ProfileId': 125},
#    {'Id': 1938133058,
#     'Name': 'Other Mortality',
#     'Sequence': 3,
#     'ProfileId': 125}]},
#  {'Id': 130,
#   'Name': 'Wider Determinants of Health',
#   'Key': 'wider-determinants',
#   'GroupIds': [1938133043,
#    1938133042,
#    1938133044,
#    1938133045,
#    1938133073,
#    1938133071,
#    1938133119,
#    1938133080,
#    1938133262],
#   'GroupMetadata': [{'Id': 1938133043,
#     'Name': 'Natural and built environment',
#     'Sequence': 1,
#     'ProfileId': 130},
#    {'Id': 1938133042,
#     'Name': 'Work and the labour market',
#     'Sequence': 2,
#     'ProfileId': 130},
#    {'Id': 1938133044,
#     'Name': 'Vulnerability',
#     'Sequence': 3,
#     'ProfileId': 130},
#    {'Id': 1938133045, 'Name': 'Income', 'Sequence': 4, 'ProfileId': 130},
#    {'Id': 1938133073, 'Name': 'Crime', 'Sequence': 5, 'ProfileId': 130},
#    {'Id': 1938133071, 'Name': 'Education', 'Sequence': 6, 'ProfileId': 130},
#    {'Id': 1938133119,
#     'Name': 'Marmot indicators',
#     'Sequence': 7,
#     'ProfileId': 130},
#    {'Id': 1938133080,
#     'Name': 'Health outcomes',
#     'Sequence': 8,
#     'ProfileId': 130},
#    {'Id': 1938133262,
#     'Name': 'Health assets',
#     'Sequence': 9,
#     'ProfileId': 130}]},
#  {'Id': 132,
#   'Name': 'Populations',
#   'Key': 'populations',
#   'GroupIds': [1938133081],
#   'GroupMetadata': [{'Id': 1938133081,
#     'Name': 'Populations',
#     'Sequence': 1,
#     'ProfileId': 132}]},
#  {'Id': 133,
#   'Name': "Children and Young People's Mental Health and Wellbeing",
#   'Key': 'cypmh',
#   'GroupIds': [1938133090,
#    1938133089,
#    1938133095,
#    1938133096,
#    1938133094,
#    1938133292],
#   'GroupMetadata': [{'Id': 1938133090,
#     'Name': 'Identification of need',
#     'Sequence': 1,
#     'ProfileId': 133},
#    {'Id': 1938133089,
#     'Name': 'Protective factors',
#     'Sequence': 2,
#     'ProfileId': 133},
#    {'Id': 1938133095,
#     'Name': 'Primary prevention: Adversity',
#     'Sequence': 3,
#     'ProfileId': 133},
#    {'Id': 1938133096,
#     'Name': 'Primary prevention: Vulnerability',
#     'Sequence': 4,
#     'ProfileId': 133},
#    {'Id': 1938133094, 'Name': 'Finance', 'Sequence': 5, 'ProfileId': 133},
#    {'Id': 1938133292, 'Name': 'Services', 'Sequence': 6, 'ProfileId': 133}]},
#  {'Id': 135,
#   'Name': 'Cardiovascular Disease',
#   'Key': 'cardiovascular',
#   'GroupIds': [1938133106, 1938133107, 1938133108, 1938133109, 1938133110],
#   'GroupMetadata': [{'Id': 1938133106,
#     'Name': 'Risk Factors',
#     'Sequence': 1,
#     'ProfileId': 135},
#    {'Id': 1938133107, 'Name': 'Diabetes', 'Sequence': 2, 'ProfileId': 135},
#    {'Id': 1938133108, 'Name': 'Heart', 'Sequence': 3, 'ProfileId': 135},
#    {'Id': 1938133109, 'Name': 'Kidney', 'Sequence': 4, 'ProfileId': 135},
#    {'Id': 1938133110, 'Name': 'Stroke', 'Sequence': 5, 'ProfileId': 135}]},
#  {'Id': 137,
#   'Name': 'Technical Guidance',
#   'Key': 'guidance',
#   'GroupIds': [1938133128],
#   'GroupMetadata': [{'Id': 1938133128,
#     'Name': 'guidance',
#     'Sequence': 1,
#     'ProfileId': 137}]},
#  {'Id': 139,
#   'Name': 'Diabetes',
#   'Key': 'diabetes-ft',
#   'GroupIds': [1938133138,
#    1938133136,
#    1938133158,
#    1938133135,
#    1938133137,
#    1938133181],
#   'GroupMetadata': [{'Id': 1938133138,
#     'Name': 'Prevalence and risk',
#     'Sequence': 1,
#     'ProfileId': 139},
#    {'Id': 1938133136,
#     'Name': 'Care processes',
#     'Sequence': 2,
#     'ProfileId': 139},
#    {'Id': 1938133158,
#     'Name': 'Structured education',
#     'Sequence': 3,
#     'ProfileId': 139},
#    {'Id': 1938133135,
#     'Name': 'Treatment targets',
#     'Sequence': 4,
#     'ProfileId': 139},
#    {'Id': 1938133137,
#     'Name': 'Complications',
#     'Sequence': 5,
#     'ProfileId': 139},
#    {'Id': 1938133181,
#     'Name': 'Foot care activity',
#     'Sequence': 6,
#     'ProfileId': 139}]},
#  {'Id': 140,
#   'Name': 'Public Health Dashboard - Longer Lives',
#   'Key': 'public-health-dashboard',
#   'GroupIds': [1938133162,
#    1938133145,
#    1938133161,
#    1938133163,
#    1938133155,
#    1938133144,
#    1938133159,
#    1938133160,
#    1938133221],
#   'GroupMetadata': [{'Id': 1938133162,
#     'Name': 'Summary rank',
#     'Sequence': 1,
#     'ProfileId': 140},
#    {'Id': 1938133145,
#     'Name': 'Child obesity',
#     'Sequence': 2,
#     'ProfileId': 140},
#    {'Id': 1938133161,
#     'Name': 'NHS Health Checks',
#     'Sequence': 3,
#     'ProfileId': 140},
#    {'Id': 1938133163,
#     'Name': 'Tobacco control',
#     'Sequence': 4,
#     'ProfileId': 140},
#    {'Id': 1938133155,
#     'Name': 'Alcohol treatment',
#     'Sequence': 5,
#     'ProfileId': 140},
#    {'Id': 1938133144,
#     'Name': 'Drug treatment',
#     'Sequence': 6,
#     'ProfileId': 140},
#    {'Id': 1938133159,
#     'Name': 'Best start in life',
#     'Sequence': 7,
#     'ProfileId': 140},
#    {'Id': 1938133160,
#     'Name': 'Sexual and reproductive health',
#     'Sequence': 8,
#     'ProfileId': 140},
#    {'Id': 1938133221,
#     'Name': 'Air Quality',
#     'Sequence': 9,
#     'ProfileId': 140}]},
#  {'Id': 141,
#   'Name': 'Public Health Dashboard',
#   'Key': 'public-health-dashboard-ft',
#   'GroupIds': [1938133143,
#    1938133156,
#    1938133197,
#    1938133154,
#    1938133142,
#    1938133198,
#    1938133157,
#    1938133220],
#   'GroupMetadata': [{'Id': 1938133143,
#     'Name': 'Child obesity',
#     'Sequence': 1,
#     'ProfileId': 141},
#    {'Id': 1938133156,
#     'Name': 'NHS Health Checks',
#     'Sequence': 2,
#     'ProfileId': 141},
#    {'Id': 1938133197,
#     'Name': 'Tobacco control',
#     'Sequence': 3,
#     'ProfileId': 141},
#    {'Id': 1938133154,
#     'Name': 'Alcohol treatment',
#     'Sequence': 4,
#     'ProfileId': 141},
#    {'Id': 1938133142,
#     'Name': 'Drug treatment',
#     'Sequence': 5,
#     'ProfileId': 141},
#    {'Id': 1938133198,
#     'Name': 'Best start in life',
#     'Sequence': 6,
#     'ProfileId': 141},
#    {'Id': 1938133157,
#     'Name': 'Sexual and reproductive health',
#     'Sequence': 7,
#     'ProfileId': 141},
#    {'Id': 1938133220,
#     'Name': 'Air Quality',
#     'Sequence': 8,
#     'ProfileId': 141}]},
#  {'Id': 143,
#   'Name': 'Local Health',
#   'Key': 'local-health',
#   'GroupIds': [1938133180, 1938133183, 1938133184, 1938133185],
#   'GroupMetadata': [{'Id': 1938133180,
#     'Name': 'Our community',
#     'Sequence': 1,
#     'ProfileId': 143},
#    {'Id': 1938133183,
#     'Name': 'Behavioural risk factors and child health',
#     'Sequence': 2,
#     'ProfileId': 143},
#    {'Id': 1938133184,
#     'Name': 'Disease and poor health',
#     'Sequence': 3,
#     'ProfileId': 143},
#    {'Id': 1938133185,
#     'Name': 'Life expectancy and causes of death',
#     'Sequence': 4,
#     'ProfileId': 143}]},
#  {'Id': 146,
#   'Name': 'Productive Healthy Ageing Profile',
#   'Key': 'healthy-ageing',
#   'GroupIds': [1938133280, 1938133250, 1938133251, 1938133252, 1938133253],
#   'GroupMetadata': [{'Id': 1938133280,
#     'Name': 'Optimise Health & Reduce Risks Early',
#     'Sequence': 1,
#     'ProfileId': 146},
#    {'Id': 1938133250,
#     'Name': 'Improve Wellbeing & Wider Determinants of Health',
#     'Sequence': 2,
#     'ProfileId': 146},
#    {'Id': 1938133251,
#     'Name': 'Reverse or Live Well with a Long-term Condition',
#     'Sequence': 3,
#     'ProfileId': 146},
#    {'Id': 1938133252,
#     'Name': 'Enhance Care & Support',
#     'Sequence': 4,
#     'ProfileId': 146},
#    {'Id': 1938133253,
#     'Name': 'Demographics & Mortality',
#     'Sequence': 5,
#     'ProfileId': 146}]},
#  {'Id': 147,
#   'Name': 'Cardiovascular Disease, Diabetes and Kidney Disease',
#   'Key': 'cardiovascular-disease-diabetes-kidney-disease',
#   'GroupIds': [1938133264],
#   'GroupMetadata': [{'Id': 1938133264,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 147}]},
#  {'Id': 148,
#   'Name': 'Diabetes Footcare',
#   'Key': 'diabetes-footcare',
#   'GroupIds': [1938133265],
#   'GroupMetadata': [{'Id': 1938133265,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 148}]},
#  {'Id': 150,
#   'Name': 'Cardiovascular Disease Primary Care Intelligence',
#   'Key': 'cardiovascular-disease-primary-care',
#   'GroupIds': [1938133266],
#   'GroupMetadata': [{'Id': 1938133266,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 150}]},
#  {'Id': 152,
#   'Name': 'Public Health Dashboard - Longer Lives (Supporting Indicators)',
#   'Key': 'public-health-dashboard-supporting-indicators',
#   'GroupIds': [1938132706],
#   'GroupMetadata': [{'Id': 1938132706,
#     'Name': 'Values at top of page',
#     'Sequence': 1,
#     'ProfileId': 152}]},
#  {'Id': 154,
#   'Name': 'Inequality Tools',
#   'Key': 'inequality-tools',
#   'GroupIds': [1938133282],
#   'GroupMetadata': [{'Id': 1938133282,
#     'Name': 'Segment Tool',
#     'Sequence': 1,
#     'ProfileId': 154}]},
#  {'Id': 155,
#   'Name': 'SPOT - Spend and Outcomes Tool',
#   'Key': 'spot',
#   'GroupIds': [1938133283, 1938133284, 1938133285, 1938133299],
#   'GroupMetadata': [{'Id': 1938133283,
#     'Name': 'Spend',
#     'Sequence': 1,
#     'ProfileId': 155},
#    {'Id': 1938133284,
#     'Name': 'Outcomes - SPOT only',
#     'Sequence': 2,
#     'ProfileId': 155},
#    {'Id': 1938133285,
#     'Name': 'Outcomes - PHOLIO 1',
#     'Sequence': 3,
#     'ProfileId': 155},
#    {'Id': 1938133299,
#     'Name': 'Outcomes - PHOLIO 2',
#     'Sequence': 4,
#     'ProfileId': 155}]},
#  {'Id': 156,
#   'Name': 'Development Profile for Testing fingertipsR',
#   'Key': 'development-profile-for-testing-fingertipsr',
#   'GroupIds': [1938133293, 1938133294, 1938133301],
#   'GroupMetadata': [{'Id': 1938133293,
#     'Name': 'Domain 1',
#     'Sequence': 1,
#     'ProfileId': 156},
#    {'Id': 1938133294, 'Name': 'Domain 2', 'Sequence': 2, 'ProfileId': 156},
#    {'Id': 1938133301, 'Name': 'Domain 3', 'Sequence': 3, 'ProfileId': 156}]},
#  {'Id': 161,
#   'Name': 'Cardiovascular Disease Prevention',
#   'Key': 'cardiovascular-disease-prevention',
#   'GroupIds': [1938133344],
#   'GroupMetadata': [{'Id': 1938133344,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 161}]}]

# %%
area_type_id_dict = ftp.metadata.get_area_type_ids_for_profile(20)
area_type_id_dict
# Out:
# [7, 154, 165, 166, 204, 220]

# %%
ftp.metadata.get_area_types_as_dict()
# Out:
# [{'Id': 1,
#   'Name': 'Local Authority District',
#   'Short': 'LA',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 2,
#   'Name': 'Primary Care Trust',
#   'Short': 'Primary Care Trust',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 3,
#   'Name': 'Middle Super Output Area',
#   'Short': 'MSOA',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 4,
#   'Name': 'Lower Super Output Area',
#   'Short': 'LSOA',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 5,
#   'Name': 'Strategic Health Authority',
#   'Short': 'SHA',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 6,
#   'Name': 'Government Office Region',
#   'Short': 'Region',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 7,
#   'Name': 'General Practice',
#   'Short': 'GP',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 8,
#   'Name': 'Ward',
#   'Short': 'Ward',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 9,
#   'Name': 'County ',
#   'Short': 'County',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 14,
#   'Name': 'Acute Trust',
#   'Short': 'Acute Trust',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 15,
#   'Name': 'England',
#   'Short': 'England',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 16,
#   'Name': 'Unitary Authority',
#   'Short': 'UA',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 18,
#   'Name': 'GP classification by shapes from YHPHO',
#   'Short': 'GP Shape Classification',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 20,
#   'Name': 'Mental Health Trust',
#   'Short': 'Mental Health Trust',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 21,
#   'Name': 'Rurality (based on popDensity of PCarea,01 census)',
#   'Short': 'GP rurality',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 22,
#   'Name': 'SHA Cluster (from 2011/12)',
#   'Short': 'SHA Cluster',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 40,
#   'Name': 'Care Trust',
#   'Short': 'Care Trust',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 41,
#   'Name': 'Ambulance Trust',
#   'Short': 'Ambulance Trust',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 42,
#   'Name': '2013 PHE Regions (4)',
#   'Short': 'PHE Region ',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 43,
#   'Name': '2013 PHE Centres (15)',
#   'Short': 'PHE Centre',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 44,
#   'Name': 'E40, former commissioning regions',
#   'Short': 'NHS region',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 46,
#   'Name': 'E39, former sub-region, former Local area teams)',
#   'Short': 'NHS region - local office',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 47,
#   'Name': 'Local commissioning group',
#   'Short': 'LCG',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 48,
#   'Name': 'PHE Centres, not continued from 2015 onwards (11)',
#   'Short': 'PHE Centre 2013-2015',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 49,
#   'Name': 'PHE Centres, new 2015 (5)',
#   'Short': 'PHE Centre from 2015',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 50,
#   'Name': 'PHE Centres 2013, unchanged (4)',
#   'Short': 'PHE Centre from 2013',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 51,
#   'Name': 'CCG unchanged (April 2017)',
#   'Short': 'CCG unchanged 17',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 52,
#   'Name': 'CCG introduced April 2017 (exc. Morecambe Bay old code and Norfolk (4/20))',
#   'Short': 'CCG new 4/17, remaining 4/20',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 53,
#   'Name': 'CCG superseded April 2017',
#   'Short': 'CCG old 17',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 54,
#   'Name': 'CCG introduced April 2018',
#   'Short': 'CCG new 18',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 55,
#   'Name': 'CCG superseded April 2018',
#   'Short': 'CCGs old 2018',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 56,
#   'Name': 'CCG still unchanged April 2020',
#   'Short': 'CCGs unchanged 2020',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 57,
#   'Name': 'CCG new 4/17 obsolete 4/18 (Morecambe Bay old code)',
#   'Short': 'CCG new 4/17 obsolete 4/18',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 58,
#   'Name': 'CCGs introduced April 2019',
#   'Short': 'CCGs new 4/2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 59,
#   'Name': 'CCGs sup',
#   'Short': 'CCGs old 2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 60,
#   'Name': 'CCGs introduced April 2020',
#   'Short': 'CCGs new 2020',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 61,
#   'Name': 'CCGs new 4/17, superseded 4/20 (split off from 52)',
#   'Short': 'CCGs new 4/17, superseded 4/20',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 62,
#   'Name': 'CCGs superseded 4/20 (split off from 56)',
#   'Short': 'CCGs superseded 4/20',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 101,
#   'Name': 'Lower tier local authorities (pre 4/19)',
#   'Short': 'District & UA (pre 4/19)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 102,
#   'Name': 'Upper tier local authorities (pre 4/19)',
#   'Short': 'County & UA (pre 4/19)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 103,
#   'Name': 'PHEC 2013 only plus PHEC unchanged',
#   'Short': 'PHE Centres (2013)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 104,
#   'Name': 'PHEC 2015 new plus PHEC 2013 unchanged',
#   'Short': 'PHE Centres (2015)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 105,
#   'Name': 'Dummy SHA e.g. add Milton Keynes to East Mids',
#   'Short': 'Dummy SHA',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 106,
#   'Name': 'Dummy region e.g. add Milton Keynes to East Mids',
#   'Short': 'Dummy region',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 109,
#   'Name': 'ONS statistical neighbour cluster - top level',
#   'Short': 'ONS 2001 cluster supergroup',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 110,
#   'Name': 'ONS statistical neighbour cluster - middle level',
#   'Short': 'ONS 2001 cluster group',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 111,
#   'Name': 'ONS statistical neighbour cluster - bottom level',
#   'Short': 'ONS 2001 cluster subgroup',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 112,
#   'Name': 'Strategic Clinical Network',
#   'Short': 'Strategic Clinical Network',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 113,
#   'Name': 'Parliamentary constituency (2014)',
#   'Short': 'Parliamentary constituency',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 114,
#   'Name': 'ONS statistical neighbour cluster 2011 - top level',
#   'Short': 'ONS 2011 supergroup (superseded)',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 115,
#   'Name': 'ONS statistical neighbour cluster 2011 - middle level',
#   'Short': 'ONS 2011 group (superseded)',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 116,
#   'Name': 'ONS statistical neighbour cluster 2011 - bottom level',
#   'Short': 'ONS 2011 subgroup (superseded)',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 117,
#   'Name': 'Mental Health and Acute Trust combined',
#   'Short': 'MH and Acute Trust',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 118,
#   'Name': 'Acute Trusts (incl.combined MH+Acute)',
#   'Short': 'Acute Trusts',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 119,
#   'Name': 'Mental Health Trusts (incl.combined MH+Acute)',
#   'Short': 'Mental Health Trusts',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 120,
#   'Name': 'Sustainability and Transformation Footprints',
#   'Short': 'STP (unchanged)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 121,
#   'Name': 'Abdominal aortic aneurysm screening cohort',
#   'Short': 'AAA Screening Cohorts',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 122,
#   'Name': 'Bowel Cancer Screening Centres',
#   'Short': 'Bowel Cancer Screening Centres',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 123,
#   'Name': 'Diabetic Eye Screening Programmes',
#   'Short': 'Diabetic Eye Screening Programmes',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 124,
#   'Name': 'Newborn Screening Sites',
#   'Short': 'Newborn Screening Sites',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 125,
#   'Name': 'Maternity Services',
#   'Short': 'Maternity Services',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 126,
#   'Name': 'Combined authorities',
#   'Short': 'Combined authorities',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 127,
#   'Name': 'Police Force Area',
#   'Short': 'Police Force Area',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 128,
#   'Name': 'GP cluster groups',
#   'Short': 'GP cluster groups',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 129,
#   'Name': 'Laboratory',
#   'Short': 'Laboratory',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 130,
#   'Name': 'Breast Screening Service',
#   'Short': 'Breast Screening Service',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 152,
#   'Name': 'CCG unchanged plus new 2017',
#   'Short': 'CCGs (2017/18)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 153,
#   'Name': 'CCG unchanged plus old 2017',
#   'Short': 'CCGs (pre 4/2017)',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 154,
#   'Name': 'CCG unchanged plus new 2018',
#   'Short': 'CCGs (2018/19)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 155,
#   'Name': 'ONS 2011 supergroup (revised)',
#   'Short': 'ONS 2011 supergroup',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 156,
#   'Name': 'ONS 2011 group (revised)',
#   'Short': 'ONS 2011 group',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 157,
#   'Name': 'ONS 2011 subgroup (revised)',
#   'Short': 'ONS 2011 subgroup',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 158,
#   'Name': 'Hospital trust type',
#   'Short': 'Trust type',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 159,
#   'Name': 'United Kingdom',
#   'Short': 'UK',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 160,
#   'Name': 'LA unchanged',
#   'Short': 'LA unchanged',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 161,
#   'Name': 'LA new 2019',
#   'Short': 'LA new 2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 162,
#   'Name': 'LA old 2019',
#   'Short': 'LA obsolete 2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 163,
#   'Name': 'LA old 2020',
#   'Short': 'LA obsolete 2020',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 165,
#   'Name': 'CCGs unchanged plus new 2019',
#   'Short': 'CCGs (2019/20)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 166,
#   'Name': 'CCGs unchanged minus old plus new',
#   'Short': 'CCGs (since 4/20)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 170,
#   'Name': 'UA unchanged',
#   'Short': 'UA unchanged',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 171,
#   'Name': 'UA new 2019',
#   'Short': 'UA new 2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 172,
#   'Name': 'UA old 2019',
#   'Short': 'UA obsolete 2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 173,
#   'Name': 'UA new 2020',
#   'Short': 'UA new 2020',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 174,
#   'Name': 'UA new 2021',
#   'Short': 'UA new 2021',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 180,
#   'Name': 'County unchanged',
#   'Short': 'County unchanged',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 182,
#   'Name': 'County old 2019',
#   'Short': 'County obsolete 2019',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 183,
#   'Name': 'County old 2020',
#   'Short': 'County obsolete 2020',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 201,
#   'Name': 'Lower tier local authorities (4/19 - 3/20)',
#   'Short': 'District & UA (4/19-3/20)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 202,
#   'Name': 'Upper tier local authorities (4/19 - 3/20)',
#   'Short': 'County & UA (4/19-3/20)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 203,
#   'Name': 'IAPT services',
#   'Short': 'IAPT services',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 204,
#   'Name': 'Primary Care Network (provisional)',
#   'Short': 'PCN (provisional)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 205,
#   'Name': 'Local Maternity System',
#   'Short': 'Local Maternity System',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 217,
#   'Name': 'STP',
#   'Short': 'STP (new 4/20)',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 218,
#   'Name': 'STP',
#   'Short': 'STP (obsolete)',
#   'IsSearchable': False,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 219,
#   'Name': 'STP (120 +218)',
#   'Short': 'STP (pre 4/20)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 220,
#   'Name': 'Sustainability and Transformation Footprints',
#   'Short': 'STP (since 4/20)',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 301,
#   'Name': 'Lower tier local authorities (post 4/20)',
#   'Short': 'District & UA',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 302,
#   'Name': 'Upper tier local authorities (post 4/20)',
#   'Short': 'County & UA',
#   'IsSearchable': True,
#   'CanBeDisplayedOnMap': True}]
