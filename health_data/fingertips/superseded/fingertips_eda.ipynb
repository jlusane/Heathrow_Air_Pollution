# %%
# dark theme extension https://stackoverflow.com/questions/46510192/change-the-theme-in-jupyter-notebook
import fingertips_py as ftp
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
import os
pd.set_option('display.max_colwidth', -1)    # stop the column text truncating... 
pd.set_option("display.max_rows", None, "display.max_columns", None)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Test the API methods

# %%
mlc = ftp.get_data_for_indicator_at_all_available_geographies(285)
print(mlc.shape)
# mlc[(mlc['Area Type']=='GP')].head(5)
# we can see from below that the QOF dataset is available
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (90537, 26)

# %%
mlc[(mlc['Area Type']=='GP')].head(5)
# Out:
#    Indicator ID                     Indicator Name Parent Code Parent Name  \
# 2  285           Asthma: QOF prevalence (all ages)  E92000001   England
# 3  285           Asthma: QOF prevalence (all ages)  E92000001   England
# 4  285           Asthma: QOF prevalence (all ages)  E92000001   England
# 5  285           Asthma: QOF prevalence (all ages)  E92000001   England
# 6  285           Asthma: QOF prevalence (all ages)  E92000001   England
#
#   Area Code                        Area Name Area Type      Sex       Age  \
# 2  A81001    The Densham Surgery              GP        Persons  All ages
# 3  A81002    Queens Park Medical Centre       GP        Persons  All ages
# 4  A81004    Bluebell Medical Centre          GP        Persons  All ages
# 5  A81005    Springwood Surgery               GP        Persons  All ages
# 6  A81006    Tennant Street Medical Practice  GP        Persons  All ages
#
#    Category Type  Category Time period     Value  Lower CI 95.0 limit  \
# 2 NaN            NaN        2009/10     7.228626  6.480871
# 3 NaN            NaN        2009/10     7.518943  7.166613
# 4 NaN            NaN        2009/10     5.597872  5.122754
# 5 NaN            NaN        2009/10     4.766683  4.320375
# 6 NaN            NaN        2009/10     6.219167  5.806942
#
#    Upper CI 95.0 limit  Lower CI 99.8 limit  Upper CI 99.8 limit  Count  \
# 2  8.055226            NaN                  NaN                   301
# 3  7.887123            NaN                  NaN                   1548
# 4  6.114216            NaN                  NaN                   463
# 5  5.256564            NaN                  NaN                   380
# 6  6.658586            NaN                  NaN                   769
#
#    Denominator Value note Recent Trend  \
# 2  4164         NaN        NaN
# 3  20588        NaN        NaN
# 4  8271         NaN        NaN
# 5  7972         NaN        NaN
# 6  12365        NaN        NaN
#
#   Compared to England value or percentiles Compared to percentiles  \
# 2  Higher                                   Not compared
# 3  Higher                                   Not compared
# 4  Similar                                  Not compared
# 5  Lower                                    Not compared
# 6  Similar                                  Not compared
#
#    Time period Sortable  New data  Compared to goal
# 2  20090000             NaN       NaN
# 3  20090000             NaN       NaN
# 4  20090000             NaN       NaN
# 5  20090000             NaN       NaN
# 6  20090000             NaN       NaN

# %%
# cop = ftp.get_data_for_indicator_at_all_available_geographies(253)
# cop.head(100)
cop['Area Type'].unique()
# Out:
# array(['England', 'STP (since 4/20)', 'STP (pre 4/20)',
#        'PCN (v. 29/10/20)', 'CCGs (since 4/20)', 'CCGs (2019/20)',
#        'CCGs (2018/19)', 'GP'], dtype=object)

# %% [markdown]
# ## Load in the Data

# %%
##################################################################################################
# buzzwords - to 'search' our indicator df for  
# asthma - done 
# lower respiratory tract infections - done 
# pneumonia - done 
# respiratory - done 
# chronic obstructive pulmonary disease - done 

### tables broken down by ailment, next --> arrange into indicdence, mortality rate, hospital admissions.

# 1205  Lung cancer registrations
# 1203	Mortality rate from lung cancer



########################################### RESPIRATORY DISEASES #######################################################

# returned indicators from our searched values

### Prevalance...  -- maybe lung cancer can surplus Quality framework dataset... 
# 1205  Lung cancer registrations
# 253		COPD: QOF prevalence (all ages)  --> check out...   

### mortality
# 1203	Mortality rate from lung cancer
# 93643	Mortality rate from COPD as a contributory cause
# 1204	Mortality rate from chronic obstructive pulmonary disease
# 40701	Under 75 mortality rate from respiratory disease
# 93644	Mortality rate from asthma
# 93641	Mortality rate from pneumonia (all mentions)
# 93640	Mortality rate from pneumonia (underlying cause)


### admissions 
# 92302	Emergency hospital admissions for COPD
# 93577	Emergency hospital admissions for COPD, all ages
# 93575	Emergency hospital admissions for respiratory disease
# 92253	Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years
# 192972	Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years
# 92971	Admissions for lower respiratory tract infections in infants aged 1 year
# 92252	Admissions for lower respiratory tract infections in infants aged 1 year
# 92251	Admissions for lower respiratory tract infections in infants aged under 1 year
# 92970	Admissions for lower respiratory tract infections in infants aged under 1 year
# 93573	Emergency hospital admissions for asthma in adults (aged 19 years and over)
# 90810	Hospital admissions for asthma (under 19 years)
# 92780	Hospital admissions for asthma (under 19 years) -- need to see which one is relevant
# 93574	Emergency hospital admissions for pneumonia


### need to double check 
# 90612 COPD002: Diagnosis conf. by spirometry (den. incl. exc.) - need to check 

########################################### CARDIOVASCULAR DISEASES #######################################################

# (ANALYSIS NOT YET RUN ON INDICATORS BELOW)

# 92783	Estimated prevalence of Heart failure (16+)

# 93231	Emergency hospital admissions for stroke, standardised admission ratio
# 93229	Emergency hospital admissions for coronary heart disease, standardised admission ratio
# 93232	Emergency hospital admissions for Myocardial Infarction (heart attack), standardised admission ratio
# 90987	Heart failure admissions (all ages)
# 90988	CHD admissions (all ages)


# mortality rates 
# 91059	Coronary heart disease mortality rates, under 75 years
# 92718	Mortality rate from all cardiovascular diseases, ages 65+ years
# 40401	Under 75 mortality rate from all cardiovascular diseases
# 91166	Under 75 mortality rate from heart disease
# 91167	Under 75 mortality rate from stroke
# 91106	Stroke mortality rates, over 75 years (age standardised)
# 91061	Stroke mortality rates, under 75 years (age standardised)
# 40402	Under 75 mortality rate from cardiovascular diseases considered preventable (2016 definition)
# 93722	Under 75 mortality rate from cardiovascular diseases considered preventable (2019 definition)
# 93259	Deaths from stroke, all ages, standardised mortality ratio

# %%
# get a df of all indicators available in Fingertips
indicator_df = ftp.get_metadata_for_all_indicators_from_csv()
interested_indicators = indicator_df[['Indicator ID', 'Indicator']].sort_values(by='Indicator')

# %%
# We search the indicator_df here with buzzwords and return indicators want to use in our analysis
interested_indicators[interested_indicators['Indicator'].str.lower().str.contains('qof'.lower())].head(100)
# Out:
#      Indicator ID  \
# 30   285
# 37   280
# 33   273
# 11   258
# 29   253
# 662  92589
# 50   276
# 7    247
# 176  90646
# 5    241
# 12   224
# 371  91280
# 35   262
# 34   849
# 6    219
# 13   200
# 175  90581
# 656  92588
# 195  90443
# 657  92590
# 14   294
# 1    114
# 230  90573
# 374  91269
# 482  91547
# 32   212
# 2    295
#
#                                                                                                                                           Indicator
# 30   Asthma: QOF prevalence (all ages)
# 37   Atrial fibrillation: QOF prevalence
# 33   CHD: QOF prevalence (all ages)
# 11   CKD: QOF prevalence (18+)
# 29   COPD: QOF prevalence (all ages)
# 662  CVD-PP: QOF prevalence (30-74)
# 50   Cancer: QOF prevalence (all ages)
# 7    Dementia: QOF prevalence (all ages)
# 176  Depression: QOF incidence (18+) - new diagnosis
# 5    Diabetes: QOF prevalence (17+)
# 12   Epilepsy: QOF prevalence (18+)
# 371  Estimated smoking prevalence (QOF)
# 35   Heart Failure: QOF prevalence (all ages)
# 34   Heart failure w LVD: QOF prevalence (all ages)
# 6    Hypertension: QOF prevalence (all ages)
# 13   Learning disability: QOF prevalence
# 175  Mental Health: QOF prevalence (all ages)
# 656  Obesity: QOF prevalence (18+)
# 195  Osteoporosis: QOF prevalence (50+)
# 657  PAD: QOF prevalence (all ages)
# 14   Palliative/supportive care: QOF prevalence (all ages)
# 1    QOF Total List Size
# 230  Ratio of QOF and estimated prevalence of severe mental illness (SMI): QOF register prevalence of SMI as a ratio of estimated prevalence of SMI
# 374  Rheumatoid Arthritis: QOF prevalence (16+)
# 482  Smoking prevalence in adults (15+) - current smokers (QOF)
# 32   Stroke: QOF prevalence (all ages)
# 2    Total QOF points

# %%
# concat indicator data, output as a CSV file
def _concat_output_data(indicator_ids, name):
    directory = './data_output/{0}'.format(name)

    if not os.path.exists(directory):
        os.makedirs(directory)
        
    lst_df = []
    for id in indicator_ids:
        tmp_d = ftp.get_data_for_indicator_at_all_available_geographies(id)
        lst_df.append(tmp_d)
        
    tmp_concat = pd.concat(lst_df, axis=0, ignore_index=True)
    
    tmp_concat.to_csv(directory + '/' +  name + '.csv')
    
    # free memory
    tmp_concat= None 
    lst_df = None

# %%
# navigate through API for prevalence indicators and concat the prevalence dataset, commented out as we have already completed
# save concatenated set to CSV
_concat_output_data([1205,253, 285], 'prevalance_supplement')

# %%
# # navigate through API for mortality indicators and concat the mortality_rate dataset, commented out as we have already completed
# save concatenated set to CSV
# _concat_output_data([1203,93643, 1204, 40701, 93644, 93641, 93640], 'mortality_rate')

# %%
# navigate through API for hospital indicators and concat the hospital_admissions dataset, commented out as we have already completed
# save concatenated set to CSV
# _concat_output_data([92302,93577, 93575, 92253, 192972, 92971, 92252, 92251, 92970, 93573, 90810, 92780, 93574], 'hospital_admissions')

# %% [markdown]
# # Preliminary Analysis on Mortality, Dataset)

# %%
# some basic checks 

def preliminary_data_checks(df, name):
    
    print('Running analysis checks on the {0} DataFrame...'.format(name))
    print('\n\n')
    
    print('the shape of the df is as follows: ', df.shape)
    print('\n\n')

    print('Check 1. Columns for the {0} DataFrame as as follows: {1} \n'.format(name, list(df.columns)))
    print('\n\n')

    print('Check 2. The {0} DataFrame column datatypes are as follows: {1}'.format(name, df.dtypes))
    print('\n\n')
    
    print('Check 1a. NULL values in Columns for the {0} DataFrame as as follows: \n'.format(name))
    print(df.isna().sum())
    print('\n\n')
    
    indicators = df['Indicator Name'].unique()
    print('there are {0} diifferent indicators in this set, they are as follows:'.format(len(indicators)))
    for indicator in indicators:
        print(indicator)
        
    print('\n\n')
    
    print('data is prevalent for the following years (individual indicator analysis is required...) \n')
    print(sorted(df['Time period Sortable'].unique()))
#     print(sorted(tmp_df['Area Type'].unique()))

# %%
mortality_df = pd.read_csv('./data_output/mortality_rate/mortality_rate.csv')
prevalance_supplement_df = pd.read_csv('./data_output/prevalance_supplement/prevalance_supplement.csv')
hospital_admissions_df = pd.read_csv('./data_output/hospital_admissions/hospital_admissions.csv')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (10,11,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
preliminary_data_checks(mortality_df, 'mortality')
# Out:
# Running analysis checks on the mortality DataFrame...
#
#
#
# the shape of the df is as follows:  (228912, 27)
#
#
#
# Check 1. Columns for the mortality DataFrame as as follows: ['Unnamed: 0', 'Indicator ID', 'Indicator Name', 'Parent Code', 'Parent Name', 'Area Code', 'Area Name', 'Area Type', 'Sex', 'Age', 'Category Type', 'Category', 'Time period', 'Value', 'Lower CI 95.0 limit', 'Upper CI 95.0 limit', 'Lower CI 99.8 limit', 'Upper CI 99.8 limit', 'Count', 'Denominator', 'Value note', 'Recent Trend', 'Compared to England value or percentiles', 'Compared to percentiles', 'Time period Sortable', 'New data', 'Compared to goal']
#
#
#
#
# Check 2. The mortality DataFrame column datatypes are as follows: Unnamed: 0                                  int64
# Indicator ID                                int64
# Indicator Name                              object
# Parent Code                                 object
# Parent Name                                 object
# Area Code                                   object
# Area Name                                   object
# Area Type                                   object
# Sex                                         object
# Age                                         object
# Category Type                               object
# Category                                    object
# Time period                                 object
# Value                                       float64
# Lower CI 95.0 limit                         float64
# Upper CI 95.0 limit                         float64
# Lower CI 99.8 limit                         float64
# Upper CI 99.8 limit                         float64
# Count                                       float64
# Denominator                                 float64
# Value note                                  object
# Recent Trend                                object
# Compared to England value or percentiles    object
# Compared to percentiles                     object
# Time period Sortable                        int64
# New data                                    float64
# Compared to goal                            float64
# dtype: object
#
#
#
# Check 1a. NULL values in Columns for the mortality DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 5337
# Parent Name                                 5337
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               218652
# Category                                    218652
# Time period                                 0
# Value                                       2692
# Lower CI 95.0 limit                         2692
# Upper CI 95.0 limit                         2692
# Lower CI 99.8 limit                         183528
# Upper CI 99.8 limit                         183528
# Count                                       5183
# Denominator                                 860
# Value note                                  221151
# Recent Trend                                215069
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    228912
# Compared to goal                            228912
# dtype: int64
#
#
#
# there are 7 diifferent indicators in this set, they are as follows:
# Mortality rate from lung cancer
# Mortality rate from COPD as a contributory cause
# Mortality rate from chronic obstructive pulmonary disease
# Under 75 mortality rate from respiratory disease
# Mortality rate from asthma
# Mortality rate from pneumonia (all mentions)
# Mortality rate from pneumonia (underlying cause)
#
#
#
# data is prevalent for the following years (individual indicator analysis is required...)
#
# [20010000, 20020000, 20030000, 20040000, 20050000, 20060000, 20070000, 20080000, 20090000, 20100000, 20110000, 20120000, 20130000, 20140000, 20150000, 20160000, 20170000]

# %%
# grouped = mortality_df.groupby(['Time period Sortable', 'Indicator Name']).size().reset_index().rename(columns={0:'nr_records'})


# we should use count instead, as we do not want to include the null values with 'size()'
# we pick any column (Area codem, whatever, they will all contain the same vlaue the same)
grouped = mortality_df.groupby(['Time period Sortable', 'Indicator Name']).count()['Area Code'].reset_index().rename(columns={'Area Code':'nr_records'})

# get rid of extra 0 and cast to int for now...
grouped['Time period Sortable'] = (grouped['Time period Sortable']/10000).astype(int)
grouped.head()
# Out:
#    Time period Sortable  \
# 0  2001
# 1  2001
# 2  2001
# 3  2002
# 4  2002
#
#                                               Indicator Name  nr_records
# 0  Mortality rate from chronic obstructive pulmonary disease  4533
# 1  Mortality rate from lung cancer                            3015
# 2  Under 75 mortality rate from respiratory disease           4266
# 3  Mortality rate from chronic obstructive pulmonary disease  4533
# 4  Mortality rate from lung cancer                            3015

# %%
piv = grouped.pivot(
index = 'Time period Sortable',
columns='Indicator Name',
values='nr_records'
)
piv.head(5)
# Out:
# Indicator Name        Mortality rate from COPD as a contributory cause  \
# Time period Sortable
# 2001                 NaN
# 2002                 NaN
# 2003                 NaN
# 2004                 NaN
# 2005                 NaN
#
# Indicator Name        Mortality rate from asthma  \
# Time period Sortable
# 2001                 NaN
# 2002                 NaN
# 2003                 NaN
# 2004                 NaN
# 2005                 NaN
#
# Indicator Name        Mortality rate from chronic obstructive pulmonary disease  \
# Time period Sortable
# 2001                  4533.0
# 2002                  4533.0
# 2003                  4533.0
# 2004                  4533.0
# 2005                  4533.0
#
# Indicator Name        Mortality rate from lung cancer  \
# Time period Sortable
# 2001                  3015.0
# 2002                  3015.0
# 2003                  3015.0
# 2004                  3015.0
# 2005                  3015.0
#
# Indicator Name        Mortality rate from pneumonia (all mentions)  \
# Time period Sortable
# 2001                 NaN
# 2002                 NaN
# 2003                 NaN
# 2004                 NaN
# 2005                 NaN
#
# Indicator Name        Mortality rate from pneumonia (underlying cause)  \
# Time period Sortable
# 2001                 NaN
# 2002                 NaN
# 2003                 NaN
# 2004                 NaN
# 2005                 NaN
#
# Indicator Name        Under 75 mortality rate from respiratory disease
# Time period Sortable
# 2001                  4266.0
# 2002                  4266.0
# 2003                  4266.0
# 2004                  4266.0
# 2005                  4266.0

# %%
# lets see the number of rows/records in our concatenated file
# pivot doesnt seem to be working (maybe set is too large, next we will try facetgrid with seaborn)
m = sns.FacetGrid(grouped, col='Indicator Name', col_wrap=3, height=5)
m.map(sns.lineplot, 'Time period Sortable', 'nr_records')
m.set(xticks=np.arange(2000, 2022, 2))

# %%
# the above =shows that we have consistent file/row numbers for the mortality rate
# what is the data window for each mortality indicator? 

for indicator in grouped['Indicator Name'].unique():
    t_df = grouped[grouped['Indicator Name'] == indicator]
    max_year = t_df['Time period Sortable'].max()
    min_year = t_df['Time period Sortable'].min()

    print('Indicator statistics for {0}:'.format(indicator))
    
    print('First Data Points: {0} the last data points {1} \n'.format(
        min_year, max_year)
    )
# Out:
# Indicator statistics for Mortality rate from chronic obstructive pulmonary disease:
# First Data Points: 2001 the last data points 2017
#
# Indicator statistics for Mortality rate from lung cancer:
# First Data Points: 2001 the last data points 2017
#
# Indicator statistics for Under 75 mortality rate from respiratory disease:
# First Data Points: 2001 the last data points 2017
#
# Indicator statistics for Mortality rate from COPD as a contributory cause:
# First Data Points: 2006 the last data points 2017
#
# Indicator statistics for Mortality rate from asthma:
# First Data Points: 2006 the last data points 2017
#
# Indicator statistics for Mortality rate from pneumonia (all mentions):
# First Data Points: 2006 the last data points 2017
#
# Indicator statistics for Mortality rate from pneumonia (underlying cause):
# First Data Points: 2006 the last data points 2017

# %%
# next, make some plots on the mortality rate, remember to keep the most granulat area type, which is CCG for our set
# lets see how the mortality rate changes over time. 

# remove england statistics, we want CCGs
special = mortality_df[(mortality_df['Area Name'] != 'England')]

# filter out male and female results, for now
special = special[special['Sex'] == 'Persons']

# limit to CCGS (using LOC with isin())
special = special.loc[special['Area Type'].isin(['CCGs (since 4/20)','CCGs (2019/20)'])]

# Important graph is to plot the different indicators values by year (so use a sum instead of count)
grouped_sum = special.groupby(['Time period Sortable', 'Indicator Name']).sum()['Count'].reset_index()

# get rid of extra 0 and cast to int for now, for the sortable time period...
grouped_sum['Time period Sortable'] = (grouped_sum['Time period Sortable']/10000).astype(int)

# we will use seaborn here (for pandas might need a pivot table, where we break out indicator name)
# set the figure size with rc argument for seaborn (stack overflow)
sns.set(rc={'figure.figsize':(11,8)})

sns.lineplot(data=grouped_sum, x='Time period Sortable', y='Count', hue='Indicator Name', legend='full')

# Put the legend out of the figure using matlibplot (stackoverflow...)
plt.legend((bbox_to_anchor)=(1.03,1), loc=2, borderaxespad=1)

plt.show()

# %%
def plot_indicator_df(df):
    # Important graph is to plot the different indicators values by year (so use a sum instead of count)
    grouped_sum = df.groupby(['Time period Sortable', 'Indicator Name', 'Indicator ID']).sum()['Count'].reset_index()

    # get rid of extra 0 and cast to int for now...
    grouped_sum['Time period Sortable'] = (grouped_sum['Time period Sortable']/10000).astype(int)
#     grouped_sum['Count'] = grouped_sum['Count'].astype(int)

    # we will use seaborn here (for pandas will need another pivot table, where we break out indicator name)
    # set the figure size with rc argument for seaborn (stack overflow)
    sns.set(rc={'figure.figsize':(11,8)})

    sns.lineplot(data=grouped_sum, x='Time period Sortable', y='Count', hue='Indicator Name', legend='full')

    # Put the legend out of the figure using matlibplot (stackoverflow...)
    plt.legend((bbox_to_anchor)=(1.03,1), loc=2, borderaxespad=1)

    plt.show()

# %% [markdown]
# # Main Analysis on All Concatenated Datasets (Admissions, Mortality, Prevalance)

# %% [markdown]
# we will now answer the dataset detailing questions:
#
#
# ### 1. How many data sources are you using? Where are you getting the data from? Is it publicly available?
# Who provides the data? What challenges might be present based on your answers?
#
# **Answer**
# For Fingertips, we are using the publicly available 'fingertips_py' python package: https://fingertips-py.readthedocs.io/en/latest/ to download a SERIES (PUT FINAL NUMBER) of indicators. Preliminary findings indicate that data is on tghe yearly level, for the mortalities dataset we have a window between 2006 - 2017 for all indicators.

# %% [markdown]
# ### 2. How large are your data sets? Do you foresee any hardware restrictions in analyzing your data? Will you need to use creative methods to handle your data (working in smaller batches, outsourcing computing etc.)

# %%
print('answer: we have concatenated the fingertips indicators into three datasets: mortality_df, prevalance_supplement_df, hospital_admissions_df')

print('the size is as follows: ')
print('mortality: ', mortality_df.shape)
print('prevalance_supplement_df: ', prevalance_supplement_df.shape)
print('hospital_admissions_df: ', hospital_admissions_df.shape)

print('At the time of writing, we do not see a problem with analysing the sets, as our model will take a subset of rows based on CGP area location. In addition, our important field (count) is aggregated to the year level.')

mortality_df.head()
# Out:
# answer: we have concatenated the fingertips indicators into three datasets: mortality_df, prevalance_supplement_df, hospital_admissions_df
# the size is as follows:
# mortality:  (228912, 27)
# prevalance_supplement_df:  (157586, 27)
# hospital_admissions_df:  (55900, 28)
# At the time of writing, we do not see a problem with analysing the sets, as our model will take a subset of rows based on CGP area location. In addition, our important field (count) is aggregated to the year level.
#    Unnamed: 0  Indicator ID                   Indicator Name Parent Code  \
# 0  0           1203          Mortality rate from lung cancer  NaN
# 1  1           1203          Mortality rate from lung cancer  NaN
# 2  2           1203          Mortality rate from lung cancer  NaN
# 3  3           1203          Mortality rate from lung cancer  NaN
# 4  4           1203          Mortality rate from lung cancer  NaN
#
#   Parent Name  Area Code Area Name Area Type   Sex       Age  \
# 0  NaN         E92000001  England   England   Male  All ages
# 1  NaN         E92000001  England   England   Male  All ages
# 2  NaN         E92000001  England   England   Male  All ages
# 3  NaN         E92000001  England   England   Male  All ages
# 4  NaN         E92000001  England   England   Male  All ages
#
#                                           Category Type  \
# 0  NaN
# 1  County & UA deprivation deciles in England (IMD2010)
# 2  County & UA deprivation deciles in England (IMD2010)
# 3  County & UA deprivation deciles in England (IMD2010)
# 4  County & UA deprivation deciles in England (IMD2010)
#
#                                 Category Time period       Value  \
# 0  NaN                                    2001 - 03   93.446004
# 1  Most deprived decile (IMD2010)         2001 - 03   129.952898
# 2  Second most deprived decile (IMD2010)  2001 - 03   113.045523
# 3  Third more deprived decile (IMD2010)   2001 - 03   122.301265
# 4  Fourth more deprived decile (IMD2010)  2001 - 03   109.243674
#
#    Lower CI 95.0 limit  Upper CI 95.0 limit  Lower CI 99.8 limit  \
# 0  92.596587            94.301109           NaN
# 1  126.203319           133.782087          NaN
# 2  109.214648           116.972968          NaN
# 3  118.496771           126.193157          NaN
# 4  106.086345           112.468933          NaN
#
#    Upper CI 99.8 limit    Count  Denominator Value note Recent Trend  \
# 0 NaN                   49011.0  72886051.0   NaN        NaN
# 1 NaN                   4952.0   6435808.0    NaN        NaN
# 2 NaN                   3528.0   5129660.0    NaN        NaN
# 3 NaN                   4238.0   4944789.0    NaN        NaN
# 4 NaN                   4824.0   6391084.0    NaN        NaN
#
#   Compared to England value or percentiles Compared to percentiles  \
# 0  Not compared                             Not compared
# 1  Worse                                    Not compared
# 2  Worse                                    Not compared
# 3  Worse                                    Not compared
# 4  Worse                                    Not compared
#
#    Time period Sortable  New data  Compared to goal
# 0  20010000             NaN       NaN
# 1  20010000             NaN       NaN
# 2  20010000             NaN       NaN
# 3  20010000             NaN       NaN
# 4  20010000             NaN       NaN

# %% [markdown]
# ### 3.  What variables do you have in your data? What data dypes do you have?

# %%
print('The variables for mortality_df, prevalance_supplement_df, hospital_admissions_df are consistent and follow the convention: \n')
print('mortality: ', mortality_df.dtypes)
print('\n')

# print('hospital_admissions_df: ', hospital_admissions_df.dtypes)
# print('\n\n')


print(hospital_admissions_df.columns == prevalance_supplement_df.columns )
print(prevalance_supplement_df.columns ==hospital_admissions_df.columns)
print('\n\n')


print('''Fields of interest are: Indicator Name, Area Name, Area Type, Time Period Sortable/Time Period Count, 
Denominator. Additional fields of interest for model breakdown: Age, Sex''')

print('potential problem with lung cancel registrations (no denominator.... I dont think we can use this set )')


print('largest issue is that we do not have GP/hospital breakdown with this set.')
# Out:
# The variables for mortality_df, prevalance_supplement_df, hospital_admissions_df are consistent and follow the convention:
#
# mortality:  Unnamed: 0                                  int64
# Indicator ID                                int64
# Indicator Name                              object
# Parent Code                                 object
# Parent Name                                 object
# Area Code                                   object
# Area Name                                   object
# Area Type                                   object
# Sex                                         object
# Age                                         object
# Category Type                               object
# Category                                    object
# Time period                                 object
# Value                                       float64
# Lower CI 95.0 limit                         float64
# Upper CI 95.0 limit                         float64
# Lower CI 99.8 limit                         float64
# Upper CI 99.8 limit                         float64
# Count                                       float64
# Denominator                                 float64
# Value note                                  object
# Recent Trend                                object
# Compared to England value or percentiles    object
# Compared to percentiles                     object
# Time period Sortable                        int64
# New data                                    float64
# Compared to goal                            float64
# dtype: object
#
#
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
#
#
#
# Fields of interest are: Indicator Name, Area Name, Area Type, Time Period Sortable/Time Period Count,
# Denominator. Additional fields of interest for model breakdown: Age, Sex
# potential problem with lung cancel registrations (no denominator.... I dont think we can use this set )
# largest issue is that we do not have GP/hospital breakdown with this set.

# %% [markdown]
# ### 4.  How complete is your data? How will you be addressing NAs?

# %%
for df, name in [[mortality_df, 'mortality'],[ prevalance_supplement_df, 'prevalence'], [ hospital_admissions_df, 'hospital']]:
    
    print('Check 1a. NULL values in Columns for the {0} DataFrame as as follows: \n'.format(name))
    print(df.isna().sum())
    print('\n\n')
    print('Reasons for Nan values are specified here: ', df[df['Count'].isna()]['Value note'].unique())
    print('\n\n')

    
    
    
# There are NaNs in some CCG fields across all years. 
# The documentation (https://www.ons.gov.uk/file?uri=/methodology/methodologytopicsandstatisticalconcepts/disclosurecontrol/healthstatistics/confidentialityguidanctcm77181864.pdf) 
# explains that cell suppression has taken place, in CCGs recording low numbers of indicators (to avoid identification of paitents)
# Secondary supression also occurs in the same field for CCGs (to avoid disclosure by differencing) 


print('For supressed CCGs, we should potentially drom them from our analysis (as no data available across range'),

print('if missing data due to malfunction e.g. 1 year, - we could interpolate based on the values before after, or the CGP values around this area..')

print('potential problem with lung cancel registrations (no denominator.... I dont think we can use this set ) - it might not have the range anyway...')
# Out:
# Check 1a. NULL values in Columns for the mortality DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 5337
# Parent Name                                 5337
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               218652
# Category                                    218652
# Time period                                 0
# Value                                       2692
# Lower CI 95.0 limit                         2692
# Upper CI 95.0 limit                         2692
# Lower CI 99.8 limit                         183528
# Upper CI 99.8 limit                         183528
# Count                                       5183
# Denominator                                 860
# Value note                                  221151
# Recent Trend                                215069
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    228912
# Compared to goal                            228912
# dtype: int64
#
#
#
# Reasons for Nan values are specified here:  ['Value for Cornwall and Isles of Scilly combined'
#  'Value cannot be calculated as number of cases is too small'
#  'Value for Hackney and City of London combined'
#  'Value suppressed to avoid disclosure by differencing'
#  'Value suppressed for disclosure control due to small count']
#
#
#
# Check 1a. NULL values in Columns for the prevalence DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 241
# Parent Name                                 241
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               157164
# Category                                    157164
# Time period                                 0
# Value                                       38
# Lower CI 95.0 limit                         144
# Upper CI 95.0 limit                         144
# Lower CI 99.8 limit                         127543
# Upper CI 99.8 limit                         127543
# Count                                       80
# Denominator                                 10040
# Value note                                  156785
# Recent Trend                                141744
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    157586
# Compared to goal                            157586
# dtype: int64
#
#
#
# Reasons for Nan values are specified here:  [nan 'Value for Cornwall and Isles of Scilly combined'
#  'Value for Hackney and City of London combined']
#
#
#
# Check 1a. NULL values in Columns for the hospital DataFrame as as follows:
#
# Unnamed: 0                                  0
# Indicator ID                                0
# Indicator Name                              0
# Parent Code                                 1636
# Parent Name                                 1636
# Area Code                                   0
# Area Name                                   0
# Area Type                                   0
# Sex                                         0
# Age                                         0
# Category Type                               53570
# Category                                    53570
# Time period                                 0
# Value                                       1650
# Lower CI 95.0 limit                         2232
# Upper CI 95.0 limit                         2232
# Lower CI 99.8 limit                         12677
# Upper CI 99.8 limit                         12677
# Count                                       1642
# Denominator                                 522
# Value note                                  52834
# Recent Trend                                45742
# Compared to England value or percentiles    0
# Compared to percentiles                     0
# Time period Sortable                        0
# New data                                    56538
# Compared to goal                            56538
# dtype: int64
#
#
#
# Reasons for Nan values are specified here:  ['Value for Cornwall and Isles of Scilly combined'
#  'Value for Hackney and City of London combined'
#  'Value is not presented due to an issue with HES coding in Nottingham University Hospitals Trust in 2016/17, for which over 30% of records did not have a valid geography of residence assigned. In 2015/16, over 20% of patients that attended hospital from this area were treated at Nottingham University Hospitals Trust.'
#  'Value is not presented due to an issue with HES coding in East Sussex Healthcare NHS Trust in 2018/19, for which approximately 85,000 records erroneously had all diagnosis codes removed. In 2018/19, over 10% of patients that attended hospital from this area had records that were missing diagnosis codes'
#  'Value suppressed for disclosure control reasons'
#  'Value suppressed for disclosure control due to small count'
#  'Value suppressed to avoid disclosure by differencing'
#  'Due to an issue with HES coding in Nottingham University Hospitals Trust in 2016/17, for which over 30% of records did not have a valid geography of residence assigned, this value should be treated with caution. In 2015/16, between 10% and 20% of patients that attended hospital from this area were treated at Nottingham University Hospitals Trust.']
#
#
#
# For supressed CCGs, we should potentially drom them from our analysis (as no data available across range
# if missing data due to malfunction e.g. 1 year, - we could interpolate based on the values before after, or the CGP values around this area..
# potential problem with lung cancel registrations (no denominator.... I dont think we can use this set ) - it might not have the range anyway...

# %%
# plot a graph for the datasets to see data window:
# FYI - NO FILTERING OR RESTRICTION HAVE BEEN APPLIED ON THE GRAPHS BELOW, ASSUME THEY NEED FURHTER ANALYSIS AND 
# A CORRECTNESS CHECK

for df, name in [[mortality_df, 'mortality'],[ prevalance_supplement_df, 'prevalence'], [ hospital_admissions_df, 'hospital']]:
    print('Plotting incident graph for {0} dataset.'.format(name))
    print('\n\n')
    
    print('FYI - NO FILTERING OR RESTRICTION HAVE BEEN APPLIED ON THE GRAPHS BELOW, ASSUME THEY NEED FURHTER ANALYSIS AND A CORRECTNESS CHECK')
    print('\n\n')

    plot_indicator_df(df)
    print('\n\n')
# Out:
# Plotting incident graph for mortality dataset.
#
#
#
# FYI - NO FILTERING OR RESTRICTION HAVE BEEN APPLIED ON THE GRAPHS BELOW, ASSUME THEY NEED FURHTER ANALYSIS AND A CORRECTNESS CHECK
# Plotting incident graph for prevalence dataset.
#
#
#
# FYI - NO FILTERING OR RESTRICTION HAVE BEEN APPLIED ON THE GRAPHS BELOW, ASSUME THEY NEED FURHTER ANALYSIS AND A CORRECTNESS CHECK
# Plotting incident graph for hospital dataset.
#
#
#
# FYI - NO FILTERING OR RESTRICTION HAVE BEEN APPLIED ON THE GRAPHS BELOW, ASSUME THEY NEED FURHTER ANALYSIS AND A CORRECTNESS CHECK
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Q5-8: Remaining Questions

# %% [markdown]
# **FYI, from graphs above, dropped "Emergency hospital admissions for bronchiolitis in children aged under 2 years"** indicator.. only 1 year available
#
# 5. Do you need more data at this point?
#    * **Answer** three notable issues with this dataset are
#    * Datasets are not broken down by hospital/GP... this means they cannot work with the radius/distance approach
#    * Hospital admissions/prevalence supplement sets are yearly, mortality is bi-yearly
#
#
#    * Hospital admissions
#      * do not go back further than 2013  aside from Asthma U19 (2011) & COPD (2010) and all end in 2018, these give us 7 and 8 points for our model respectively.
#      * Asthma hospital admissions (under 19) has two variants; 90810 is based on older definition of CCP, 92780 (2013 onwards) is the up-to-date CCP one
#      * SAME for COPD admission  - 92302 (2010 onwards) is the older definition, 93577 is the up-to-date CCG definition
#    * Mortality:
#      * I believe dataset rows are aggregated for two years (2001 - 2003, 2002 - 2004... 2017-2019).. we may need to aggrgate the pollution for 2 years for mortality indicators. See original "Time Period" field.
#
#    * Our three prevelance supplement datasets,
#        * COPD: QOF prevalence (all ages), broken down by GP, 2009 - 2019 data, this should be identical to NHS set.
#        * Asthma QOF prevalence (all ages), broken down by GP, 2009 - 2019 data, this should be identical to NHS set.
#        * Both prevalence sets show increase in 2015 (more collection?)
#        * Lung Cancer registrations is broken down by "County & UA" (not CCP) and is in two - year intervals. - I recommend we disregard the set.
#     * Recommendation: The team should double check whether data is really bi-annual for Mortality, if so, search for annual data as a minimum
#
#
#
#
# 6. What keys exist for record linkaging if you need to do so in the future?
#    * Time period Sortable
#    * Area Name (CCG - we can link this to pollutant station location, & e.g. map out which station lies in which CCG)
#
#
# 7. What are the most interesting data points?
#    * Prevalence supplement - spike in 2015, further investigation required
#
#
#
# 8. Are there any data points that you don't have yet that you would like or need for your analysis?
#    * Annual points for mortality dataset.

# %%
# Drop the child bronchitis row, not useful ( only 1 year of data)
# I removed 93576 from the original concentation above, so we will not require this step again.

# 93576 --> is the corresponding Indicator ID
# print shape before & after to ensure we have dropped the rows
# print(hospital_admissions_df.shape)
# print(hospital_admissions_df['Indicator ID'].unique())

# hospital_admissions_df = hospital_admissions_df.drop(hospital_admissions_df[hospital_admissions_df['Indicator ID'] == 93576].index)

# print(hospital_admissions_df.shape)
# print(hospital_admissions_df['Indicator ID'].unique())

# tmp = hospital_admissions_df.copy()

# %% [markdown]
# ## Extra Fixes

# %%
# fix for the two asthma indicators (same, but renamed in later data sets)
def func(row):
    if row['Indicator ID'] == 92780:        
        return 'Hospital admissions for asthma (under 19 years) CCG'
    else:
        return row['Indicator Name']

# %%
# use apply to rename the extra asthma dataset. 
hospital_admissions_df['Indicator Name'] = hospital_admissions_df.apply(func, axis=1)
hospital_admissions_df.shape
# Out:
# (55900, 28)

# %%
hocopspital_admissions_df['Indicator Name'].unique()
# Out:
# array(['Emergency hospital admissions for COPD',
#        'Emergency hospital admissions for COPD, all ages',
#        'Emergency hospital admissions for respiratory disease',
#        'Admissions for lower respiratory tract infections in children aged 2, 3 and 4 years',
#        'Admissions for lower respiratory tract infections in infants aged 1 year',
#        'Admissions for lower respiratory tract infections in infants aged under 1 year',
#        'Emergency hospital admissions for asthma in adults (aged 19 years and over)',
#        'Hospital admissions for asthma (under 19 years)',
#        'Hospital admissions for asthma (under 19 years) CCG',
#        'Emergency hospital admissions for pneumonia'], dtype=object)

# %%
copd.head(2000)
# Out:
#       Indicator ID                          Indicator Name Parent Code  \
# 0     92302         Emergency hospital admissions for COPD  NaN
# 1     92302         Emergency hospital admissions for COPD  NaN
# 2     92302         Emergency hospital admissions for COPD  NaN
# 3     92302         Emergency hospital admissions for COPD  NaN
# 4     92302         Emergency hospital admissions for COPD  NaN
# 5     92302         Emergency hospital admissions for COPD  NaN
# 6     92302         Emergency hospital admissions for COPD  NaN
# 7     92302         Emergency hospital admissions for COPD  NaN
# 8     92302         Emergency hospital admissions for COPD  NaN
# 9     92302         Emergency hospital admissions for COPD  NaN
# 10    92302         Emergency hospital admissions for COPD  NaN
# 11    92302         Emergency hospital admissions for COPD  NaN
# 12    92302         Emergency hospital admissions for COPD  NaN
# 13    92302         Emergency hospital admissions for COPD  NaN
# 14    92302         Emergency hospital admissions for COPD  NaN
# 15    92302         Emergency hospital admissions for COPD  NaN
# 16    92302         Emergency hospital admissions for COPD  NaN
# 17    92302         Emergency hospital admissions for COPD  NaN
# 18    92302         Emergency hospital admissions for COPD  NaN
# 19    92302         Emergency hospital admissions for COPD  NaN
# 20    92302         Emergency hospital admissions for COPD  NaN
# 21    92302         Emergency hospital admissions for COPD  NaN
# 22    92302         Emergency hospital admissions for COPD  NaN
# 23    92302         Emergency hospital admissions for COPD  NaN
# 24    92302         Emergency hospital admissions for COPD  NaN
# 25    92302         Emergency hospital admissions for COPD  NaN
# 26    92302         Emergency hospital admissions for COPD  NaN
# 27    92302         Emergency hospital admissions for COPD  NaN
# 28    92302         Emergency hospital admissions for COPD  NaN
# 29    92302         Emergency hospital admissions for COPD  NaN
# 30    92302         Emergency hospital admissions for COPD  NaN
# 31    92302         Emergency hospital admissions for COPD  NaN
# 32    92302         Emergency hospital admissions for COPD  NaN
# 33    92302         Emergency hospital admissions for COPD  NaN
# 34    92302         Emergency hospital admissions for COPD  NaN
# 35    92302         Emergency hospital admissions for COPD  NaN
# 36    92302         Emergency hospital admissions for COPD  NaN
# 37    92302         Emergency hospital admissions for COPD  NaN
# 38    92302         Emergency hospital admissions for COPD  NaN
# 39    92302         Emergency hospital admissions for COPD  NaN
# 40    92302         Emergency hospital admissions for COPD  NaN
# 41    92302         Emergency hospital admissions for COPD  NaN
# 42    92302         Emergency hospital admissions for COPD  NaN
# 43    92302         Emergency hospital admissions for COPD  NaN
# 44    92302         Emergency hospital admissions for COPD  NaN
# 45    92302         Emergency hospital admissions for COPD  NaN
# 46    92302         Emergency hospital admissions for COPD  NaN
# 47    92302         Emergency hospital admissions for COPD  NaN
# 48    92302         Emergency hospital admissions for COPD  NaN
# 49    92302         Emergency hospital admissions for COPD  NaN
# 50    92302         Emergency hospital admissions for COPD  NaN
# 51    92302         Emergency hospital admissions for COPD  NaN
# 52    92302         Emergency hospital admissions for COPD  NaN
# 53    92302         Emergency hospital admissions for COPD  NaN
# 54    92302         Emergency hospital admissions for COPD  NaN
# 55    92302         Emergency hospital admissions for COPD  NaN
# 56    92302         Emergency hospital admissions for COPD  NaN
# 57    92302         Emergency hospital admissions for COPD  NaN
# 58    92302         Emergency hospital admissions for COPD  NaN
# 59    92302         Emergency hospital admissions for COPD  NaN
# 60    92302         Emergency hospital admissions for COPD  NaN
# 61    92302         Emergency hospital admissions for COPD  NaN
# 62    92302         Emergency hospital admissions for COPD  NaN
# 63    92302         Emergency hospital admissions for COPD  E92000001
# 64    92302         Emergency hospital admissions for COPD  E92000001
# 65    92302         Emergency hospital admissions for COPD  E92000001
# 66    92302         Emergency hospital admissions for COPD  E92000001
# 67    92302         Emergency hospital admissions for COPD  E92000001
# 68    92302         Emergency hospital admissions for COPD  E92000001
# 69    92302         Emergency hospital admissions for COPD  E92000001
# 70    92302         Emergency hospital admissions for COPD  E92000001
# 71    92302         Emergency hospital admissions for COPD  E92000001
# 72    92302         Emergency hospital admissions for COPD  E92000001
# 73    92302         Emergency hospital admissions for COPD  E92000001
# 74    92302         Emergency hospital admissions for COPD  E92000001
# 75    92302         Emergency hospital admissions for COPD  E92000001
# 76    92302         Emergency hospital admissions for COPD  E92000001
# 77    92302         Emergency hospital admissions for COPD  E92000001
# 78    92302         Emergency hospital admissions for COPD  E92000001
# 79    92302         Emergency hospital admissions for COPD  E92000001
# 80    92302         Emergency hospital admissions for COPD  E92000001
# 81    92302         Emergency hospital admissions for COPD  E92000001
# 82    92302         Emergency hospital admissions for COPD  E92000001
# 83    92302         Emergency hospital admissions for COPD  E92000001
# 84    92302         Emergency hospital admissions for COPD  E92000001
# 85    92302         Emergency hospital admissions for COPD  E92000001
# 86    92302         Emergency hospital admissions for COPD  E92000001
# 87    92302         Emergency hospital admissions for COPD  E92000001
# 88    92302         Emergency hospital admissions for COPD  E92000001
# 89    92302         Emergency hospital admissions for COPD  E92000001
# 90    92302         Emergency hospital admissions for COPD  E92000001
# 91    92302         Emergency hospital admissions for COPD  E92000001
# 92    92302         Emergency hospital admissions for COPD  E92000001
# 93    92302         Emergency hospital admissions for COPD  E92000001
# 94    92302         Emergency hospital admissions for COPD  E92000001
# 95    92302         Emergency hospital admissions for COPD  E92000001
# 96    92302         Emergency hospital admissions for COPD  E92000001
# 97    92302         Emergency hospital admissions for COPD  E92000001
# 98    92302         Emergency hospital admissions for COPD  E92000001
# 99    92302         Emergency hospital admissions for COPD  E92000001
# 100   92302         Emergency hospital admissions for COPD  E92000001
# 101   92302         Emergency hospital admissions for COPD  E92000001
# 102   92302         Emergency hospital admissions for COPD  E92000001
# 103   92302         Emergency hospital admissions for COPD  E92000001
# 104   92302         Emergency hospital admissions for COPD  E92000001
# 105   92302         Emergency hospital admissions for COPD  E92000001
# 106   92302         Emergency hospital admissions for COPD  E92000001
# 107   92302         Emergency hospital admissions for COPD  E92000001
# 108   92302         Emergency hospital admissions for COPD  E92000001
# 109   92302         Emergency hospital admissions for COPD  E92000001
# 110   92302         Emergency hospital admissions for COPD  E92000001
# 111   92302         Emergency hospital admissions for COPD  E92000001
# 112   92302         Emergency hospital admissions for COPD  E92000001
# 113   92302         Emergency hospital admissions for COPD  E92000001
# 114   92302         Emergency hospital admissions for COPD  E92000001
# 115   92302         Emergency hospital admissions for COPD  E92000001
# 116   92302         Emergency hospital admissions for COPD  E92000001
# 117   92302         Emergency hospital admissions for COPD  E92000001
# 118   92302         Emergency hospital admissions for COPD  E92000001
# 119   92302         Emergency hospital admissions for COPD  E92000001
# 120   92302         Emergency hospital admissions for COPD  E92000001
# 121   92302         Emergency hospital admissions for COPD  E92000001
# 122   92302         Emergency hospital admissions for COPD  E92000001
# 123   92302         Emergency hospital admissions for COPD  E92000001
# 124   92302         Emergency hospital admissions for COPD  E92000001
# 125   92302         Emergency hospital admissions for COPD  E92000001
# 126   92302         Emergency hospital admissions for COPD  E92000001
# 127   92302         Emergency hospital admissions for COPD  E92000001
# 128   92302         Emergency hospital admissions for COPD  E92000001
# 129   92302         Emergency hospital admissions for COPD  E92000001
# 130   92302         Emergency hospital admissions for COPD  E92000001
# 131   92302         Emergency hospital admissions for COPD  E92000001
# 132   92302         Emergency hospital admissions for COPD  E92000001
# 133   92302         Emergency hospital admissions for COPD  E92000001
# 134   92302         Emergency hospital admissions for COPD  E92000001
# 135   92302         Emergency hospital admissions for COPD  E92000001
# 136   92302         Emergency hospital admissions for COPD  E92000001
# 137   92302         Emergency hospital admissions for COPD  E92000001
# 138   92302         Emergency hospital admissions for COPD  E92000001
# 139   92302         Emergency hospital admissions for COPD  E92000001
# 140   92302         Emergency hospital admissions for COPD  E92000001
# 141   92302         Emergency hospital admissions for COPD  E92000001
# 142   92302         Emergency hospital admissions for COPD  E92000001
# 143   92302         Emergency hospital admissions for COPD  E92000001
# 144   92302         Emergency hospital admissions for COPD  E92000001
# 145   92302         Emergency hospital admissions for COPD  E92000001
# 146   92302         Emergency hospital admissions for COPD  E92000001
# 147   92302         Emergency hospital admissions for COPD  E92000001
# 148   92302         Emergency hospital admissions for COPD  E92000001
# 149   92302         Emergency hospital admissions for COPD  E92000001
# 150   92302         Emergency hospital admissions for COPD  E92000001
# 151   92302         Emergency hospital admissions for COPD  E92000001
# 152   92302         Emergency hospital admissions for COPD  E92000001
# 153   92302         Emergency hospital admissions for COPD  E92000001
# 154   92302         Emergency hospital admissions for COPD  E92000001
# 155   92302         Emergency hospital admissions for COPD  E92000001
# 156   92302         Emergency hospital admissions for COPD  E92000001
# 157   92302         Emergency hospital admissions for COPD  E92000001
# 158   92302         Emergency hospital admissions for COPD  E92000001
# 159   92302         Emergency hospital admissions for COPD  E92000001
# 160   92302         Emergency hospital admissions for COPD  E92000001
# 161   92302         Emergency hospital admissions for COPD  E92000001
# 162   92302         Emergency hospital admissions for COPD  E92000001
# 163   92302         Emergency hospital admissions for COPD  E92000001
# 164   92302         Emergency hospital admissions for COPD  E92000001
# 165   92302         Emergency hospital admissions for COPD  E92000001
# 166   92302         Emergency hospital admissions for COPD  E92000001
# 167   92302         Emergency hospital admissions for COPD  E92000001
# 168   92302         Emergency hospital admissions for COPD  E92000001
# 169   92302         Emergency hospital admissions for COPD  E92000001
# 170   92302         Emergency hospital admissions for COPD  E92000001
# 171   92302         Emergency hospital admissions for COPD  E92000001
# 172   92302         Emergency hospital admissions for COPD  E92000001
# 173   92302         Emergency hospital admissions for COPD  E92000001
# 174   92302         Emergency hospital admissions for COPD  E92000001
# 175   92302         Emergency hospital admissions for COPD  E92000001
# 176   92302         Emergency hospital admissions for COPD  E92000001
# 177   92302         Emergency hospital admissions for COPD  E92000001
# 178   92302         Emergency hospital admissions for COPD  E92000001
# 179   92302         Emergency hospital admissions for COPD  E92000001
# 180   92302         Emergency hospital admissions for COPD  E92000001
# 181   92302         Emergency hospital admissions for COPD  E92000001
# 182   92302         Emergency hospital admissions for COPD  E92000001
# 183   92302         Emergency hospital admissions for COPD  E92000001
# 184   92302         Emergency hospital admissions for COPD  E92000001
# 185   92302         Emergency hospital admissions for COPD  E92000001
# 186   92302         Emergency hospital admissions for COPD  E92000001
# 187   92302         Emergency hospital admissions for COPD  E92000001
# 188   92302         Emergency hospital admissions for COPD  E92000001
# 189   92302         Emergency hospital admissions for COPD  E92000001
# 190   92302         Emergency hospital admissions for COPD  E92000001
# 191   92302         Emergency hospital admissions for COPD  E92000001
# 192   92302         Emergency hospital admissions for COPD  E92000001
# 193   92302         Emergency hospital admissions for COPD  E92000001
# 194   92302         Emergency hospital admissions for COPD  E92000001
# 195   92302         Emergency hospital admissions for COPD  E92000001
# 196   92302         Emergency hospital admissions for COPD  E92000001
# 197   92302         Emergency hospital admissions for COPD  E92000001
# 198   92302         Emergency hospital admissions for COPD  E92000001
# 199   92302         Emergency hospital admissions for COPD  E92000001
# 200   92302         Emergency hospital admissions for COPD  E92000001
# 201   92302         Emergency hospital admissions for COPD  E92000001
# 202   92302         Emergency hospital admissions for COPD  E92000001
# 203   92302         Emergency hospital admissions for COPD  E92000001
# 204   92302         Emergency hospital admissions for COPD  E92000001
# 205   92302         Emergency hospital admissions for COPD  E92000001
# 206   92302         Emergency hospital admissions for COPD  E92000001
# 207   92302         Emergency hospital admissions for COPD  E92000001
# 208   92302         Emergency hospital admissions for COPD  E92000001
# 209   92302         Emergency hospital admissions for COPD  E92000001
# 210   92302         Emergency hospital admissions for COPD  E92000001
# 211   92302         Emergency hospital admissions for COPD  E92000001
# 212   92302         Emergency hospital admissions for COPD  E92000001
# 213   92302         Emergency hospital admissions for COPD  E92000001
# 214   92302         Emergency hospital admissions for COPD  E92000001
# 215   92302         Emergency hospital admissions for COPD  E92000001
# 216   92302         Emergency hospital admissions for COPD  E92000001
# 217   92302         Emergency hospital admissions for COPD  E92000001
# 218   92302         Emergency hospital admissions for COPD  E92000001
# 219   92302         Emergency hospital admissions for COPD  E92000001
# 220   92302         Emergency hospital admissions for COPD  E92000001
# 221   92302         Emergency hospital admissions for COPD  E92000001
# 222   92302         Emergency hospital admissions for COPD  E92000001
# 223   92302         Emergency hospital admissions for COPD  E92000001
# 224   92302         Emergency hospital admissions for COPD  E92000001
# 225   92302         Emergency hospital admissions for COPD  E92000001
# 226   92302         Emergency hospital admissions for COPD  E92000001
# 227   92302         Emergency hospital admissions for COPD  E92000001
# 228   92302         Emergency hospital admissions for COPD  E92000001
# 229   92302         Emergency hospital admissions for COPD  E92000001
# 230   92302         Emergency hospital admissions for COPD  E92000001
# 231   92302         Emergency hospital admissions for COPD  E92000001
# 232   92302         Emergency hospital admissions for COPD  E92000001
# 233   92302         Emergency hospital admissions for COPD  E92000001
# 234   92302         Emergency hospital admissions for COPD  E92000001
# 235   92302         Emergency hospital admissions for COPD  E92000001
# 236   92302         Emergency hospital admissions for COPD  E92000001
# 237   92302         Emergency hospital admissions for COPD  E92000001
# 238   92302         Emergency hospital admissions for COPD  E92000001
# 239   92302         Emergency hospital admissions for COPD  E92000001
# 240   92302         Emergency hospital admissions for COPD  E92000001
# 241   92302         Emergency hospital admissions for COPD  E92000001
# 242   92302         Emergency hospital admissions for COPD  E92000001
# 243   92302         Emergency hospital admissions for COPD  E92000001
# 244   92302         Emergency hospital admissions for COPD  E92000001
# 245   92302         Emergency hospital admissions for COPD  E92000001
# 246   92302         Emergency hospital admissions for COPD  E92000001
# 247   92302         Emergency hospital admissions for COPD  E92000001
# 248   92302         Emergency hospital admissions for COPD  E92000001
# 249   92302         Emergency hospital admissions for COPD  E92000001
# 250   92302         Emergency hospital admissions for COPD  E92000001
# 251   92302         Emergency hospital admissions for COPD  E92000001
# 252   92302         Emergency hospital admissions for COPD  E92000001
# 253   92302         Emergency hospital admissions for COPD  E92000001
# 254   92302         Emergency hospital admissions for COPD  E92000001
# 255   92302         Emergency hospital admissions for COPD  E92000001
# 256   92302         Emergency hospital admissions for COPD  E92000001
# 257   92302         Emergency hospital admissions for COPD  E92000001
# 258   92302         Emergency hospital admissions for COPD  E92000001
# 259   92302         Emergency hospital admissions for COPD  E92000001
# 260   92302         Emergency hospital admissions for COPD  E92000001
# 261   92302         Emergency hospital admissions for COPD  E92000001
# 262   92302         Emergency hospital admissions for COPD  E92000001
# 263   92302         Emergency hospital admissions for COPD  E92000001
# 264   92302         Emergency hospital admissions for COPD  E92000001
# 265   92302         Emergency hospital admissions for COPD  E92000001
# 266   92302         Emergency hospital admissions for COPD  E92000001
# 267   92302         Emergency hospital admissions for COPD  E92000001
# 268   92302         Emergency hospital admissions for COPD  E92000001
# 269   92302         Emergency hospital admissions for COPD  E92000001
# 270   92302         Emergency hospital admissions for COPD  E92000001
# 271   92302         Emergency hospital admissions for COPD  E92000001
# 272   92302         Emergency hospital admissions for COPD  E92000001
# 273   92302         Emergency hospital admissions for COPD  E92000001
# 274   92302         Emergency hospital admissions for COPD  E92000001
# 275   92302         Emergency hospital admissions for COPD  E92000001
# 276   92302         Emergency hospital admissions for COPD  E92000001
# 277   92302         Emergency hospital admissions for COPD  E92000001
# 278   92302         Emergency hospital admissions for COPD  E92000001
# 279   92302         Emergency hospital admissions for COPD  E92000001
# 280   92302         Emergency hospital admissions for COPD  E92000001
# 281   92302         Emergency hospital admissions for COPD  E92000001
# 282   92302         Emergency hospital admissions for COPD  E92000001
# 283   92302         Emergency hospital admissions for COPD  E92000001
# 284   92302         Emergency hospital admissions for COPD  E92000001
# 285   92302         Emergency hospital admissions for COPD  E92000001
# 286   92302         Emergency hospital admissions for COPD  E92000001
# 287   92302         Emergency hospital admissions for COPD  E92000001
# 288   92302         Emergency hospital admissions for COPD  E92000001
# 289   92302         Emergency hospital admissions for COPD  E92000001
# 290   92302         Emergency hospital admissions for COPD  E92000001
# 291   92302         Emergency hospital admissions for COPD  E92000001
# 292   92302         Emergency hospital admissions for COPD  E92000001
# 293   92302         Emergency hospital admissions for COPD  E92000001
# 294   92302         Emergency hospital admissions for COPD  E92000001
# 295   92302         Emergency hospital admissions for COPD  E92000001
# 296   92302         Emergency hospital admissions for COPD  E92000001
# 297   92302         Emergency hospital admissions for COPD  E92000001
# 298   92302         Emergency hospital admissions for COPD  E92000001
# 299   92302         Emergency hospital admissions for COPD  E92000001
# 300   92302         Emergency hospital admissions for COPD  E92000001
# 301   92302         Emergency hospital admissions for COPD  E92000001
# 302   92302         Emergency hospital admissions for COPD  E92000001
# 303   92302         Emergency hospital admissions for COPD  E92000001
# 304   92302         Emergency hospital admissions for COPD  E92000001
# 305   92302         Emergency hospital admissions for COPD  E92000001
# 306   92302         Emergency hospital admissions for COPD  E92000001
# 307   92302         Emergency hospital admissions for COPD  E92000001
# 308   92302         Emergency hospital admissions for COPD  E92000001
# 309   92302         Emergency hospital admissions for COPD  E92000001
# 310   92302         Emergency hospital admissions for COPD  E92000001
# 311   92302         Emergency hospital admissions for COPD  E92000001
# 312   92302         Emergency hospital admissions for COPD  E92000001
# 313   92302         Emergency hospital admissions for COPD  E92000001
# 314   92302         Emergency hospital admissions for COPD  E92000001
# 315   92302         Emergency hospital admissions for COPD  E92000001
# 316   92302         Emergency hospital admissions for COPD  E92000001
# 317   92302         Emergency hospital admissions for COPD  E92000001
# 318   92302         Emergency hospital admissions for COPD  E92000001
# 319   92302         Emergency hospital admissions for COPD  E92000001
# 320   92302         Emergency hospital admissions for COPD  E92000001
# 321   92302         Emergency hospital admissions for COPD  E92000001
# 322   92302         Emergency hospital admissions for COPD  E92000001
# 323   92302         Emergency hospital admissions for COPD  E92000001
# 324   92302         Emergency hospital admissions for COPD  E92000001
# 325   92302         Emergency hospital admissions for COPD  E92000001
# 326   92302         Emergency hospital admissions for COPD  E92000001
# 327   92302         Emergency hospital admissions for COPD  E92000001
# 328   92302         Emergency hospital admissions for COPD  E92000001
# 329   92302         Emergency hospital admissions for COPD  E92000001
# 330   92302         Emergency hospital admissions for COPD  E92000001
# 331   92302         Emergency hospital admissions for COPD  E92000001
# 332   92302         Emergency hospital admissions for COPD  E92000001
# 333   92302         Emergency hospital admissions for COPD  E92000001
# 334   92302         Emergency hospital admissions for COPD  E92000001
# 335   92302         Emergency hospital admissions for COPD  E92000001
# 336   92302         Emergency hospital admissions for COPD  E92000001
# 337   92302         Emergency hospital admissions for COPD  E92000001
# 338   92302         Emergency hospital admissions for COPD  E92000001
# 339   92302         Emergency hospital admissions for COPD  E92000001
# 340   92302         Emergency hospital admissions for COPD  E92000001
# 341   92302         Emergency hospital admissions for COPD  E92000001
# 342   92302         Emergency hospital admissions for COPD  E92000001
# 343   92302         Emergency hospital admissions for COPD  E92000001
# 344   92302         Emergency hospital admissions for COPD  E92000001
# 345   92302         Emergency hospital admissions for COPD  E92000001
# 346   92302         Emergency hospital admissions for COPD  E92000001
# 347   92302         Emergency hospital admissions for COPD  E92000001
# 348   92302         Emergency hospital admissions for COPD  E92000001
# 349   92302         Emergency hospital admissions for COPD  E92000001
# 350   92302         Emergency hospital admissions for COPD  E92000001
# 351   92302         Emergency hospital admissions for COPD  E92000001
# 352   92302         Emergency hospital admissions for COPD  E92000001
# 353   92302         Emergency hospital admissions for COPD  E92000001
# 354   92302         Emergency hospital admissions for COPD  E92000001
# 355   92302         Emergency hospital admissions for COPD  E92000001
# 356   92302         Emergency hospital admissions for COPD  E92000001
# 357   92302         Emergency hospital admissions for COPD  E92000001
# 358   92302         Emergency hospital admissions for COPD  E92000001
# 359   92302         Emergency hospital admissions for COPD  E92000001
# 360   92302         Emergency hospital admissions for COPD  E92000001
# 361   92302         Emergency hospital admissions for COPD  E92000001
# 362   92302         Emergency hospital admissions for COPD  E92000001
# 363   92302         Emergency hospital admissions for COPD  E92000001
# 364   92302         Emergency hospital admissions for COPD  E92000001
# 365   92302         Emergency hospital admissions for COPD  E92000001
# 366   92302         Emergency hospital admissions for COPD  E92000001
# 367   92302         Emergency hospital admissions for COPD  E92000001
# 368   92302         Emergency hospital admissions for COPD  E92000001
# 369   92302         Emergency hospital admissions for COPD  E92000001
# 370   92302         Emergency hospital admissions for COPD  E92000001
# 371   92302         Emergency hospital admissions for COPD  E92000001
# 372   92302         Emergency hospital admissions for COPD  E92000001
# 373   92302         Emergency hospital admissions for COPD  E92000001
# 374   92302         Emergency hospital admissions for COPD  E92000001
# 375   92302         Emergency hospital admissions for COPD  E92000001
# 376   92302         Emergency hospital admissions for COPD  E92000001
# 377   92302         Emergency hospital admissions for COPD  E92000001
# 378   92302         Emergency hospital admissions for COPD  E92000001
# 379   92302         Emergency hospital admissions for COPD  E92000001
# 380   92302         Emergency hospital admissions for COPD  E92000001
# 381   92302         Emergency hospital admissions for COPD  E92000001
# 382   92302         Emergency hospital admissions for COPD  E92000001
# 383   92302         Emergency hospital admissions for COPD  E92000001
# 384   92302         Emergency hospital admissions for COPD  E92000001
# 385   92302         Emergency hospital admissions for COPD  E92000001
# 386   92302         Emergency hospital admissions for COPD  E92000001
# 387   92302         Emergency hospital admissions for COPD  E92000001
# 388   92302         Emergency hospital admissions for COPD  E92000001
# 389   92302         Emergency hospital admissions for COPD  E92000001
# 390   92302         Emergency hospital admissions for COPD  E92000001
# 391   92302         Emergency hospital admissions for COPD  E92000001
# 392   92302         Emergency hospital admissions for COPD  E92000001
# 393   92302         Emergency hospital admissions for COPD  E92000001
# 394   92302         Emergency hospital admissions for COPD  E92000001
# 395   92302         Emergency hospital admissions for COPD  E92000001
# 396   92302         Emergency hospital admissions for COPD  E92000001
# 397   92302         Emergency hospital admissions for COPD  E92000001
# 398   92302         Emergency hospital admissions for COPD  E92000001
# 399   92302         Emergency hospital admissions for COPD  E92000001
# 400   92302         Emergency hospital admissions for COPD  E92000001
# 401   92302         Emergency hospital admissions for COPD  E92000001
# 402   92302         Emergency hospital admissions for COPD  E92000001
# 403   92302         Emergency hospital admissions for COPD  E92000001
# 404   92302         Emergency hospital admissions for COPD  E92000001
# 405   92302         Emergency hospital admissions for COPD  E92000001
# 406   92302         Emergency hospital admissions for COPD  E92000001
# 407   92302         Emergency hospital admissions for COPD  E92000001
# 408   92302         Emergency hospital admissions for COPD  E92000001
# 409   92302         Emergency hospital admissions for COPD  E92000001
# 410   92302         Emergency hospital admissions for COPD  E92000001
# 411   92302         Emergency hospital admissions for COPD  E92000001
# 412   92302         Emergency hospital admissions for COPD  E92000001
# 413   92302         Emergency hospital admissions for COPD  E92000001
# 414   92302         Emergency hospital admissions for COPD  E92000001
# 415   92302         Emergency hospital admissions for COPD  E92000001
# 416   92302         Emergency hospital admissions for COPD  E92000001
# 417   92302         Emergency hospital admissions for COPD  E92000001
# 418   92302         Emergency hospital admissions for COPD  E92000001
# 419   92302         Emergency hospital admissions for COPD  E92000001
# 420   92302         Emergency hospital admissions for COPD  E92000001
# 421   92302         Emergency hospital admissions for COPD  E92000001
# 422   92302         Emergency hospital admissions for COPD  E92000001
# 423   92302         Emergency hospital admissions for COPD  E92000001
# 424   92302         Emergency hospital admissions for COPD  E92000001
# 425   92302         Emergency hospital admissions for COPD  E92000001
# 426   92302         Emergency hospital admissions for COPD  E92000001
# 427   92302         Emergency hospital admissions for COPD  E92000001
# 428   92302         Emergency hospital admissions for COPD  E92000001
# 429   92302         Emergency hospital admissions for COPD  E92000001
# 430   92302         Emergency hospital admissions for COPD  E92000001
# 431   92302         Emergency hospital admissions for COPD  E92000001
# 432   92302         Emergency hospital admissions for COPD  E92000001
# 433   92302         Emergency hospital admissions for COPD  E92000001
# 434   92302         Emergency hospital admissions for COPD  E92000001
# 435   92302         Emergency hospital admissions for COPD  E92000001
# 436   92302         Emergency hospital admissions for COPD  E92000001
# 437   92302         Emergency hospital admissions for COPD  E92000001
# 438   92302         Emergency hospital admissions for COPD  E92000001
# 439   92302         Emergency hospital admissions for COPD  E92000001
# 440   92302         Emergency hospital admissions for COPD  E92000001
# 441   92302         Emergency hospital admissions for COPD  E92000001
# 442   92302         Emergency hospital admissions for COPD  E92000001
# 443   92302         Emergency hospital admissions for COPD  E92000001
# 444   92302         Emergency hospital admissions for COPD  E92000001
# 445   92302         Emergency hospital admissions for COPD  E92000001
# 446   92302         Emergency hospital admissions for COPD  E92000001
# 447   92302         Emergency hospital admissions for COPD  E92000001
# 448   92302         Emergency hospital admissions for COPD  E92000001
# 449   92302         Emergency hospital admissions for COPD  E92000001
# 450   92302         Emergency hospital admissions for COPD  E92000001
# 451   92302         Emergency hospital admissions for COPD  E92000001
# 452   92302         Emergency hospital admissions for COPD  E92000001
# 453   92302         Emergency hospital admissions for COPD  E92000001
# 454   92302         Emergency hospital admissions for COPD  E92000001
# 455   92302         Emergency hospital admissions for COPD  E92000001
# 456   92302         Emergency hospital admissions for COPD  E92000001
# 457   92302         Emergency hospital admissions for COPD  E92000001
# 458   92302         Emergency hospital admissions for COPD  E92000001
# 459   92302         Emergency hospital admissions for COPD  E92000001
# 460   92302         Emergency hospital admissions for COPD  E92000001
# 461   92302         Emergency hospital admissions for COPD  E92000001
# 462   92302         Emergency hospital admissions for COPD  E92000001
# 463   92302         Emergency hospital admissions for COPD  E92000001
# 464   92302         Emergency hospital admissions for COPD  E92000001
# 465   92302         Emergency hospital admissions for COPD  E92000001
# 466   92302         Emergency hospital admissions for COPD  E92000001
# 467   92302         Emergency hospital admissions for COPD  E92000001
# 468   92302         Emergency hospital admissions for COPD  E92000001
# 469   92302         Emergency hospital admissions for COPD  E92000001
# 470   92302         Emergency hospital admissions for COPD  E92000001
# 471   92302         Emergency hospital admissions for COPD  E92000001
# 472   92302         Emergency hospital admissions for COPD  E92000001
# 473   92302         Emergency hospital admissions for COPD  E92000001
# 474   92302         Emergency hospital admissions for COPD  E92000001
# 475   92302         Emergency hospital admissions for COPD  E92000001
# 476   92302         Emergency hospital admissions for COPD  E92000001
# 477   92302         Emergency hospital admissions for COPD  E92000001
# 478   92302         Emergency hospital admissions for COPD  E92000001
# 479   92302         Emergency hospital admissions for COPD  E92000001
# 480   92302         Emergency hospital admissions for COPD  E92000001
# 481   92302         Emergency hospital admissions for COPD  E92000001
# 482   92302         Emergency hospital admissions for COPD  E92000001
# 483   92302         Emergency hospital admissions for COPD  E92000001
# 484   92302         Emergency hospital admissions for COPD  E92000001
# 485   92302         Emergency hospital admissions for COPD  E92000001
# 486   92302         Emergency hospital admissions for COPD  E92000001
# 487   92302         Emergency hospital admissions for COPD  E92000001
# 488   92302         Emergency hospital admissions for COPD  E92000001
# 489   92302         Emergency hospital admissions for COPD  E92000001
# 490   92302         Emergency hospital admissions for COPD  E92000001
# 491   92302         Emergency hospital admissions for COPD  E92000001
# 492   92302         Emergency hospital admissions for COPD  E92000001
# 493   92302         Emergency hospital admissions for COPD  E92000001
# 494   92302         Emergency hospital admissions for COPD  E92000001
# 495   92302         Emergency hospital admissions for COPD  E92000001
# 496   92302         Emergency hospital admissions for COPD  E92000001
# 497   92302         Emergency hospital admissions for COPD  E92000001
# 498   92302         Emergency hospital admissions for COPD  E92000001
# 499   92302         Emergency hospital admissions for COPD  E92000001
# 500   92302         Emergency hospital admissions for COPD  E92000001
# 501   92302         Emergency hospital admissions for COPD  E92000001
# 502   92302         Emergency hospital admissions for COPD  E92000001
# 503   92302         Emergency hospital admissions for COPD  E92000001
# 504   92302         Emergency hospital admissions for COPD  E92000001
# 505   92302         Emergency hospital admissions for COPD  E92000001
# 506   92302         Emergency hospital admissions for COPD  E92000001
# 507   92302         Emergency hospital admissions for COPD  E92000001
# 508   92302         Emergency hospital admissions for COPD  E92000001
# 509   92302         Emergency hospital admissions for COPD  E92000001
# 510   92302         Emergency hospital admissions for COPD  E92000001
# 511   92302         Emergency hospital admissions for COPD  E92000001
# 512   92302         Emergency hospital admissions for COPD  E92000001
# 513   92302         Emergency hospital admissions for COPD  E92000001
# 514   92302         Emergency hospital admissions for COPD  E92000001
# 515   92302         Emergency hospital admissions for COPD  E92000001
# 516   92302         Emergency hospital admissions for COPD  E92000001
# 517   92302         Emergency hospital admissions for COPD  E92000001
# 518   92302         Emergency hospital admissions for COPD  E92000001
# 519   92302         Emergency hospital admissions for COPD  E92000001
# 520   92302         Emergency hospital admissions for COPD  E92000001
# 521   92302         Emergency hospital admissions for COPD  E92000001
# 522   92302         Emergency hospital admissions for COPD  E92000001
# 523   92302         Emergency hospital admissions for COPD  E92000001
# 524   92302         Emergency hospital admissions for COPD  E92000001
# 525   92302         Emergency hospital admissions for COPD  E92000001
# 526   92302         Emergency hospital admissions for COPD  E92000001
# 527   92302         Emergency hospital admissions for COPD  E92000001
# 528   92302         Emergency hospital admissions for COPD  E92000001
# 529   92302         Emergency hospital admissions for COPD  E92000001
# 530   92302         Emergency hospital admissions for COPD  E92000001
# 531   92302         Emergency hospital admissions for COPD  E92000001
# 532   92302         Emergency hospital admissions for COPD  E92000001
# 533   92302         Emergency hospital admissions for COPD  E92000001
# 534   92302         Emergency hospital admissions for COPD  E92000001
# 535   92302         Emergency hospital admissions for COPD  E92000001
# 536   92302         Emergency hospital admissions for COPD  E92000001
# 537   92302         Emergency hospital admissions for COPD  E92000001
# 538   92302         Emergency hospital admissions for COPD  E92000001
# 539   92302         Emergency hospital admissions for COPD  E92000001
# 540   92302         Emergency hospital admissions for COPD  E92000001
# 541   92302         Emergency hospital admissions for COPD  E92000001
# 542   92302         Emergency hospital admissions for COPD  E92000001
# 543   92302         Emergency hospital admissions for COPD  E92000001
# 544   92302         Emergency hospital admissions for COPD  E92000001
# 545   92302         Emergency hospital admissions for COPD  E92000001
# 546   92302         Emergency hospital admissions for COPD  E92000001
# 547   92302         Emergency hospital admissions for COPD  E92000001
# 548   92302         Emergency hospital admissions for COPD  E92000001
# 549   92302         Emergency hospital admissions for COPD  E92000001
# 550   92302         Emergency hospital admissions for COPD  E92000001
# 551   92302         Emergency hospital admissions for COPD  E92000001
# 552   92302         Emergency hospital admissions for COPD  E92000001
# 553   92302         Emergency hospital admissions for COPD  E92000001
# 554   92302         Emergency hospital admissions for COPD  E92000001
# 555   92302         Emergency hospital admissions for COPD  E92000001
# 556   92302         Emergency hospital admissions for COPD  E92000001
# 557   92302         Emergency hospital admissions for COPD  E92000001
# 558   92302         Emergency hospital admissions for COPD  E92000001
# 559   92302         Emergency hospital admissions for COPD  E92000001
# 560   92302         Emergency hospital admissions for COPD  E92000001
# 561   92302         Emergency hospital admissions for COPD  E92000001
# 562   92302         Emergency hospital admissions for COPD  E92000001
# 563   92302         Emergency hospital admissions for COPD  E92000001
# 564   92302         Emergency hospital admissions for COPD  E92000001
# 565   92302         Emergency hospital admissions for COPD  E92000001
# 566   92302         Emergency hospital admissions for COPD  E92000001
# 567   92302         Emergency hospital admissions for COPD  E92000001
# 568   92302         Emergency hospital admissions for COPD  E92000001
# 569   92302         Emergency hospital admissions for COPD  E92000001
# 570   92302         Emergency hospital admissions for COPD  E92000001
# 571   92302         Emergency hospital admissions for COPD  E92000001
# 572   92302         Emergency hospital admissions for COPD  E92000001
# 573   92302         Emergency hospital admissions for COPD  NaN
# 574   92302         Emergency hospital admissions for COPD  NaN
# 575   92302         Emergency hospital admissions for COPD  NaN
# 576   92302         Emergency hospital admissions for COPD  NaN
# 577   92302         Emergency hospital admissions for COPD  NaN
# 578   92302         Emergency hospital admissions for COPD  NaN
# 579   92302         Emergency hospital admissions for COPD  NaN
# 580   92302         Emergency hospital admissions for COPD  NaN
# 581   92302         Emergency hospital admissions for COPD  NaN
# 582   92302         Emergency hospital admissions for COPD  NaN
# 583   92302         Emergency hospital admissions for COPD  NaN
# 584   92302         Emergency hospital admissions for COPD  NaN
# 585   92302         Emergency hospital admissions for COPD  NaN
# 586   92302         Emergency hospital admissions for COPD  NaN
# 587   92302         Emergency hospital admissions for COPD  NaN
# 588   92302         Emergency hospital admissions for COPD  NaN
# 589   92302         Emergency hospital admissions for COPD  NaN
# 590   92302         Emergency hospital admissions for COPD  NaN
# 591   92302         Emergency hospital admissions for COPD  NaN
# 592   92302         Emergency hospital admissions for COPD  NaN
# 593   92302         Emergency hospital admissions for COPD  NaN
# 594   92302         Emergency hospital admissions for COPD  NaN
# 595   92302         Emergency hospital admissions for COPD  NaN
# 596   92302         Emergency hospital admissions for COPD  NaN
# 597   92302         Emergency hospital admissions for COPD  NaN
# 598   92302         Emergency hospital admissions for COPD  NaN
# 599   92302         Emergency hospital admissions for COPD  NaN
# 600   92302         Emergency hospital admissions for COPD  NaN
# 601   92302         Emergency hospital admissions for COPD  NaN
# 602   92302         Emergency hospital admissions for COPD  NaN
# 603   92302         Emergency hospital admissions for COPD  NaN
# 604   92302         Emergency hospital admissions for COPD  NaN
# 605   92302         Emergency hospital admissions for COPD  NaN
# 606   92302         Emergency hospital admissions for COPD  NaN
# 607   92302         Emergency hospital admissions for COPD  NaN
# 608   92302         Emergency hospital admissions for COPD  NaN
# 609   92302         Emergency hospital admissions for COPD  NaN
# 610   92302         Emergency hospital admissions for COPD  NaN
# 611   92302         Emergency hospital admissions for COPD  NaN
# 612   92302         Emergency hospital admissions for COPD  NaN
# 613   92302         Emergency hospital admissions for COPD  NaN
# 614   92302         Emergency hospital admissions for COPD  NaN
# 615   92302         Emergency hospital admissions for COPD  NaN
# 616   92302         Emergency hospital admissions for COPD  NaN
# 617   92302         Emergency hospital admissions for COPD  NaN
# 618   92302         Emergency hospital admissions for COPD  NaN
# 619   92302         Emergency hospital admissions for COPD  NaN
# 620   92302         Emergency hospital admissions for COPD  NaN
# 621   92302         Emergency hospital admissions for COPD  NaN
# 622   92302         Emergency hospital admissions for COPD  NaN
# 623   92302         Emergency hospital admissions for COPD  NaN
# 624   92302         Emergency hospital admissions for COPD  NaN
# 625   92302         Emergency hospital admissions for COPD  NaN
# 626   92302         Emergency hospital admissions for COPD  NaN
# 627   92302         Emergency hospital admissions for COPD  NaN
# 628   92302         Emergency hospital admissions for COPD  NaN
# 629   92302         Emergency hospital admissions for COPD  NaN
# 630   92302         Emergency hospital admissions for COPD  NaN
# 631   92302         Emergency hospital admissions for COPD  NaN
# 632   92302         Emergency hospital admissions for COPD  NaN
# 633   92302         Emergency hospital admissions for COPD  NaN
# 634   92302         Emergency hospital admissions for COPD  NaN
# 635   92302         Emergency hospital admissions for COPD  NaN
# 636   92302         Emergency hospital admissions for COPD  E92000001
# 637   92302         Emergency hospital admissions for COPD  E92000001
# 638   92302         Emergency hospital admissions for COPD  E92000001
# 639   92302         Emergency hospital admissions for COPD  E92000001
# 640   92302         Emergency hospital admissions for COPD  E92000001
# 641   92302         Emergency hospital admissions for COPD  E92000001
# 642   92302         Emergency hospital admissions for COPD  E92000001
# 643   92302         Emergency hospital admissions for COPD  E92000001
# 644   92302         Emergency hospital admissions for COPD  E92000001
# 645   92302         Emergency hospital admissions for COPD  E92000001
# 646   92302         Emergency hospital admissions for COPD  E92000001
# ...
# 1720  20130000             NaN       NaN
# 1721  20130000             NaN       NaN
# 1722  20130000             NaN       NaN
# 1723  20130000             NaN       NaN
# 1724  20130000             NaN       NaN
# 1725  20130000             NaN       NaN
# 1726  20130000             NaN       NaN
# 1727  20130000             NaN       NaN
# 1728  20130000             NaN       NaN
# 1729  20130000             NaN       NaN
# 1730  20130000             NaN       NaN
# 1731  20130000             NaN       NaN
# 1732  20130000             NaN       NaN
# 1733  20130000             NaN       NaN
# 1734  20130000             NaN       NaN
# 1735  20130000             NaN       NaN
# 1736  20130000             NaN       NaN
# 1737  20130000             NaN       NaN
# 1738  20130000             NaN       NaN
# 1739  20130000             NaN       NaN
# 1740  20130000             NaN       NaN
# 1741  20130000             NaN       NaN
# 1742  20130000             NaN       NaN
# 1743  20130000             NaN       NaN
# 1744  20130000             NaN       NaN
# 1745  20130000             NaN       NaN
# 1746  20130000             NaN       NaN
# 1747  20130000             NaN       NaN
# 1748  20130000             NaN       NaN
# 1749  20130000             NaN       NaN
# 1750  20130000             NaN       NaN
# 1751  20130000             NaN       NaN
# 1752  20130000             NaN       NaN
# 1753  20130000             NaN       NaN
# 1754  20130000             NaN       NaN
# 1755  20130000             NaN       NaN
# 1756  20130000             NaN       NaN
# 1757  20130000             NaN       NaN
# 1758  20130000             NaN       NaN
# 1759  20130000             NaN       NaN
# 1760  20130000             NaN       NaN
# 1761  20130000             NaN       NaN
# 1762  20130000             NaN       NaN
# 1763  20130000             NaN       NaN
# 1764  20130000             NaN       NaN
# 1765  20130000             NaN       NaN
# 1766  20130000             NaN       NaN
# 1767  20130000             NaN       NaN
# 1768  20130000             NaN       NaN
# 1769  20130000             NaN       NaN
# 1770  20130000             NaN       NaN
# 1771  20130000             NaN       NaN
# 1772  20130000             NaN       NaN
# 1773  20130000             NaN       NaN
# 1774  20130000             NaN       NaN
# 1775  20130000             NaN       NaN
# 1776  20130000             NaN       NaN
# 1777  20130000             NaN       NaN
# 1778  20130000             NaN       NaN
# 1779  20130000             NaN       NaN
# 1780  20130000             NaN       NaN
# 1781  20130000             NaN       NaN
# 1782  20130000             NaN       NaN
# 1783  20130000             NaN       NaN
# 1784  20130000             NaN       NaN
# 1785  20130000             NaN       NaN
# 1786  20130000             NaN       NaN
# 1787  20130000             NaN       NaN
# 1788  20130000             NaN       NaN
# 1789  20130000             NaN       NaN
# 1790  20130000             NaN       NaN
# 1791  20130000             NaN       NaN
# 1792  20130000             NaN       NaN
# 1793  20130000             NaN       NaN
# 1794  20130000             NaN       NaN
# 1795  20130000             NaN       NaN
# 1796  20130000             NaN       NaN
# 1797  20130000             NaN       NaN
# 1798  20130000             NaN       NaN
# 1799  20130000             NaN       NaN
# 1800  20130000             NaN       NaN
# 1801  20130000             NaN       NaN
# 1802  20130000             NaN       NaN
# 1803  20130000             NaN       NaN
# 1804  20130000             NaN       NaN
# 1805  20130000             NaN       NaN
# 1806  20130000             NaN       NaN
# 1807  20130000             NaN       NaN
# 1808  20130000             NaN       NaN
# 1809  20130000             NaN       NaN
# 1810  20130000             NaN       NaN
# 1811  20130000             NaN       NaN
# 1812  20130000             NaN       NaN
# 1813  20130000             NaN       NaN
# 1814  20130000             NaN       NaN
# 1815  20130000             NaN       NaN
# 1816  20130000             NaN       NaN
# 1817  20130000             NaN       NaN
# 1818  20130000             NaN       NaN
# 1819  20130000             NaN       NaN
# 1820  20130000             NaN       NaN
# 1821  20130000             NaN       NaN
# 1822  20130000             NaN       NaN
# 1823  20130000             NaN       NaN
# 1824  20130000             NaN       NaN
# 1825  20130000             NaN       NaN
# 1826  20130000             NaN       NaN
# 1827  20130000             NaN       NaN
# 1828  20130000             NaN       NaN
# 1829  20130000             NaN       NaN
# 1830  20130000             NaN       NaN
# 1831  20130000             NaN       NaN
# 1832  20130000             NaN       NaN
# 1833  20130000             NaN       NaN
# 1834  20130000             NaN       NaN
# 1835  20130000             NaN       NaN
# 1836  20130000             NaN       NaN
# 1837  20130000             NaN       NaN
# 1838  20130000             NaN       NaN
# 1839  20130000             NaN       NaN
# 1840  20130000             NaN       NaN
# 1841  20130000             NaN       NaN
# 1842  20130000             NaN       NaN
# 1843  20130000             NaN       NaN
# 1844  20130000             NaN       NaN
# 1845  20130000             NaN       NaN
# 1846  20130000             NaN       NaN
# 1847  20130000             NaN       NaN
# 1848  20130000             NaN       NaN
# 1849  20130000             NaN       NaN
# 1850  20130000             NaN       NaN
# 1851  20130000             NaN       NaN
# 1852  20130000             NaN       NaN
# 1853  20130000             NaN       NaN
# 1854  20130000             NaN       NaN
# 1855  20130000             NaN       NaN
# 1856  20130000             NaN       NaN
# 1857  20130000             NaN       NaN
# 1858  20130000             NaN       NaN
# 1859  20130000             NaN       NaN
# 1860  20130000             NaN       NaN
# 1861  20130000             NaN       NaN
# 1862  20130000             NaN       NaN
# 1863  20130000             NaN       NaN
# 1864  20130000             NaN       NaN
# 1865  20130000             NaN       NaN
# 1866  20130000             NaN       NaN
# 1867  20130000             NaN       NaN
# 1868  20130000             NaN       NaN
# 1869  20130000             NaN       NaN
# 1870  20130000             NaN       NaN
# 1871  20130000             NaN       NaN
# 1872  20130000             NaN       NaN
# 1873  20130000             NaN       NaN
# 1874  20130000             NaN       NaN
# 1875  20130000             NaN       NaN
# 1876  20130000             NaN       NaN
# 1877  20130000             NaN       NaN
# 1878  20130000             NaN       NaN
# 1879  20130000             NaN       NaN
# 1880  20130000             NaN       NaN
# 1881  20130000             NaN       NaN
# 1882  20130000             NaN       NaN
# 1883  20130000             NaN       NaN
# 1884  20130000             NaN       NaN
# 1885  20130000             NaN       NaN
# 1886  20130000             NaN       NaN
# 1887  20130000             NaN       NaN
# 1888  20130000             NaN       NaN
# 1889  20130000             NaN       NaN
# 1890  20130000             NaN       NaN
# 1891  20130000             NaN       NaN
# 1892  20130000             NaN       NaN
# 1893  20130000             NaN       NaN
# 1894  20130000             NaN       NaN
# 1895  20130000             NaN       NaN
# 1896  20130000             NaN       NaN
# 1897  20130000             NaN       NaN
# 1898  20130000             NaN       NaN
# 1899  20130000             NaN       NaN
# 1900  20130000             NaN       NaN
# 1901  20130000             NaN       NaN
# 1902  20130000             NaN       NaN
# 1903  20130000             NaN       NaN
# 1904  20130000             NaN       NaN
# 1905  20130000             NaN       NaN
# 1906  20130000             NaN       NaN
# 1907  20130000             NaN       NaN
# 1908  20130000             NaN       NaN
# 1909  20130000             NaN       NaN
# 1910  20130000             NaN       NaN
# 1911  20130000             NaN       NaN
# 1912  20130000             NaN       NaN
# 1913  20130000             NaN       NaN
# 1914  20130000             NaN       NaN
# 1915  20130000             NaN       NaN
# 1916  20130000             NaN       NaN
# 1917  20130000             NaN       NaN
# 1918  20130000             NaN       NaN
# 1919  20130000             NaN       NaN
# 1920  20130000             NaN       NaN
# 1921  20130000             NaN       NaN
# 1922  20130000             NaN       NaN
# 1923  20130000             NaN       NaN
# 1924  20130000             NaN       NaN
# 1925  20130000             NaN       NaN
# 1926  20130000             NaN       NaN
# 1927  20130000             NaN       NaN
# 1928  20130000             NaN       NaN
# 1929  20130000             NaN       NaN
# 1930  20130000             NaN       NaN
# 1931  20130000             NaN       NaN
# 1932  20130000             NaN       NaN
# 1933  20130000             NaN       NaN
# 1934  20130000             NaN       NaN
# 1935  20130000             NaN       NaN
# 1936  20130000             NaN       NaN
# 1937  20130000             NaN       NaN
# 1938  20130000             NaN       NaN
# 1939  20130000             NaN       NaN
# 1940  20130000             NaN       NaN
# 1941  20130000             NaN       NaN
# 1942  20130000             NaN       NaN
# 1943  20130000             NaN       NaN
# 1944  20130000             NaN       NaN
# 1945  20130000             NaN       NaN
# 1946  20130000             NaN       NaN
# 1947  20130000             NaN       NaN
# 1948  20130000             NaN       NaN
# 1949  20130000             NaN       NaN
# 1950  20130000             NaN       NaN
# 1951  20130000             NaN       NaN
# 1952  20130000             NaN       NaN
# 1953  20130000             NaN       NaN
# 1954  20130000             NaN       NaN
# 1955  20130000             NaN       NaN
# 1956  20130000             NaN       NaN
# 1957  20130000             NaN       NaN
# 1958  20130000             NaN       NaN
# 1959  20130000             NaN       NaN
# 1960  20130000             NaN       NaN
# 1961  20130000             NaN       NaN
# 1962  20130000             NaN       NaN
# 1963  20130000             NaN       NaN
# 1964  20130000             NaN       NaN
# 1965  20130000             NaN       NaN
# 1966  20130000             NaN       NaN
# 1967  20130000             NaN       NaN
# 1968  20130000             NaN       NaN
# 1969  20130000             NaN       NaN
# 1970  20130000             NaN       NaN
# 1971  20130000             NaN       NaN
# 1972  20130000             NaN       NaN
# 1973  20130000             NaN       NaN
# 1974  20130000             NaN       NaN
# 1975  20130000             NaN       NaN
# 1976  20130000             NaN       NaN
# 1977  20130000             NaN       NaN
# 1978  20130000             NaN       NaN
# 1979  20130000             NaN       NaN
# 1980  20130000             NaN       NaN
# 1981  20130000             NaN       NaN
# 1982  20130000             NaN       NaN
# 1983  20130000             NaN       NaN
# 1984  20130000             NaN       NaN
# 1985  20130000             NaN       NaN
# 1986  20130000             NaN       NaN
# 1987  20130000             NaN       NaN
# 1988  20130000             NaN       NaN
# 1989  20130000             NaN       NaN
# 1990  20130000             NaN       NaN
# 1991  20130000             NaN       NaN
# 1992  20130000             NaN       NaN
# 1993  20130000             NaN       NaN
# 1994  20130000             NaN       NaN
# 1995  20130000             NaN       NaN
# 1996  20130000             NaN       NaN
# 1997  20130000             NaN       NaN
# 1998  20130000             NaN       NaN
# 1999  20130000             NaN       NaN
